# %% [markdown]
# # Lasagne Conv Net on Media Eval 2015 Placing Task - Locale

# %%
# Import Python libraries
import numpy as np
import theano
import theano.tensor as Tensor
import lasagne
import time

# allows plots to show inline in ipython notebook
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
# Import own modules
import data_utils, visualize
import lasagne_model_predict_country as cnn_model

# %%
# Model hyperparameters
cnn_architecture = "complex_cnn"
num_filters = 32
filter_width = 3 # can be integer or tuple
pool_width = 2 
stride_width = 1 # can be integer or tuple
padding = 'full'  # can be integer or tuple or 'full', 'same', 'valid'
hidden_size = 256 # size of hidden layer of neurons
dropout_p = 0.0
# lr_decay = 0.995
reg_strength = 0
# grad_clip = 10

# Optimization hyperparams
LEARNING_RATE = 1e-2
MOMENTUM = 0.9
theano.config.optimizer='fast_compile'
theano.config.exception_verbosity='high'

# Training parameters
batchsize = 1000
num_epochs = 10
record_per_iter = True  # save train and val loss/accuracy after each batch runthrough

# %%
# Load Data Set

# DATA_BATCH = '000_small_'
# DATA_SIZE = '48by32'
# DATA_SET = DATA_BATCH + DATA_SIZE
# NUM_CLASSES = 5

DATA_SET = 'subset_48by32_5'
NUM_CLASSES = 5
NUM_BATCHES = 6
USE_BATCH = [0, 1, 2]

print ('Data Set:', DATA_SET)
print ('Num classes:', NUM_CLASSES)
print ('Batches: {}'.format(USE_BATCH))
print ('Preparing Data Set....')

X = None
Y = None

for batch_num in USE_BATCH:
    X_input_filename = 'data_maps/' + DATA_SET + '/x_input_' + str(batch_num) + '.npy'
    Y_output_filename = 'data_maps/' + DATA_SET + '/y_labels_' + str(batch_num) + '.npy'

    X_batch = data_utils.load_npy_file(X_input_filename)
    Y_batch = data_utils.load_npy_file(Y_output_filename)
    
    if X is None:
        X = X_batch
    else:
        X = np.vstack((X, X_batch))
        
    if Y is None:
        Y = Y_batch
    else:
        Y = np.hstack((Y, Y_batch))  # use hstack because 1-d array is represented as a row vector internally
    
    
print 'X: {}'.format(X.shape)
print 'Y: {}'.format(Y.shape)
print 'Y sample ', Y[:10]

num_samples, H, W, C = X.shape

# swap C and H axes --> expected input
X = np.swapaxes(X, 1, 3)  # (num_samples, C, W, H)
X -= np.mean(X, axis = 0)  # Data Preprocessing: mean subtraction
X /= np.std(X, axis = 0)  # Normalization

#Splitting into train, val, test sets

num_train = int(num_samples * 0.8)
num_val = int(num_samples * 0.1)
num_test = num_samples - num_train - num_val

# print 'num_train: %d, num_val: %d, num_test: %d' % (num_train, num_val, num_test)

X_train = X[:num_train]
X_val = X[num_train:num_train+num_val]
X_test = X[num_train+num_val:]

y_train = Y[:num_train]
y_val = Y[num_train:num_train+num_val]
y_test = Y[num_train+num_val:]

print ('X_train', X_train.shape)
print ('y_train', y_train.shape)
print ('X_val', X_val.shape)
print ('y_val', y_val.shape)
print ('X_test', X_test.shape)
print ('y_test', y_test.shape)
# Out:
# ('Data Set:', 'subset_48by32_5')
# ('Num classes:', 5)
# Batches: [0, 1, 2]
# Preparing Data Set....
# X: (90000, 32, 48, 3)
# Y: (90000,)
# Y sample  [0 1 2 1 0 3 2 2 1 2]
# ('X_train', (72000, 3, 48, 32))
# ('y_train', (72000,))
# ('X_val', (9000, 3, 48, 32))
# ('y_val', (9000,))
# ('X_test', (9000, 3, 48, 32))
# ('y_test', (9000,))

# %%
# Create model and compile train and val functions
train_fn, val_fn = cnn_model.main_create_model(C, W, H, NUM_CLASSES, cnn_architecture=cnn_architecture, num_filters=num_filters, filter_width=filter_width, pool_width=pool_width, stride=stride_width, pad=padding, hidden_size=hidden_size, dropout=dropout_p, use_optimizer=USE_OPTIMIZER, learning_rate=LEARNING_RATE, momentum=MOMENTUM, beta1=beta1, beta2=beta2, epsilon=epsilon)
# Out:
# Building network...
# Building a complex CNN...
# Compiling functions...
# Compiling Finished!

# %%
# Train the model.
train_err_list, train_acc_list, val_err_list, val_acc_list, epochs_train_err_list, epochs_train_acc_list, epochs_val_err_list, epochs_val_acc_list = cnn_model.train(num_epochs, batchsize, num_train, num_val, USE_OPTIMIZER, train_fn, val_fn, X_train, y_train, record_per_iter=record_per_iter)
# Out:
# Training on: 3 epochs of batch size 500 with num training samples 72000
# Validation Size: 9000
# Starting training...
# Ep 0 	iter 0  	loss 1.63537, train acc 20.00, val acc 25.60
# Ep 0 	iter 1  	loss 1.63000, train acc 20.80, val acc 22.40
# Ep 0 	iter 2  	loss 1.61996, train acc 22.00, val acc 24.80
# Ep 0 	iter 3  	loss 1.61148, train acc 23.00, val acc 27.00
# Ep 0 	iter 4  	loss 1.59327, train acc 26.80, val acc 30.60
# Ep 0 	iter 5  	loss 1.61232, train acc 22.40, val acc 25.60
# Ep 0 	iter 6  	loss 1.60275, train acc 21.00, val acc 25.80
# Ep 0 	iter 7  	loss 1.60363, train acc 24.80, val acc 25.40
# Ep 0 	iter 8  	loss 1.64171, train acc 20.00, val acc 21.80
# Ep 0 	iter 9  	loss 1.61330, train acc 21.40, val acc 23.20
# Ep 0 	iter 10  	loss 1.60592, train acc 21.40, val acc 24.40
# Ep 0 	iter 11  	loss 1.62444, train acc 20.20, val acc 23.00
# Ep 0 	iter 12  	loss 1.60911, train acc 22.60, val acc 25.80
# Ep 0 	iter 13  	loss 1.62226, train acc 21.60, val acc 24.80
# Ep 0 	iter 14  	loss 1.61884, train acc 22.60, val acc 24.60
# Ep 0 	iter 15  	loss 1.60766, train acc 23.20, val acc 24.80
# Ep 0 	iter 16  	loss 1.60401, train acc 23.40, val acc 23.40
# Ep 0 	iter 17  	loss 1.60567, train acc 23.60, val acc 23.80
# Ep 0 	iter 18  	loss 1.58702, train acc 24.60, val acc 29.20
# Ep 0 	iter 19  	loss 1.62400, train acc 22.20, val acc 24.20
# Ep 0 	iter 20  	loss 1.60542, train acc 21.20, val acc 23.80
# Ep 0 	iter 21  	loss 1.60280, train acc 24.60, val acc 26.80
# Ep 0 	iter 22  	loss 1.60232, train acc 24.20, val acc 26.80
# Ep 0 	iter 23  	loss 1.61356, train acc 22.40, val acc 22.80
# Ep 0 	iter 24  	loss 1.61008, train acc 24.00, val acc 22.80
# Ep 0 	iter 25  	loss 1.61302, train acc 21.60, val acc 23.60
# Ep 0 	iter 26  	loss 1.61672, train acc 19.80, val acc 23.20
# Ep 0 	iter 27  	loss 1.60951, train acc 22.80, val acc 25.80
# Ep 0 	iter 28  	loss 1.61173, train acc 19.40, val acc 29.60
# Ep 0 	iter 29  	loss 1.60733, train acc 20.00, val acc 22.00
# Ep 0 	iter 30  	loss 1.59975, train acc 24.20, val acc 25.00
# Ep 0 	iter 31  	loss 1.61833, train acc 22.60, val acc 24.20
# Ep 0 	iter 32  	loss 1.59309, train acc 26.00, val acc 28.20
# Ep 0 	iter 33  	loss 1.60598, train acc 23.80, val acc 23.60
# Ep 0 	iter 34  	loss 1.58842, train acc 30.20, val acc 29.40
# Ep 0 	iter 35  	loss 1.60105, train acc 24.80, val acc 24.80
# Ep 0 	iter 36  	loss 1.60050, train acc 24.20, val acc 24.40
# Ep 0 	iter 37  	loss 1.60622, train acc 22.20, val acc 23.20
# Ep 0 	iter 38  	loss 1.60872, train acc 25.00, val acc 26.20
# Ep 0 	iter 39  	loss 1.60064, train acc 24.80, val acc 26.00
# Ep 0 	iter 40  	loss 1.60320, train acc 24.40, val acc 25.80
# Ep 0 	iter 41  	loss 1.59541, train acc 26.80, val acc 27.60
# Ep 0 	iter 42  	loss 1.61087, train acc 25.40, val acc 25.80
# Ep 0 	iter 43  	loss 1.61351, train acc 22.00, val acc 23.80
# Ep 0 	iter 44  	loss 1.60553, train acc 24.20, val acc 25.60
# Ep 0 	iter 45  	loss 1.59915, train acc 24.40, val acc 25.20
# Ep 0 	iter 46  	loss 1.59964, train acc 24.80, val acc 25.80
# Ep 0 	iter 47  	loss 1.60701, train acc 20.60, val acc 21.80
# Ep 0 	iter 48  	loss 1.60279, train acc 25.00, val acc 25.00
# Ep 0 	iter 49  	loss 1.59262, train acc 23.60, val acc 25.00
# Ep 0 	iter 50  	loss 1.59692, train acc 25.60, val acc 26.80
# Ep 0 	iter 51  	loss 1.60672, train acc 22.80, val acc 23.80
# Ep 0 	iter 52  	loss 1.59659, train acc 26.40, val acc 27.20
# Ep 0 	iter 53  	loss 1.60048, train acc 23.20, val acc 24.80
# Ep 0 	iter 54  	loss 1.59967, train acc 24.60, val acc 23.00
# Ep 0 	iter 55  	loss 1.59934, train acc 21.80, val acc 22.40
# Ep 0 	iter 56  	loss 1.59609, train acc 21.20, val acc 22.60
# Ep 0 	iter 57  	loss 1.59058, train acc 24.80, val acc 25.40
# Ep 0 	iter 58  	loss 1.59823, train acc 22.20, val acc 24.80
# Ep 0 	iter 59  	loss 1.60166, train acc 25.20, val acc 25.80
# Ep 0 	iter 60  	loss 1.61118, train acc 21.20, val acc 22.60
# Ep 0 	iter 61  	loss 1.60637, train acc 21.80, val acc 24.40
# Ep 0 	iter 62  	loss 1.58500, train acc 25.00, val acc 26.80
# Ep 0 	iter 63  	loss 1.58895, train acc 25.60, val acc 27.00
# Ep 0 	iter 64  	loss 1.58305, train acc 27.40, val acc 28.00
# Ep 0 	iter 65  	loss 1.59875, train acc 25.80, val acc 25.80
# Ep 0 	iter 66  	loss 1.60726, train acc 23.00, val acc 22.80
# Ep 0 	iter 67  	loss 1.58925, train acc 26.60, val acc 27.20
# Ep 0 	iter 68  	loss 1.60655, train acc 24.00, val acc 24.80
# Ep 0 	iter 69  	loss 1.59761, train acc 23.60, val acc 24.80
# Ep 0 	iter 70  	loss 1.60897, train acc 20.40, val acc 19.20
# Ep 0 	iter 71  	loss 1.59863, train acc 24.20, val acc 23.80
# Ep 0 	iter 72  	loss 1.59743, train acc 22.80, val acc 22.40
# Ep 0 	iter 73  	loss 1.58192, train acc 24.60, val acc 25.60
# Ep 0 	iter 74  	loss 1.59622, train acc 22.00, val acc 24.60
# Ep 0 	iter 75  	loss 1.60273, train acc 19.80, val acc 23.60
# Ep 0 	iter 76  	loss 1.61034, train acc 22.40, val acc 23.00
# Ep 0 	iter 77  	loss 1.59326, train acc 23.60, val acc 25.20
# Ep 0 	iter 78  	loss 1.58219, train acc 26.20, val acc 29.00
# Ep 0 	iter 79  	loss 1.59982, train acc 24.00, val acc 24.80
# Ep 0 	iter 80  	loss 1.60146, train acc 24.20, val acc 23.40
# Ep 0 	iter 81  	loss 1.58742, train acc 26.00, val acc 26.40
# Ep 0 	iter 82  	loss 1.58852, train acc 26.40, val acc 27.00
# Ep 0 	iter 83  	loss 1.61100, train acc 25.00, val acc 25.40
# Ep 0 	iter 84  	loss 1.59657, train acc 24.80, val acc 25.80
# Ep 0 	iter 85  	loss 1.57730, train acc 29.40, val acc 29.00
# Ep 0 	iter 86  	loss 1.61156, train acc 23.40, val acc 22.80
# Ep 0 	iter 87  	loss 1.59719, train acc 27.20, val acc 28.00
# Ep 0 	iter 88  	loss 1.59027, train acc 26.20, val acc 26.60
# Ep 0 	iter 89  	loss 1.59397, train acc 24.20, val acc 26.20
# Ep 0 	iter 90  	loss 1.59463, train acc 25.60, val acc 25.80
# Ep 0 	iter 91  	loss 1.60722, train acc 22.20, val acc 23.00
# Ep 0 	iter 92  	loss 1.59922, train acc 22.80, val acc 23.20
# Ep 0 	iter 93  	loss 1.59695, train acc 23.60, val acc 25.60
# Ep 0 	iter 94  	loss 1.60110, train acc 21.40, val acc 21.40
# Ep 0 	iter 95  	loss 1.59133, train acc 24.60, val acc 26.20
# Ep 0 	iter 96  	loss 1.60185, train acc 25.40, val acc 26.00
# Ep 0 	iter 97  	loss 1.58945, train acc 28.00, val acc 28.00
# Ep 0 	iter 98  	loss 1.59436, train acc 24.60, val acc 25.60
# Ep 0 	iter 99  	loss 1.59295, train acc 25.60, val acc 26.80
# Ep 0 	iter 100  	loss 1.59082, train acc 25.20, val acc 25.80
# Ep 0 	iter 101  	loss 1.61444, train acc 22.40, val acc 23.00
# Ep 0 	iter 102  	loss 1.61149, train acc 24.20, val acc 24.00
# Ep 0 	iter 103  	loss 1.59330, train acc 26.60, val acc 26.80
# Ep 0 	iter 104  	loss 1.60522, train acc 22.80, val acc 25.60
# Ep 0 	iter 105  	loss 1.59364, train acc 23.60, val acc 23.20
# Ep 0 	iter 106  	loss 1.60177, train acc 25.80, val acc 26.20
# Ep 0 	iter 107  	loss 1.58873, train acc 24.20, val acc 24.80
# Ep 0 	iter 108  	loss 1.60026, train acc 22.20, val acc 21.60
# Ep 0 	iter 109  	loss 1.59237, train acc 23.00, val acc 24.00
# Ep 0 	iter 110  	loss 1.58209, train acc 24.80, val acc 26.60
# Ep 0 	iter 111  	loss 1.58577, train acc 25.80, val acc 28.20
# Ep 0 	iter 112  	loss 1.58313, train acc 26.00, val acc 26.20
# Ep 0 	iter 113  	loss 1.60140, train acc 26.20, val acc 25.20
# Ep 0 	iter 114  	loss 1.60683, train acc 25.60, val acc 26.20
# Ep 0 	iter 115  	loss 1.58950, train acc 24.60, val acc 26.60
# Ep 0 	iter 116  	loss 1.59609, train acc 24.20, val acc 23.60
# Ep 0 	iter 117  	loss 1.59923, train acc 26.40, val acc 26.60
# Ep 0 	iter 118  	loss 1.59756, train acc 25.60, val acc 24.20
# Ep 0 	iter 119  	loss 1.60515, train acc 23.80, val acc 23.40
# Ep 0 	iter 120  	loss 1.61839, train acc 20.20, val acc 21.20
# Ep 0 	iter 121  	loss 1.58678, train acc 24.80, val acc 26.80
# Ep 0 	iter 122  	loss 1.60669, train acc 21.80, val acc 22.40
# Ep 0 	iter 123  	loss 1.59674, train acc 24.20, val acc 25.60
# Ep 0 	iter 124  	loss 1.59238, train acc 28.20, val acc 28.60
# Ep 0 	iter 125  	loss 1.60296, train acc 21.60, val acc 21.80
# Ep 0 	iter 126  	loss 1.60020, train acc 23.40, val acc 24.60
# Ep 0 	iter 127  	loss 1.61036, train acc 22.00, val acc 25.20
# Ep 0 	iter 128  	loss 1.59515, train acc 26.40, val acc 25.40
# Ep 0 	iter 129  	loss 1.60013, train acc 24.80, val acc 25.40
# Ep 0 	iter 130  	loss 1.60661, train acc 24.00, val acc 24.20
# Ep 0 	iter 131  	loss 1.59589, train acc 26.00, val acc 25.60
# Ep 0 	iter 132  	loss 1.60261, train acc 23.20, val acc 23.20
# Ep 0 	iter 133  	loss 1.58575, train acc 29.00, val acc 29.60
# Ep 0 	iter 134  	loss 1.59749, train acc 26.20, val acc 27.20
# Ep 0 	iter 135  	loss 1.59103, train acc 26.00, val acc 26.80
# Ep 0 	iter 136  	loss 1.59965, train acc 26.40, val acc 26.40
# Ep 0 	iter 137  	loss 1.59926, train acc 28.00, val acc 28.20
# Ep 0 	iter 138  	loss 1.58570, train acc 26.00, val acc 25.60
# Ep 0 	iter 139  	loss 1.59171, train acc 23.00, val acc 23.60
# Ep 0 	iter 140  	loss 1.61127, train acc 24.00, val acc 24.00
# Ep 0 	iter 141  	loss 1.58538, train acc 25.60, val acc 25.80
# Ep 0 	iter 142  	loss 1.60226, train acc 25.60, val acc 26.00
# Ep 0 	iter 143  	loss 1.58372, train acc 26.00, val acc 26.60
# Epoch 1 of 3 took 1392.817s
#   training loss:		1.601115
#   training accuracy:		24.02 %
#   validation loss:		1.580433
#   validation accuracy:		26.60 %
# Ep 1 	iter 0  	loss 1.59344, train acc 25.80, val acc 27.40
# Ep 1 	iter 1  	loss 1.59670, train acc 24.20, val acc 26.00
# Ep 1 	iter 2  	loss 1.58295, train acc 29.60, val acc 29.60
# Ep 1 	iter 3  	loss 1.59912, train acc 21.00, val acc 25.20
# Ep 1 	iter 4  	loss 1.58939, train acc 25.40, val acc 26.40
# Ep 1 	iter 5  	loss 1.58675, train acc 25.80, val acc 27.00
# Ep 1 	iter 6  	loss 1.58573, train acc 27.80, val acc 27.60
# Ep 1 	iter 7  	loss 1.58068, train acc 27.60, val acc 28.80
# Ep 1 	iter 8  	loss 1.59316, train acc 23.00, val acc 25.20
# Ep 1 	iter 9  	loss 1.59328, train acc 24.20, val acc 24.60
# Ep 1 	iter 10  	loss 1.57998, train acc 26.80, val acc 28.20
# Ep 1 	iter 11  	loss 1.58010, train acc 26.80, val acc 27.20
# Ep 1 	iter 12  	loss 1.58882, train acc 26.40, val acc 27.00
# Ep 1 	iter 13  	loss 1.59102, train acc 27.20, val acc 27.80
# Ep 1 	iter 14  	loss 1.57000, train acc 28.40, val acc 29.20
# Ep 1 	iter 15  	loss 1.58100, train acc 26.80, val acc 27.00
# Ep 1 	iter 16  	loss 1.58688, train acc 26.00, val acc 26.00
# Ep 1 	iter 17  	loss 1.59645, train acc 25.80, val acc 25.00
# Ep 1 	iter 18  	loss 1.60125, train acc 22.80, val acc 23.40
# Ep 1 	iter 19  	loss 1.60355, train acc 24.00, val acc 23.60
# Ep 1 	iter 20  	loss 1.59767, train acc 25.60, val acc 25.80
# Ep 1 	iter 21  	loss 1.60263, train acc 22.20, val acc 24.80
# Ep 1 	iter 22  	loss 1.59554, train acc 24.60, val acc 27.60
# Ep 1 	iter 23  	loss 1.59426, train acc 23.40, val acc 23.60
# Ep 1 	iter 24  	loss 1.59179, train acc 24.40, val acc 26.20
# Ep 1 	iter 25  	loss 1.59221, train acc 26.20, val acc 26.20
# Ep 1 	iter 26  	loss 1.60410, train acc 23.40, val acc 24.00
# Ep 1 	iter 27  	loss 1.58512, train acc 24.60, val acc 25.80
# Ep 1 	iter 28  	loss 1.58687, train acc 25.00, val acc 25.20
# Ep 1 	iter 29  	loss 1.58639, train acc 26.00, val acc 26.60
# Ep 1 	iter 30  	loss 1.59090, train acc 25.20, val acc 25.80
# Ep 1 	iter 31  	loss 1.59005, train acc 26.40, val acc 27.80
# Ep 1 	iter 32  	loss 1.59284, train acc 24.40, val acc 25.60
# Ep 1 	iter 33  	loss 1.58591, train acc 23.20, val acc 25.60
# Ep 1 	iter 34  	loss 1.58910, train acc 26.60, val acc 26.20
# Ep 1 	iter 35  	loss 1.59029, train acc 24.00, val acc 24.00
# Ep 1 	iter 36  	loss 1.59331, train acc 22.80, val acc 24.00
# Ep 1 	iter 37  	loss 1.57875, train acc 28.60, val acc 29.00
# Ep 1 	iter 38  	loss 1.57480, train acc 28.60, val acc 27.80
# Ep 1 	iter 39  	loss 1.58820, train acc 27.60, val acc 27.60
# Ep 1 	iter 40  	loss 1.57203, train acc 28.00, val acc 27.80
# Ep 1 	iter 41  	loss 1.58802, train acc 24.60, val acc 25.80
# Ep 1 	iter 42  	loss 1.57026, train acc 28.40, val acc 28.00
# Ep 1 	iter 43  	loss 1.59841, train acc 22.40, val acc 22.80
# Ep 1 	iter 44  	loss 1.60159, train acc 21.40, val acc 22.60
# Ep 1 	iter 45  	loss 1.59093, train acc 25.20, val acc 25.80
# Ep 1 	iter 46  	loss 1.58221, train acc 27.40, val acc 27.20
# Ep 1 	iter 47  	loss 1.57927, train acc 26.00, val acc 27.00
# Ep 1 	iter 48  	loss 1.58933, train acc 24.60, val acc 27.00
# Ep 1 	iter 49  	loss 1.59511, train acc 21.40, val acc 23.60
# Ep 1 	iter 50  	loss 1.58908, train acc 24.40, val acc 26.20
# Ep 1 	iter 51  	loss 1.59460, train acc 23.60, val acc 23.20
# Ep 1 	iter 52  	loss 1.59027, train acc 24.20, val acc 26.40
# Ep 1 	iter 53  	loss 1.57250, train acc 30.40, val acc 31.60
# Ep 1 	iter 54  	loss 1.59263, train acc 23.00, val acc 24.80
# Ep 1 	iter 55  	loss 1.59425, train acc 22.00, val acc 23.40
# Ep 1 	iter 56  	loss 1.58386, train acc 26.80, val acc 27.40
# Ep 1 	iter 57  	loss 1.57654, train acc 25.00, val acc 27.60
# Ep 1 	iter 58  	loss 1.59558, train acc 24.00, val acc 24.20
# Ep 1 	iter 59  	loss 1.57256, train acc 25.80, val acc 26.80
# Ep 1 	iter 60  	loss 1.58880, train acc 26.80, val acc 27.40
# Ep 1 	iter 61  	loss 1.59441, train acc 27.20, val acc 28.40
# Ep 1 	iter 62  	loss 1.58540, train acc 27.40, val acc 27.60
# Ep 1 	iter 63  	loss 1.58591, train acc 26.60, val acc 26.40
# Ep 1 	iter 64  	loss 1.58847, train acc 24.00, val acc 24.40
# Ep 1 	iter 65  	loss 1.59751, train acc 23.60, val acc 24.00
# Ep 1 	iter 66  	loss 1.58971, train acc 26.80, val acc 28.00
# Ep 1 	iter 67  	loss 1.58384, train acc 26.60, val acc 26.60
# Ep 1 	iter 68  	loss 1.59736, train acc 23.60, val acc 23.40
# Ep 1 	iter 69  	loss 1.56989, train acc 27.60, val acc 28.20
# Ep 1 	iter 70  	loss 1.60395, train acc 20.20, val acc 22.20
# Ep 1 	iter 71  	loss 1.57935, train acc 26.40, val acc 28.20
# Ep 1 	iter 72  	loss 1.60768, train acc 25.00, val acc 27.00
# Ep 1 	iter 73  	loss 1.59323, train acc 24.40, val acc 25.00
# Ep 1 	iter 74  	loss 1.59740, train acc 23.80, val acc 26.20
# Ep 1 	iter 75  	loss 1.59488, train acc 27.20, val acc 27.60
# Ep 1 	iter 76  	loss 1.58430, train acc 28.40, val acc 28.80
# Ep 1 	iter 77  	loss 1.58751, train acc 25.00, val acc 25.80
# Ep 1 	iter 78  	loss 1.58102, train acc 26.60, val acc 26.80
# Ep 1 	iter 79  	loss 1.57937, train acc 26.00, val acc 26.20
# Ep 1 	iter 80  	loss 1.58452, train acc 26.40, val acc 26.60
# Ep 1 	iter 81  	loss 1.59261, train acc 23.20, val acc 24.80
# Ep 1 	iter 82  	loss 1.58773, train acc 22.80, val acc 23.00
# Ep 1 	iter 83  	loss 1.59744, train acc 25.60, val acc 25.20
# Ep 1 	iter 84  	loss 1.60068, train acc 24.60, val acc 24.40
# Ep 1 	iter 85  	loss 1.59569, train acc 27.80, val acc 29.00
# Ep 1 	iter 86  	loss 1.59562, train acc 30.80, val acc 30.60
# Ep 1 	iter 87  	loss 1.59327, train acc 26.40, val acc 27.40
# Ep 1 	iter 88  	loss 1.60089, train acc 25.00, val acc 27.60
# Ep 1 	iter 89  	loss 1.58152, train acc 27.20, val acc 28.40
# Ep 1 	iter 90  	loss 1.59553, train acc 25.20, val acc 24.60
# Ep 1 	iter 91  	loss 1.61447, train acc 22.60, val acc 24.00
# Ep 1 	iter 92  	loss 1.60151, train acc 22.20, val acc 24.20
# Ep 1 	iter 93  	loss 1.58696, train acc 24.60, val acc 25.40
# Ep 1 	iter 94  	loss 1.57915, train acc 30.20, val acc 31.40
# Ep 1 	iter 95  	loss 1.58642, train acc 25.40, val acc 26.60
# Ep 1 	iter 96  	loss 1.59427, train acc 22.80, val acc 25.20
# Ep 1 	iter 97  	loss 1.58841, train acc 24.20, val acc 25.80
# Ep 1 	iter 98  	loss 1.59058, train acc 23.80, val acc 25.00
# Ep 1 	iter 99  	loss 1.58655, train acc 24.80, val acc 25.00
# Ep 1 	iter 100  	loss 1.58347, train acc 29.60, val acc 30.00
# Ep 1 	iter 101  	loss 1.57799, train acc 24.40, val acc 23.60
# Ep 1 	iter 102  	loss 1.59222, train acc 27.40, val acc 27.60
# Ep 1 	iter 103  	loss 1.59520, train acc 26.40, val acc 25.60
# Ep 1 	iter 104  	loss 1.58439, train acc 25.00, val acc 25.40
# Ep 1 	iter 105  	loss 1.55688, train acc 32.80, val acc 32.80
# Ep 1 	iter 106  	loss 1.57914, train acc 26.00, val acc 26.20
# Ep 1 	iter 107  	loss 1.56952, train acc 27.00, val acc 28.20
# Ep 1 	iter 108  	loss 1.57837, train acc 26.40, val acc 26.60
# Ep 1 	iter 109  	loss 1.58809, train acc 27.40, val acc 28.00
# Ep 1 	iter 110  	loss 1.58195, train acc 25.00, val acc 26.80
# Ep 1 	iter 111  	loss 1.57585, train acc 25.40, val acc 26.20
# Ep 1 	iter 112  	loss 1.58152, train acc 25.60, val acc 26.60
# Ep 1 	iter 113  	loss 1.58540, train acc 26.40, val acc 26.40
# Ep 1 	iter 114  	loss 1.58575, train acc 25.20, val acc 26.20
# Ep 1 	iter 115  	loss 1.58808, train acc 24.60, val acc 25.00
# Ep 1 	iter 116  	loss 1.60046, train acc 27.60, val acc 28.00
# Ep 1 	iter 117  	loss 1.58536, train acc 26.00, val acc 27.80
# Ep 1 	iter 118  	loss 1.57839, train acc 25.20, val acc 25.80
# Ep 1 	iter 119  	loss 1.59494, train acc 25.00, val acc 26.80
# Ep 1 	iter 120  	loss 1.58609, train acc 26.20, val acc 26.60
# Ep 1 	iter 121  	loss 1.58175, train acc 24.20, val acc 24.20
# Ep 1 	iter 122  	loss 1.58772, train acc 26.00, val acc 26.40
# Ep 1 	iter 123  	loss 1.58795, train acc 24.60, val acc 25.40
# Ep 1 	iter 124  	loss 1.57715, train acc 28.60, val acc 30.40
# Ep 1 	iter 125  	loss 1.58790, train acc 26.60, val acc 28.20
# Ep 1 	iter 126  	loss 1.58328, train acc 24.40, val acc 27.20
# Ep 1 	iter 127  	loss 1.58639, train acc 25.60, val acc 27.80
# Ep 1 	iter 128  	loss 1.58872, train acc 22.60, val acc 23.40
# Ep 1 	iter 129  	loss 1.57976, train acc 25.20, val acc 27.20
# Ep 1 	iter 130  	loss 1.57740, train acc 29.20, val acc 28.80
# Ep 1 	iter 131  	loss 1.59921, train acc 21.80, val acc 23.20
# Ep 1 	iter 132  	loss 1.59341, train acc 23.00, val acc 23.60
# Ep 1 	iter 133  	loss 1.57939, train acc 25.20, val acc 26.60
# Ep 1 	iter 134  	loss 1.59471, train acc 25.20, val acc 26.40
# Ep 1 	iter 135  	loss 1.58462, train acc 25.60, val acc 26.60
# Ep 1 	iter 136  	loss 1.58067, train acc 26.40, val acc 27.20
# Ep 1 	iter 137  	loss 1.58839, train acc 24.80, val acc 26.60
# Ep 1 	iter 138  	loss 1.58188, train acc 27.00, val acc 28.00
# Ep 1 	iter 139  	loss 1.59522, train acc 25.80, val acc 26.80
# Ep 1 	iter 140  	loss 1.58223, train acc 26.40, val acc 25.60
# Ep 1 	iter 141  	loss 1.57975, train acc 28.40, val acc 29.20
# Ep 1 	iter 142  	loss 1.59960, train acc 24.60, val acc 24.80
# Ep 1 	iter 143  	loss 1.58142, train acc 25.00, val acc 26.20
# Epoch 2 of 3 took 1449.375s
#   training loss:		1.588135
#   training accuracy:		25.53 %
#   validation loss:		1.574506
#   validation accuracy:		26.20 %
# Ep 2 	iter 0  	loss 1.56500, train acc 29.40, val acc 28.80
# Ep 2 	iter 1  	loss 1.57540, train acc 24.00, val acc 25.20
# Ep 2 	iter 2  	loss 1.58858, train acc 24.60, val acc 26.20
# Ep 2 	iter 3  	loss 1.57373, train acc 28.60, val acc 28.80
# Ep 2 	iter 4  	loss 1.59902, train acc 27.00, val acc 28.60
# Ep 2 	iter 5  	loss 1.59786, train acc 26.80, val acc 27.00
# Ep 2 	iter 6  	loss 1.56658, train acc 28.60, val acc 31.80
# Ep 2 	iter 7  	loss 1.57509, train acc 26.80, val acc 27.20
# Ep 2 	iter 8  	loss 1.56558, train acc 31.20, val acc 33.00
# Ep 2 	iter 9  	loss 1.58600, train acc 25.20, val acc 26.00
# Ep 2 	iter 10  	loss 1.58388, train acc 26.00, val acc 27.00
# Ep 2 	iter 11  	loss 1.56961, train acc 28.80, val acc 30.60
# Ep 2 	iter 12  	loss 1.57726, train acc 28.00, val acc 29.80
# Ep 2 	iter 13  	loss 1.56646, train acc 30.80, val acc 32.20
# Ep 2 	iter 14  	loss 1.58186, train acc 23.20, val acc 24.00
# Ep 2 	iter 15  	loss 1.56859, train acc 29.20, val acc 30.00
# Ep 2 	iter 16  	loss 1.58817, train acc 25.20, val acc 26.60
# Ep 2 	iter 17  	loss 1.56818, train acc 27.00, val acc 28.80
# Ep 2 	iter 18  	loss 1.57712, train acc 29.00, val acc 30.80
# Ep 2 	iter 19  	loss 1.60967, train acc 23.20, val acc 22.60
# Ep 2 	iter 20  	loss 1.56900, train acc 30.40, val acc 32.20
# Ep 2 	iter 21  	loss 1.57948, train acc 27.00, val acc 27.60
# Ep 2 	iter 22  	loss 1.57003, train acc 27.60, val acc 29.20
# Ep 2 	iter 23  	loss 1.57553, train acc 27.40, val acc 29.20
# Ep 2 	iter 24  	loss 1.58354, train acc 28.80, val acc 29.40
# Ep 2 	iter 25  	loss 1.57320, train acc 27.60, val acc 28.80
# Ep 2 	iter 26  	loss 1.57999, train acc 24.80, val acc 26.20
# Ep 2 	iter 27  	loss 1.57173, train acc 26.80, val acc 27.80
# Ep 2 	iter 28  	loss 1.57716, train acc 25.60, val acc 28.80
# Ep 2 	iter 29  	loss 1.57019, train acc 30.40, val acc 28.40
# Ep 2 	iter 30  	loss 1.58180, train acc 26.00, val acc 26.40
# Ep 2 	iter 31  	loss 1.56193, train acc 28.20, val acc 29.20
# Ep 2 	iter 32  	loss 1.57818, train acc 26.40, val acc 28.40
# Ep 2 	iter 33  	loss 1.57288, train acc 27.40, val acc 27.80
# Ep 2 	iter 34  	loss 1.57012, train acc 29.40, val acc 29.60
# Ep 2 	iter 35  	loss 1.59020, train acc 23.60, val acc 25.60
# Ep 2 	iter 36  	loss 1.57167, train acc 28.40, val acc 30.00
# Ep 2 	iter 37  	loss 1.59070, train acc 24.60, val acc 27.60
# Ep 2 	iter 38  	loss 1.57569, train acc 25.00, val acc 25.80
# Ep 2 	iter 39  	loss 1.58418, train acc 24.20, val acc 25.60
# Ep 2 	iter 40  	loss 1.59003, train acc 24.20, val acc 26.20
# Ep 2 	iter 41  	loss 1.58402, train acc 24.80, val acc 24.20
# Ep 2 	iter 42  	loss 1.57774, train acc 26.20, val acc 27.60
# Ep 2 	iter 43  	loss 1.58604, train acc 26.40, val acc 27.00
# Ep 2 	iter 44  	loss 1.56152, train acc 28.80, val acc 29.00
# Ep 2 	iter 45  	loss 1.59316, train acc 23.80, val acc 25.60
# Ep 2 	iter 46  	loss 1.57185, train acc 28.20, val acc 28.00
# Ep 2 	iter 47  	loss 1.58265, train acc 24.80, val acc 25.40
# Ep 2 	iter 48  	loss 1.57385, train acc 25.20, val acc 26.20
# Ep 2 	iter 49  	loss 1.59150, train acc 24.40, val acc 25.40
# Ep 2 	iter 50  	loss 1.59377, train acc 24.80, val acc 26.80
# Ep 2 	iter 51  	loss 1.58980, train acc 25.80, val acc 26.40
# Ep 2 	iter 52  	loss 1.58152, train acc 27.20, val acc 28.00
# Ep 2 	iter 53  	loss 1.58298, train acc 25.20, val acc 27.00
# Ep 2 	iter 54  	loss 1.58743, train acc 25.60, val acc 25.60
# Ep 2 	iter 55  	loss 1.59027, train acc 24.40, val acc 25.60
# Ep 2 	iter 56  	loss 1.58724, train acc 25.40, val acc 27.00
# Ep 2 	iter 57  	loss 1.58165, train acc 27.60, val acc 29.20
# Ep 2 	iter 58  	loss 1.58431, train acc 26.80, val acc 27.80
# Ep 2 	iter 59  	loss 1.57242, train acc 26.60, val acc 26.40
# Ep 2 	iter 60  	loss 1.58425, train acc 26.40, val acc 26.40
# Ep 2 	iter 61  	loss 1.55824, train acc 31.60, val acc 31.80
# Ep 2 	iter 62  	loss 1.58848, train acc 25.60, val acc 27.00
# Ep 2 	iter 63  	loss 1.59827, train acc 22.80, val acc 25.40
# Ep 2 	iter 64  	loss 1.58945, train acc 24.20, val acc 27.60
# Ep 2 	iter 65  	loss 1.57879, train acc 25.20, val acc 26.20
# Ep 2 	iter 66  	loss 1.56703, train acc 28.60, val acc 30.40
# Ep 2 	iter 67  	loss 1.57690, train acc 26.80, val acc 27.40
# Ep 2 	iter 68  	loss 1.57963, train acc 25.20, val acc 26.60
# Ep 2 	iter 69  	loss 1.57743, train acc 24.80, val acc 25.60
# Ep 2 	iter 70  	loss 1.58188, train acc 26.40, val acc 27.20
# Ep 2 	iter 71  	loss 1.56449, train acc 27.60, val acc 28.80
# Ep 2 	iter 72  	loss 1.57603, train acc 25.80, val acc 26.40
# Ep 2 	iter 73  	loss 1.58528, train acc 26.20, val acc 27.00
# Ep 2 	iter 74  	loss 1.57405, train acc 27.00, val acc 27.60
# Ep 2 	iter 75  	loss 1.58771, train acc 24.00, val acc 25.80
# Ep 2 	iter 76  	loss 1.57268, train acc 27.40, val acc 30.20
# Ep 2 	iter 77  	loss 1.57734, train acc 26.60, val acc 27.80
# Ep 2 	iter 78  	loss 1.60399, train acc 21.60, val acc 23.80
# Ep 2 	iter 79  	loss 1.59082, train acc 24.40, val acc 25.00
# Ep 2 	iter 80  	loss 1.58983, train acc 25.80, val acc 28.60
# Ep 2 	iter 81  	loss 1.56762, train acc 28.20, val acc 29.80
# Ep 2 	iter 82  	loss 1.58975, train acc 24.20, val acc 24.80
# Ep 2 	iter 83  	loss 1.56463, train acc 26.80, val acc 27.00
# Ep 2 	iter 84  	loss 1.57600, train acc 27.60, val acc 29.40
# Ep 2 	iter 85  	loss 1.58229, train acc 29.80, val acc 29.60
# Ep 2 	iter 86  	loss 1.57977, train acc 26.80, val acc 27.60
# Ep 2 	iter 87  	loss 1.56965, train acc 25.20, val acc 26.20
# Ep 2 	iter 88  	loss 1.57971, train acc 27.20, val acc 27.80
# Ep 2 	iter 89  	loss 1.56727, train acc 27.80, val acc 28.60
# Ep 2 	iter 90  	loss 1.57892, train acc 25.40, val acc 25.60
# Ep 2 	iter 91  	loss 1.55774, train acc 30.20, val acc 31.40
# Ep 2 	iter 92  	loss 1.58021, train acc 29.20, val acc 29.80
# Ep 2 	iter 93  	loss 1.59134, train acc 23.00, val acc 26.00
# Ep 2 	iter 94  	loss 1.58447, train acc 26.00, val acc 28.20
# Ep 2 	iter 95  	loss 1.59200, train acc 24.80, val acc 26.20
# Ep 2 	iter 96  	loss 1.57901, train acc 28.80, val acc 30.00
# Ep 2 	iter 97  	loss 1.56945, train acc 27.60, val acc 28.60
# Ep 2 	iter 98  	loss 1.57402, train acc 27.40, val acc 28.00
# Ep 2 	iter 99  	loss 1.57457, train acc 25.60, val acc 26.40
# Ep 2 	iter 100  	loss 1.57488, train acc 29.20, val acc 30.80
# Ep 2 	iter 101  	loss 1.57406, train acc 26.80, val acc 28.40
# Ep 2 	iter 102  	loss 1.58763, train acc 24.20, val acc 25.80
# Ep 2 	iter 103  	loss 1.58619, train acc 26.00, val acc 26.80
# Ep 2 	iter 104  	loss 1.55615, train acc 29.40, val acc 29.80
# Ep 2 	iter 105  	loss 1.57870, train acc 24.00, val acc 24.80
# Ep 2 	iter 106  	loss 1.54799, train acc 31.00, val acc 31.20
# Ep 2 	iter 107  	loss 1.58834, train acc 26.80, val acc 28.00
# Ep 2 	iter 108  	loss 1.58726, train acc 27.00, val acc 27.20
# Ep 2 	iter 109  	loss 1.57466, train acc 28.40, val acc 29.20
# Ep 2 	iter 110  	loss 1.57660, train acc 28.00, val acc 29.80
# Ep 2 	iter 111  	loss 1.58477, train acc 28.80, val acc 28.60
# Ep 2 	iter 112  	loss 1.57268, train acc 30.00, val acc 29.80
# Ep 2 	iter 113  	loss 1.58136, train acc 27.80, val acc 27.80
# Ep 2 	iter 114  	loss 1.58986, train acc 24.40, val acc 25.00
# Ep 2 	iter 115  	loss 1.58694, train acc 26.60, val acc 29.00
# Ep 2 	iter 116  	loss 1.57875, train acc 27.80, val acc 28.60
# Ep 2 	iter 117  	loss 1.56434, train acc 33.40, val acc 34.60
# Ep 2 	iter 118  	loss 1.56247, train acc 27.00, val acc 27.00
# Ep 2 	iter 119  	loss 1.57473, train acc 29.00, val acc 29.60
# Ep 2 	iter 120  	loss 1.58614, train acc 25.80, val acc 25.60
# Ep 2 	iter 121  	loss 1.56765, train acc 29.20, val acc 30.00
# Ep 2 	iter 122  	loss 1.58448, train acc 27.00, val acc 27.60
# Ep 2 	iter 123  	loss 1.57831, train acc 25.20, val acc 24.60
# Ep 2 	iter 124  	loss 1.58690, train acc 23.80, val acc 26.60
# Ep 2 	iter 125  	loss 1.58478, train acc 26.80, val acc 29.00
# Ep 2 	iter 126  	loss 1.57406, train acc 25.80, val acc 27.80
# Ep 2 	iter 127  	loss 1.58066, train acc 25.60, val acc 26.20
# Ep 2 	iter 128  	loss 1.57115, train acc 29.60, val acc 30.40
# Ep 2 	iter 129  	loss 1.58805, train acc 26.60, val acc 27.80
# Ep 2 	iter 130  	loss 1.59218, train acc 25.00, val acc 26.80
# Ep 2 	iter 131  	loss 1.58151, train acc 27.20, val acc 27.80
# Ep 2 	iter 132  	loss 1.57654, train acc 28.00, val acc 29.40
# Ep 2 	iter 133  	loss 1.57825, train acc 26.20, val acc 27.40
# Ep 2 	iter 134  	loss 1.58488, train acc 26.80, val acc 27.80
# Ep 2 	iter 135  	loss 1.58569, train acc 23.20, val acc 24.00
# Ep 2 	iter 136  	loss 1.57482, train acc 25.00, val acc 26.80
# Ep 2 	iter 137  	loss 1.58530, train acc 25.40, val acc 26.60
# Ep 2 	iter 138  	loss 1.58225, train acc 28.00, val acc 28.20
# Ep 2 	iter 139  	loss 1.56639, train acc 28.60, val acc 29.00
# Ep 2 	iter 140  	loss 1.58684, train acc 23.40, val acc 25.80
# Ep 2 	iter 141  	loss 1.57345, train acc 28.00, val acc 29.20
# Ep 2 	iter 142  	loss 1.57313, train acc 27.60, val acc 28.80
# Ep 2 	iter 143  	loss 1.55487, train acc 31.60, val acc 30.80
# Epoch 3 of 3 took 1543.071s
#   training loss:		1.578904
#   training accuracy:		26.73 %
#   validation loss:		1.546296
#   validation accuracy:		30.80 %
# Training finished!

# %%
# After training, we compute and print the test error:
print ("Test Size: {}".format(num_test) )
print('Testing...')
test_err = 0
test_acc = 0
test_batches = 0
for batch in data_utils.iterate_minibatches(X_test, y_test, batchsize, shuffle=False):
    inputs, targets = batch
    err, acc = val_fn(inputs, targets)
    test_err += err
    test_acc += acc
    test_batches += 1
    
print("Final results:")
print("  test loss:\t\t\t{:.6f}".format(test_err / test_batches))
print("  test accuracy:\t\t{:.2f} %".format(
    test_acc / test_batches * 100))
# Out:
# Test Size: 9000
# Testing...
# Final results:
#   test loss:			1.595923
#   test accuracy:		24.74 %

# %%
# Visualize the loss and the accuracies for both training and validation sets for each epoch
num_train = X_train.shape[0]
if record_per_iter:
    xlabel = "iterations"
else:
    xlabel = "epochs"
# Printing training losses and training + validation accuracies
data_set_name = DATA_SET + 'batch'
for batch_num in USE_BATCH:
    data_set_name += "_"
    data_set_name += str(batch_num)
visualize.plot_loss_acc(data_set_name, train_err_list, train_acc_list, val_acc_list, LEARNING_RATE, reg_strength, num_epochs, num_train, xlabel=xlabel)

# %%
# Visualize the loss and the accuracies for both training and validation sets for each epoch
num_train = X_train.shape[0]
xlabel = "epochs"
# Printing training losses and training + validation accuracies
data_set_name = DATA_SET + 'batch_' + str(USE_BATCH) + '_on_epochs' + '_' + USE_OPTIMIZER
visualize.plot_loss_acc(data_set_name, epochs_train_err_list, epochs_train_acc_list, epochs_val_acc_list, LEARNING_RATE, reg_strength, num_epochs, num_train, xlabel=xlabel)
