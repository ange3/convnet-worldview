# %% [markdown]
# # Conv Net on Media Eval 2015 Placing Task - Locale

# %%
import numpy as np
import matplotlib.pyplot as plt
from cs231n.classifiers.cnn import *
# from cs231n.data_utils import get_CIFAR10_data
from cs231n.gradient_check import eval_numerical_gradient_array, eval_numerical_gradient
from cs231n.layers import *
from cs231n.fast_layers import *
from cs231n.solver import Solver

# import own modules
import data_utils

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
# DATA_SET = '000_small'
# DATA_SET = '000_small_50by30'

DATA_BATCH = '000_small_'
DATA_SIZE = '50by30'

DATA_SET = DATA_BATCH + DATA_SIZE

X_input_filename = 'data_maps/' + DATA_SET + '/x_input.npy'
Y_output_filename = 'data_maps/' + DATA_SET + '/y_labels.npy'

# %%
X = data_utils.load_npy_file(X_input_filename)
Y = data_utils.load_npy_file(Y_output_filename)
print 'X: {}'.format(X.shape)
print 'Y: {}'.format(Y.shape)
print 'Y sample ', Y[:10]
# Out:
# X: (1880, 30, 50, 3)
# Y: (1880,)
# Y sample  [0 1 1 2 3 2 4 1 0 2]

# %%
num_samples, H, W, C = X.shape

# swap C and H axes --> expected input
X = np.swapaxes(X, 1, 3)  # (num_samples, C, W, H)

NUM_CLASSES = 5

# %%
#Splitting into train, val, test sets

num_train = int(num_samples * 0.8)
num_val = int(num_samples * 0.1)
num_test = num_samples - num_train - num_val

print 'num_train: %d, num_val: %d, num_test: %d' % (num_train, num_val, num_test)

X_train = X[:num_train]
X_val = X[num_train:num_train+num_val]
X_test = X[num_train+num_val:]

Y_train = Y[:num_train]
Y_val = Y[num_train:num_train+num_val]
Y_test = Y[num_train+num_val:]

print 'X_train %s, X_val %s, X_test %s' % (X_train.shape, X_val.shape, X_test.shape)
print 'Y_train %s, Y_val %s, Y_test %s' % (Y_train.shape, Y_val.shape, Y_test.shape)
# Out:
# num_train: 1504, num_val: 188, num_test: 188
# X_train (1504, 3, 50, 30), X_val (188, 3, 50, 30), X_test (188, 3, 50, 30)
# Y_train (1504,), Y_val (188,), Y_test (188,)

# %% [markdown]
# ## Overfit Small Data

# %% [markdown]
# 1) Train model to overfit on subset of data

# %%
# Hyperparams
LEARN_RATE = 1e-4
WEIGHT_SCALE = 1e-2
NUM_EPOCHS = 20
BATCH_SIZE = 50
REGULARIZATION = 0.001

# %%
num_train = 100
small_data = {
  'X_train': X_train[:num_train],
  'y_train': Y_train[:num_train],
  'X_val': X_val[:num_train],
  'y_val': Y_val[:num_train],
}

model = ThreeLayerConvNet(input_dim = (C, W, H), num_classes = 5, weight_scale=WEIGHT_SCALE, reg=REGULARIZATION)

solver = Solver(model, small_data,
                num_epochs=NUM_EPOCHS, batch_size=BATCH_SIZE,
                update_rule='adam',
                optim_config={
                  'learning_rate': LEARN_RATE,
                },
                verbose=True, print_every=1)
solver.train()
# Out:
# (Iteration 1 / 40) loss: 2.126909
# (Epoch 0 / 20) train acc: 0.220000; val_acc: 0.210000
# (Iteration 2 / 40) loss: 5.031748
# (Epoch 1 / 20) train acc: 0.170000; val_acc: 0.240000
# (Iteration 3 / 40) loss: 3.096167
# (Iteration 4 / 40) loss: 2.420195
# (Epoch 2 / 20) train acc: 0.230000; val_acc: 0.230000
# (Iteration 5 / 40) loss: 1.856532
# (Iteration 6 / 40) loss: 1.653570
# (Epoch 3 / 20) train acc: 0.340000; val_acc: 0.250000
# (Iteration 7 / 40) loss: 1.659099
# (Iteration 8 / 40) loss: 1.614169
# (Epoch 4 / 20) train acc: 0.420000; val_acc: 0.250000
# (Iteration 9 / 40) loss: 1.641427
# (Iteration 10 / 40) loss: 1.626311
# (Epoch 5 / 20) train acc: 0.410000; val_acc: 0.270000
# (Iteration 11 / 40) loss: 1.553353
# (Iteration 12 / 40) loss: 1.587191
# (Epoch 6 / 20) train acc: 0.400000; val_acc: 0.230000
# (Iteration 13 / 40) loss: 1.523658
# (Iteration 14 / 40) loss: 1.455408
# (Epoch 7 / 20) train acc: 0.490000; val_acc: 0.210000
# (Iteration 15 / 40) loss: 1.491362
# (Iteration 16 / 40) loss: 1.362989
# (Epoch 8 / 20) train acc: 0.600000; val_acc: 0.280000
# (Iteration 17 / 40) loss: 1.309768
# (Iteration 18 / 40) loss: 1.246300
# (Epoch 9 / 20) train acc: 0.530000; val_acc: 0.240000
# (Iteration 19 / 40) loss: 1.141360
# (Iteration 20 / 40) loss: 1.186857
# (Epoch 10 / 20) train acc: 0.660000; val_acc: 0.210000
# (Iteration 21 / 40) loss: 1.025811
# (Iteration 22 / 40) loss: 1.105697
# (Epoch 11 / 20) train acc: 0.660000; val_acc: 0.210000
# (Iteration 23 / 40) loss: 1.086613
# (Iteration 24 / 40) loss: 0.923350
# (Epoch 12 / 20) train acc: 0.770000; val_acc: 0.230000
# (Iteration 25 / 40) loss: 0.919211
# (Iteration 26 / 40) loss: 0.780369
# (Epoch 13 / 20) train acc: 0.850000; val_acc: 0.240000
# (Iteration 27 / 40) loss: 0.709205
# (Iteration 28 / 40) loss: 0.765984
# (Epoch 14 / 20) train acc: 0.850000; val_acc: 0.280000
# (Iteration 29 / 40) loss: 0.626561
# (Iteration 30 / 40) loss: 0.635598
# (Epoch 15 / 20) train acc: 0.860000; val_acc: 0.230000
# (Iteration 31 / 40) loss: 0.551941
# (Iteration 32 / 40) loss: 0.463608
# (Epoch 16 / 20) train acc: 0.910000; val_acc: 0.200000
# (Iteration 33 / 40) loss: 0.493202
# (Iteration 34 / 40) loss: 0.439536
# (Epoch 17 / 20) train acc: 0.940000; val_acc: 0.220000
# (Iteration 35 / 40) loss: 0.284435
# (Iteration 36 / 40) loss: 0.387392
# (Epoch 18 / 20) train acc: 0.950000; val_acc: 0.220000
# (Iteration 37 / 40) loss: 0.373492
# (Iteration 38 / 40) loss: 0.322714
# (Epoch 19 / 20) train acc: 0.980000; val_acc: 0.200000
# (Iteration 39 / 40) loss: 0.279894
# (Iteration 40 / 40) loss: 0.246747
# (Epoch 20 / 20) train acc: 0.960000; val_acc: 0.210000

# %% [markdown]
# 2) Plot to show overfitting loss and accuracy

# %%
plt.plot(solver.loss_history, 'o')
plt.xlabel('iteration')
plt.ylabel('loss')
plt.title('Loss Graph: Overfitting Small Dataset (50 x 30 images)')

plt.show()

# %%
plt.plot(solver.train_acc_history, '-o')
plt.plot(solver.val_acc_history, '-o')
plt.legend(['train', 'val'], loc='upper left')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.title('Accuracy Graph: Overfitting Small Dataset (50 x 30 images)')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-9fb69a709f97> in <module>()
#       8 plt.show()
#       9
# ---> 10 fname = 'accuracy_graph_%s_lr_%d_weight_%d_epochs_%d_batch_%d' % (DATA_SIZE, LEARN_RATE, WEIGHT_SCALE, NUM_EPOCHS, BATCH_SIZE)
#      11 plt.savefig(fname)
#
# NameError: name 'LEARN_RATE' is not defined

# %% [markdown]
# ## Train on full dataset

# %% [markdown]
# Train

# %%
# Hyperparams
LEARN_RATE = 1e-4
WEIGHT_SCALE = 1e-2
NUM_EPOCHS = 10
BATCH_SIZE = 50
REGULARIZATION = 0.001

# %%
full_data = {
  'X_train': X_train,
  'y_train': Y_train,
  'X_val': X_val,
  'y_val': Y_val,
}

model = ThreeLayerConvNet(input_dim = (C, W, H), num_classes = 5, weight_scale=WEIGHT_SCALE, reg=REGULARIZATION)

solver = Solver(model, full_data,
                num_epochs=NUM_EPOCHS, batch_size=BATCH_SIZE,
                update_rule='adam',
                optim_config={
                  'learning_rate': LEARN_RATE,
                },
                verbose=True, print_every=1)
solver.train()
# Out:
# (Iteration 1 /