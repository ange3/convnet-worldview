# %% [markdown]
# # Lasagne Conv Net on Media Eval 2015 Placing Task - Locale

# %%
# Import Python libraries
import numpy as np
import theano
import theano.tensor as Tensor
import lasagne
import time

# allows plots to show inline in ipython notebook
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
# Import own modules
import data_utils, visualize
import lasagne_model_predict_country as cnn_model

# %%
# Model hyperparameters
cnn_architecture = "complex_cnn"
num_filters = 32
filter_width = 3 # can be integer or tuple
pool_width = 2 
stride_width = 1 # can be integer or tuple
padding = 'full'  # can be integer or tuple or 'full', 'same', 'valid'
hidden_size = 256 # size of hidden layer of neurons
dropout_p = 0.0
# lr_decay = 0.995
reg_strength = 0
# grad_clip = 10

# Optimization hyperparams
# LEARNING_RATE = 1e-2
LEARNING_RATE = 0.045

# USE_OPTIMIZER = "nesterov_momentum"
USE_OPTIMIZER = "adam"
# (1) Nesterov Momentum
MOMENTUM = 0.9
# (2) Adam
beta1=0.9
beta2=0.999
epsilon=1e-08
# Optimizer config
theano.config.optimizer='fast_compile'
theano.config.exception_verbosity='high'

# Training parameters
batchsize = 500
num_epochs = 20
record_per_iter = True  # save train and val loss/accuracy after each batch runthrough

# %%
# Load Data Set

# DATA_BATCH = '000_small_'
# DATA_SIZE = '48by32'
# DATA_SET = DATA_BATCH + DATA_SIZE
# NUM_CLASSES = 5

DATA_SET = 'subset_48by32_5'
NUM_CLASSES = 5
NUM_BATCHES = 6
USE_BATCH = 0

print ('Data Set:', DATA_SET)
print ('Num classes:', NUM_CLASSES)
print ('Batches: {}'.format(USE_BATCH))
print ('Preparing Data Set....')

X_input_filename = 'data_maps/' + DATA_SET + '/x_input_' + str(USE_BATCH) + '.npy'
Y_output_filename = 'data_maps/' + DATA_SET + '/y_labels_' + str(USE_BATCH) + '.npy'

X = data_utils.load_npy_file(X_input_filename)
Y = data_utils.load_npy_file(Y_output_filename)
# print 'X: {}'.format(X.shape)
# print 'Y: {}'.format(Y.shape)
# print 'Y sample ', Y[:10]

num_samples, H, W, C = X.shape

# swap C and H axes --> expected input
X = np.swapaxes(X, 1, 3)  # (num_samples, C, W, H)
X -= np.mean(X, axis = 0)  # Data Preprocessing: mean subtraction
X /= np.std(X, axis = 0)  # Normalization

#Splitting into train, val, test sets

num_train = int(num_samples * 0.8)
num_val = int(num_samples * 0.1)
num_test = num_samples - num_train - num_val

# print 'num_train: %d, num_val: %d, num_test: %d' % (num_train, num_val, num_test)

X_train = X[:num_train]
X_val = X[num_train:num_train+num_val]
X_test = X[num_train+num_val:]

y_train = Y[:num_train]
y_val = Y[num_train:num_train+num_val]
y_test = Y[num_train+num_val:]

print ('X_train', X_train.shape)
print ('y_train', y_train.shape)
print ('X_val', X_val.shape)
print ('y_val', y_val.shape)
print ('X_test', X_test.shape)
print ('y_test', y_test.shape)
# Out:
# ('Data Set:', 'subset_48by32_5')
# ('Num classes:', 5)
# Batches: 0
# Preparing Data Set....
# ('X_train', (24000, 3, 48, 32))
# ('y_train', (24000,))
# ('X_val', (3000, 3, 48, 32))
# ('y_val', (3000,))
# ('X_test', (3000, 3, 48, 32))
# ('y_test', (3000,))

# %%
# Create model and compile train and val functions
train_fn, val_fn = cnn_model.main_create_model(C, W, H, NUM_CLASSES, cnn_architecture=cnn_architecture, num_filters=num_filters, filter_width=filter_width, pool_width=pool_width, stride=stride_width, pad=padding, hidden_size=hidden_size, dropout=dropout_p, use_optimizer=USE_OPTIMIZER, learning_rate=LEARNING_RATE, momentum=MOMENTUM, beta1=beta1, beta2=beta2, epsilon=epsilon)
# Out:
# Building network...
# Building a complex CNN...
# Compiling functions...
# Using Update: adam
# Compiling Finished!

# %%
# Train the model.
train_err_list, train_acc_list, val_err_list, val_acc_list, epochs_train_err_list, epochs_train_acc_list, epochs_val_err_list, epochs_val_acc_list = cnn_model.train(num_epochs, batchsize, num_train, num_val, USE_OPTIMIZER, train_fn, val_fn, X_train, y_train, X_val, y_val, record_per_iter=record_per_iter)
# Out:
# Training on: 20 epochs of batch size 500 with num training samples 24000
# Using optimizer: adam
# Validation Size: 3000
# Starting training...
# Ep 0 	iter 0  	loss 1.65686, train acc 18.20, val acc 26.60
# Ep 0 	iter 1  	loss 3947.85334, train acc 20.40, val acc 22.80
# Ep 0 	iter 2  	loss 408.56739, train acc 17.60, val acc 17.60
# Ep 0 	iter 3  	loss 207.42682, train acc 19.00, val acc 16.40
# Ep 0 	iter 4  	loss 55.51011, train acc 14.20, val acc 23.20
# Ep 0 	iter 5  	loss 126.39748, train acc 19.60, val acc 26.20
# Ep 0 	iter 6  	loss 30.66267, train acc 24.80, val acc 20.40
# Ep 0 	iter 7  	loss 37.64624, train acc 20.00, val acc 19.80
# Ep 0 	iter 8  	loss 8.08689, train acc 18.20, val acc 16.20
# Ep 0 	iter 9  	loss 17.53682, train acc 18.20, val acc 21.80
# Ep 0 	iter 10  	loss 18.20380, train acc 26.20, val acc 19.20
# Ep 0 	iter 11  	loss 13.44047, train acc 22.00, val acc 24.00
# Ep 0 	iter 12  	loss 2.87179, train acc 25.80, val acc 26.20
# Ep 0 	iter 13  	loss 1.61262, train acc 21.20, val acc 21.20
# Ep 0 	iter 14  	loss 1.59437, train acc 25.20, val acc 25.20
# Ep 0 	iter 15  	loss 1.59692, train acc 24.80, val acc 24.80
# Ep 0 	iter 16  	loss 1.59008, train acc 27.60, val acc 27.60
# Ep 0 	iter 17  	loss 1.59312, train acc 26.20, val acc 26.20
# Ep 0 	iter 18  	loss 1.59948, train acc 24.80, val acc 24.80
# Ep 0 	iter 19  	loss 1.60644, train acc 24.40, val acc 24.40
# Ep 0 	iter 20  	loss 1.60671, train acc 24.40, val acc 24.40
# Ep 0 	iter 21  	loss 1.59928, train acc 25.20, val acc 25.20
# Ep 0 	iter 22  	loss 1.60649, train acc 24.60, val acc 24.60
# Ep 0 	iter 23  	loss 1.61645, train acc 24.20, val acc 24.20
# Ep 0 	iter 24  	loss 1.60644, train acc 24.00, val acc 24.00
# Ep 0 	iter 25  	loss 1.60095, train acc 23.00, val acc 23.00
# Ep 0 	iter 26  	loss 1.60810, train acc 24.20, val acc 24.20
# Ep 0 	iter 27  	loss 1.59901, train acc 25.60, val acc 25.60
# Ep 0 	iter 28  	loss 1.58291, train acc 28.80, val acc 28.80
# Ep 0 	iter 29  	loss 1.60975, train acc 24.00, val acc 24.00
# Ep 0 	iter 30  	loss 1.59795, train acc 24.40, val acc 24.40
# Ep 0 	iter 31  	loss 1.60826, train acc 21.40, val acc 21.40
# Ep 0 	iter 32  	loss 1.60513, train acc 26.00, val acc 26.00
# Ep 0 	iter 33  	loss 1.59771, train acc 23.60, val acc 23.60
# Ep 0 	iter 34  	loss 1.60365, train acc 25.80, val acc 25.80
# Ep 0 	iter 35  	loss 1.60077, train acc 24.60, val acc 24.60
# Ep 0 	iter 36  	loss 1.60519, train acc 22.00, val acc 22.00
# Ep 0 	iter 37  	loss 1.59715, train acc 24.40, val acc 24.40
# Ep 0 	iter 38  	loss 1.59766, train acc 26.80, val acc 26.80
# Ep 0 	iter 39  	loss 1.59284, train acc 25.40, val acc 25.40
# Ep 0 	iter 40  	loss 1.60521, train acc 21.60, val acc 21.60
# Ep 0 	iter 41  	loss 1.60454, train acc 23.60, val acc 23.60
# Ep 0 	iter 42  	loss 1.59630, train acc 26.20, val acc 26.20
# Ep 0 	iter 43  	loss 1.58497, train acc 28.40, val acc 28.40
# Ep 0 	iter 44  	loss 1.59044, train acc 26.40, val acc 26.40
# Ep 0 	iter 45  	loss 1.61215, train acc 23.20, val acc 23.20
# Ep 0 	iter 46  	loss 1.58180, train acc 26.40, val acc 26.40
# Ep 0 	iter 47  	loss 1.58893, train acc 25.80, val acc 25.80
# Epoch 1 of 20 took 688.838s
#   training loss:		102.747093
#   training accuracy:		23.59 %
#   validation loss:		1.588731
#   validation accuracy:		25.80 %
# Ep 1 	iter 0  	loss 1.61210, train acc 22.80, val acc 22.80
# Ep 1 	iter 1  	loss 1.59728, train acc 25.40, val acc 25.40
# Ep 1 	iter 2  	loss 1.60539, train acc 22.40, val acc 22.40
# Ep 1 	iter 3  	loss 1.60988, train acc 23.40, val acc 23.40
# Ep 1 	iter 4  	loss 1.59223, train acc 23.80, val acc 23.80
# Ep 1 	iter 5  	loss 1.58994, train acc 28.20, val acc 28.20
# Ep 1 	iter 6  	loss 1.60146, train acc 24.40, val acc 24.40
# Ep 1 	iter 7  	loss 1.59807, train acc 25.40, val acc 25.40
# Ep 1 	iter 8  	loss 1.58571, train acc 28.80, val acc 28.80
# Ep 1 	iter 9  	loss 1.59958, train acc 27.20, val acc 27.20
# Ep 1 	iter 10  	loss 1.59287, train acc 24.80, val acc 24.80
# Ep 1 	iter 11  	loss 1.60143, train acc 22.80, val acc 22.80
# Ep 1 	iter 12  	loss 1.58950, train acc 25.00, val acc 25.00
# Ep 1 	iter 13  	loss 1.60046, train acc 24.80, val acc 20.80
# Ep 1 	iter 14  	loss 1.60427, train acc 21.20, val acc 24.80
# Ep 1 	iter 15  	loss 1.61379, train acc 24.20, val acc 24.20
# Ep 1 	iter 16  	loss 1.59847, train acc 23.40, val acc 23.40
# Ep 1 	iter 17  	loss 1.59110, train acc 28.40, val acc 28.40
# Ep 1 	iter 18  	loss 1.59440, train acc 25.60, val acc 25.60
# Ep 1 	iter 19  	loss 1.59610, train acc 26.20, val acc 26.20
# Ep 1 	iter 20  	loss 1.60477, train acc 23.60, val acc 23.60
# Ep 1 	iter 21  	loss 1.59918, train acc 23.60, val acc 23.60
# Ep 1 	iter 22  	loss 1.59553, train acc 26.20, val acc 26.20
# Ep 1 	iter 23  	loss 1.60770, train acc 22.60, val acc 22.60
# Ep 1 	iter 24  	loss 1.59366, train acc 27.20, val acc 27.20
# Ep 1 	iter 25  	loss 1.59590, train acc 25.60, val acc 25.60
# Ep 1 	iter 26  	loss 1.59303, train acc 27.00, val acc 27.00
# Ep 1 	iter 27  	loss 1.59306, train acc 26.20, val acc 26.20
# Ep 1 	iter 28  	loss 1.59232, train acc 25.00, val acc 25.00
# Ep 1 	iter 29  	loss 1.59442, train acc 25.60, val acc 25.60
# Ep 1 	iter 30  	loss 1.60228, train acc 24.40, val acc 24.40
# Ep 1 	iter 31  	loss 1.60765, train acc 23.00, val acc 23.00
# Ep 1 	iter 32  	loss 1.60219, train acc 27.20, val acc 27.20
# Ep 1 	iter 33  	loss 1.59960, train acc 23.80, val acc 23.80
# Ep 1 	iter 34  	loss 1.62553, train acc 20.80, val acc 20.80
# Ep 1 	iter 35  	loss 1.59116, train acc 26.80, val acc 26.80
# Ep 1 	iter 36  	loss 1.59828, train acc 26.00, val acc 26.00
# Ep 1 	iter 37  	loss 1.59614, train acc 24.20, val acc 24.20
# Ep 1 	iter 38  	loss 1.59953, train acc 24.40, val acc 24.40
# Ep 1 	iter 39  	loss 1.60595, train acc 22.80, val acc 22.80
# Ep 1 	iter 40  	loss 1.60104, train acc 24.40, val acc 24.40
# Ep 1 	iter 41  	loss 1.59299, train acc 27.40, val acc 27.40
# Ep 1 	iter 42  	loss 1.60360, train acc 22.40, val acc 22.40
# Ep 1 	iter 43  	loss 1.60104, train acc 22.40, val acc 22.40
# Ep 1 	iter 44  	loss 1.59951, train acc 25.40, val acc 25.40
# Ep 1 	iter 45  	loss 1.60334, train acc 25.80, val acc 25.80
# Ep 1 	iter 46  	loss 1.59244, train acc 27.60, val acc 27.60
# Ep 1 	iter 47  	loss 1.59072, train acc 26.00, val acc 26.00
# Epoch 2 of 20 took 400.699s
#   training loss:		1.599096
#   training accuracy:		24.91 %
#   validation loss:		1.590582
#   validation accuracy:		26.00 %
# Ep 2 	iter 0  	loss 1.60190, train acc 24.20, val acc 24.20
# Ep 2 	iter 1  	loss 1.60461, train acc 21.60, val acc 21.60
# Ep 2 	iter 2  	loss 1.59970, train acc 24.60, val acc 24.60
# Ep 2 	iter 3  	loss 1.60057, train acc 24.20, val acc 24.20
# Ep 2 	iter 4  	loss 1.60088, train acc 24.80, val acc 24.80
# Ep 2 	iter 5  	loss 1.58939, train acc 24.80, val acc 24.80
# Ep 2 	iter 6  	loss 1.58883, train acc 27.20, val acc 27.20
# Ep 2 	iter 7  	loss 1.60788, train acc 24.20, val acc 24.20
# Ep 2 	iter 8  	loss 1.59744, train acc 27.60, val acc 27.60
# Ep 2 	iter 9  	loss 1.59870, train acc 23.80, val acc 23.80
# Ep 2 	iter 10  	loss 1.58870, train acc 28.80, val acc 28.80
# Ep 2 	iter 11  	loss 1.58834, train acc 27.60, val acc 27.60
# Ep 2 	iter 12  	loss 1.59784, train acc 23.40, val acc 23.40
# Ep 2 	iter 13  	loss 1.58471, train acc 26.60, val acc 26.60
# Ep 2 	iter 14  	loss 1.60391, train acc 23.40, val acc 23.40
# Ep 2 	iter 15  	loss 1.59426, train acc 24.20, val acc 24.20
# Ep 2 	iter 16  	loss 1.60618, train acc 25.00, val acc 25.00
# Ep 2 	iter 17  	loss 1.60295, train acc 25.80, val acc 25.80
# Ep 2 	iter 18  	loss 1.60169, train acc 22.80, val acc 22.80
# Ep 2 	iter 19  	loss 1.59011, train acc 26.60, val acc 26.60
# Ep 2 	iter 20  	loss 1.60190, train acc 24.60, val acc 24.60
# Ep 2 	iter 21  	loss 1.61188, train acc 22.20, val acc 22.20
# Ep 2 	iter 22  	loss 1.60032, train acc 26.20, val acc 26.20
# Ep 2 	iter 23  	loss 1.60094, train acc 27.80, val acc 27.80
# Ep 2 	iter 24  	loss 1.60235, train acc 22.00, val acc 22.00
# Ep 2 	iter 25  	loss 1.60216, train acc 23.80, val acc 23.80
# Ep 2 	iter 26  	loss 1.59819, train acc 24.80, val acc 24.80
# Ep 2 	iter 27  	loss 1.59538, train acc 24.80, val acc 24.80
# Ep 2 	iter 28  	loss 1.60383, train acc 25.20, val acc 25.20
# Ep 2 	iter 29  	loss 1.59570, train acc 25.80, val acc 25.80
# Ep 2 	iter 30  	loss 1.60586, train acc 22.20, val acc 22.20
# Ep 2 	iter 31  	loss 1.59804, train acc 25.20, val acc 25.20
# Ep 2 	iter 32  	loss 1.60747, train acc 23.60, val acc 23.60
# Ep 2 	iter 33  	loss 1.59374, train acc 26.60, val acc 26.60
# Ep 2 	iter 34  	loss 1.60172, train acc 23.60, val acc 23.60
# Ep 2 	iter 35  	loss 1.59786, train acc 23.20, val acc 23.20
# Ep 2 	iter 36  	loss 1.59981, train acc 23.60, val acc 23.60
# Ep 2 	iter 37  	loss 1.59482, train acc 25.40, val acc 25.40
# Ep 2 	iter 38  	loss 1.58824, train acc 27.20, val acc 27.20
# Ep 2 	iter 39  	loss 1.60049, train acc 26.40, val acc 26.40
# Ep 2 	iter 40  	loss 1.59398, train acc 26.80, val acc 26.80
# Ep 2 	iter 41  	loss 1.59336, train acc 26.20, val acc 26.20
# Ep 2 	iter 42  	loss 1.59622, train acc 25.20, val acc 25.20
# Ep 2 	iter 43  	loss 1.61465, train acc 21.40, val acc 21.40
# Ep 2 	iter 44  	loss 1.58513, train acc 28.20, val acc 28.20
# Ep 2 	iter 45  	loss 1.59589, train acc 26.00, val acc 26.00
# Ep 2 	iter 46  	loss 1.59847, train acc 26.20, val acc 26.20
# Ep 2 	iter 47  	loss 1.59853, train acc 23.80, val acc 23.80
# Epoch 3 of 20 took 343.965s
#   training loss:		1.598448
#   training accuracy:		24.98 %
#   validation loss:		1.598438
#   validation accuracy:		23.80 %
# Ep 3 	iter 0  	loss 1.59979, train acc 25.00, val acc 25.00
# Ep 3 	iter 1  	loss 1.60821, train acc 22.40, val acc 22.40
# Ep 3 	iter 2  	loss 1.59467, train acc 28.20, val acc 28.20
# Ep 3 	iter 3  	loss 1.60766, train acc 24.00, val acc 24.00
# Ep 3 	iter 4  	loss 1.61103, train acc 23.40, val acc 23.40
# Ep 3 	iter 5  	loss 1.58785, train acc 26.20, val acc 26.20
# Ep 3 	iter 6  	loss 1.59588, train acc 27.00, val acc 27.00
# Ep 3 	iter 7  	loss 1.60403, train acc 26.20, val acc 26.20
# Ep 3 	iter 8  	loss 1.60144, train acc 23.00, val acc 23.00
# Ep 3 	iter 9  	loss 1.60769, train acc 22.60, val acc 22.60
# Ep 3 	iter 10  	loss 1.59894, train acc 23.20, val acc 23.20
# Ep 3 	iter 11  	loss 1.59472, train acc 24.80, val acc 24.80
# Ep 3 	iter 12  	loss 1.59068, train acc 27.20, val acc 27.20
# Ep 3 	iter 13  	loss 1.58737, train acc 24.20, val acc 24.20
# Ep 3 	iter 14  	loss 1.59783, train acc 25.40, val acc 25.40
# Ep 3 	iter 15  	loss 1.58326, train acc 29.40, val acc 29.40
# Ep 3 	iter 16  	loss 1.59299, train acc 25.20, val acc 25.20
# Ep 3 	iter 17  	loss 1.59795, train acc 27.20, val acc 27.20
# Ep 3 	iter 18  	loss 1.60118, train acc 22.80, val acc 22.80
# Ep 3 	iter 19  	loss 1.61472, train acc 25.40, val acc 25.40
# Ep 3 	iter 20  	loss 1.59250, train acc 27.80, val acc 27.80
# Ep 3 	iter 21  	loss 1.59915, train acc 26.20, val acc 26.20
# Ep 3 	iter 22  	loss 1.58252, train acc 29.60, val acc 29.60
# Ep 3 	iter 23  	loss 1.59190, train acc 26.20, val acc 26.20
# Ep 3 	iter 24  	loss 1.60564, train acc 22.40, val acc 22.40
# Ep 3 	iter 25  	loss 1.59683, train acc 26.00, val acc 26.00
# Ep 3 	iter 26  	loss 1.60479, train acc 25.00, val acc 25.00
# Ep 3 	iter 27  	loss 1.60749, train acc 23.60, val acc 23.60
# Ep 3 	iter 28  	loss 1.60342, train acc 23.80, val acc 23.80
# Ep 3 	iter 29  	loss 1.60331, train acc 24.00, val acc 24.00
# Ep 3 	iter 30  	loss 1.61358, train acc 20.60, val acc 20.60
# Ep 3 	iter 31  	loss 1.58098, train acc 30.00, val acc 30.00
# Ep 3 	iter 32  	loss 1.59693, train acc 24.20, val acc 24.20
# Ep 3 	iter 33  	loss 1.60912, train acc 23.40, val acc 23.40
# Ep 3 	iter 34  	loss 1.58872, train acc 25.20, val acc 25.20
# Ep 3 	iter 35  	loss 1.60210, train acc 23.80, val acc 23.80
# Ep 3 	iter 36  	loss 1.59560, train acc 24.40, val acc 24.40
# Ep 3 	iter 37  	loss 1.59492, train acc 25.80, val acc 25.80
# Ep 3 	iter 38  	loss 1.60595, train acc 22.40, val acc 22.40
# Ep 3 	iter 39  	loss 1.59444, train acc 23.60, val acc 23.60
# Ep 3 	iter 40  	loss 1.59488, train acc 25.00, val acc 25.00
# Ep 3 	iter 41  	loss 1.60065, train acc 22.60, val acc 22.60
# Ep 3 	iter 42  	loss 1.59209, train acc 27.00, val acc 27.00
# Ep 3 	iter 43  	loss 1.60279, train acc 28.00, val acc 28.00
# Ep 3 	iter 44  	loss 1.60187, train acc 24.00, val acc 24.00
# Ep 3 	iter 45  	loss 1.59887, train acc 25.80, val acc 25.80
# Ep 3 	iter 46  	loss 1.60036, train acc 21.20, val acc 21.20
# Ep 3 	iter 47  	loss 1.60162, train acc 24.80, val acc 24.80
# Epoch 4 of 20 took 359.315s
#   training loss:		1.598769
#   training accuracy:		24.98 %
#   validation loss:		1.601756
#   validation accuracy:		24.80 %
# Ep 4 	iter 0  	loss 1.60150, train acc 23.00, val acc 23.00
# Ep 4 	iter 1  	loss 1.58720, train acc 27.20, val acc 27.20
# Ep 4 	iter 2  	loss 1.58864, train acc 26.40, val acc 26.40
# Ep 4 	iter 3  	loss 1.60191, train acc 26.00, val acc 26.00
# Ep 4 	iter 4  	loss 1.60297, train acc 25.80, val acc 25.80
# Ep 4 	iter 5  	loss 1.59768, train acc 25.40, val acc 25.40
# Ep 4 	iter 6  	loss 1.59272, train acc 25.00, val acc 25.00
# Ep 4 	iter 7  	loss 1.58997, train acc 26.60, val acc 26.60
# Ep 4 	iter 8  	loss 1.58662, train acc 26.80, val acc 26.80
# Ep 4 	iter 9  	loss 1.59041, train acc 25.60, val acc 25.60
# Ep 4 	iter 10  	loss 1.59888, train acc 25.40, val acc 25.40
# Ep 4 	iter 11  	loss 1.62425, train acc 22.60, val acc 22.60
# Ep 4 	iter 12  	loss 1.60140, train acc 23.20, val acc 23.20
# Ep 4 	iter 13  	loss 1.59748, train acc 25.00, val acc 25.00
# Ep 4 	iter 14  	loss 1.59464, train acc 27.60, val acc 27.60
# Ep 4 	iter 15  	loss 1.60226, train acc 24.00, val acc 24.00
# Ep 4 	iter 16  	loss 1.60622, train acc 21.20, val acc 21.20
# Ep 4 	iter 17  	loss 1.59833, train acc 25.00, val acc 25.00
# Ep 4 	iter 18  	loss 1.59745, train acc 26.40, val acc 26.40
# Ep 4 	iter 19  	loss 1.59412, train acc 26.40, val acc 26.40
# Ep 4 	iter 20  	loss 1.59537, train acc 26.00, val acc 26.00
# Ep 4 	iter 21  	loss 1.60552, train acc 22.00, val acc 22.00
# Ep 4 	iter 22  	loss 1.60208, train acc 25.80, val acc 25.80
# Ep 4 	iter 23  	loss 1.59639, train acc 26.20, val acc 26.20
# Ep 4 	iter 24  	loss 1.60415, train acc 23.20, val acc 23.20
# Ep 4 	iter 25  	loss 1.59423, train acc 24.40, val acc 24.40
# Ep 4 	iter 26  	loss 1.58990, train acc 27.60, val acc 27.60
# Ep 4 	iter 27  	loss 1.59978, train acc 24.00, val acc 24.00
# Ep 4 	iter 28  	loss 1.58716, train acc 27.60, val acc 27.60
# Ep 4 	iter 29  	loss 1.60031, train acc 21.00, val acc 21.00
# Ep 4 	iter 30  	loss 1.60218, train acc 25.00, val acc 25.00
# Ep 4 	iter 31  	loss 1.59884, train acc 22.80, val acc 22.80
# Ep 4 	iter 32  	loss 1.60455, train acc 25.00, val acc 25.00
# Ep 4 	iter 33  	loss 1.59472, train acc 25.60, val acc 25.60
# Ep 4 	iter 34  	loss 1.59727, train acc 24.60, val acc 24.60
# Ep 4 	iter 35  	loss 1.59597, train acc 24.60, val acc 24.60
# Ep 4 	iter 36  	loss 1.59720, train acc 24.00, val acc 24.00
# Ep 4 	iter 37  	loss 1.59497, train acc 25.80, val acc 25.80
# Ep 4 	iter 38  	loss 1.59157, train acc 25.80, val acc 25.80
# Ep 4 	iter 39  	loss 1.59606, train acc 25.20, val acc 25.20
# Ep 4 	iter 40  	loss 1.60174, train acc 23.60, val acc 23.60
# Ep 4 	iter 41  	loss 1.60165, train acc 26.80, val acc 26.80
# Ep 4 	iter 42  	loss 1.59169, train acc 25.60, val acc 25.60
# Ep 4 	iter 43  	loss 1.59208, train acc 26.60, val acc 26.60
# Ep 4 	iter 44  	loss 1.60028, train acc 24.80, val acc 24.80
# Ep 4 	iter 45  	loss 1.60609, train acc 23.80, val acc 23.80
# Ep 4 	iter 46  	loss 1.60550, train acc 23.20, val acc 23.20
# Ep 4 	iter 47  	loss 1.60652, train acc 24.00, val acc 24.00
# Epoch 5 of 20 took 537.400s
#   training loss:		1.598092
#   training accuracy:		24.98 %
#   validation loss:		1.606196
#   validation accuracy:		24.00 %
# Ep 5 	iter 0  	loss 1.59203, train acc 27.20, val acc 27.20
# Ep 5 	iter 1  	loss 1.58763, train acc 28.40, val acc 28.40
# Ep 5 	iter 2  	loss 1.60760, train acc 24.40, val acc 24.40
# Ep 5 	iter 3  	loss 1.60577, train acc 22.80, val acc 22.80
# Ep 5 	iter 4  	loss 1.60955, train acc 22.40, val acc 22.40
# Ep 5 	iter 5  	loss 1.59968, train acc 24.40, val acc 24.40
# Ep 5 	iter 6  	loss 1.59548, train acc 26.80, val acc 26.80
# Ep 5 	iter 7  	loss 1.60221, train acc 24.40, val acc 24.40
# Ep 5 	iter 8  	loss 1.59897, train acc 23.40, val acc 23.40
# Ep 5 	iter 9  	loss 1.59791, train acc 27.20, val acc 27.20
# Ep 5 	iter 10  	loss 1.60170, train acc 22.80, val acc 22.80
# Ep 5 	iter 11  	loss 1.60269, train acc 24.40, val acc 24.40
# Ep 5 	iter 12  	loss 1.59288, train acc 26.80, val acc 26.80
# Ep 5 	iter 13  	loss 1.59882, train acc 25.20, val acc 25.20
# Ep 5 	iter 14  	loss 1.59071, train acc 26.80, val acc 26.80
# Ep 5 	iter 15  	loss 1.59955, train acc 25.00, val acc 25.00
# Ep 5 	iter 16  	loss 1.60139, train acc 24.00, val acc 24.00
# Ep 5 	iter 17  	loss 1.60267, train acc 24.00, val acc 24.00
# Ep 5 	iter 18  	loss 1.61319, train acc 21.00, val acc 21.00
# Ep 5 	iter 19  	loss 1.60144, train acc 24.80, val acc 24.80
# Ep 5 	iter 20  	loss 1.58970, train acc 28.00, val acc 28.00
# Ep 5 	iter 21  	loss 1.60297, train acc 23.00, val acc 23.00
# Ep 5 	iter 22  	loss 1.59102, train acc 28.80, val acc 28.80
# Ep 5 	iter 23  	loss 1.60775, train acc 21.60, val acc 21.60
# Ep 5 	iter 24  	loss 1.59154, train acc 24.40, val acc 24.40
# Ep 5 	iter 25  	loss 1.59243, train acc 26.60, val acc 26.60
# Ep 5 	iter 26  	loss 1.59885, train acc 25.80, val acc 25.80
# Ep 5 	iter 27  	loss 1.60130, train acc 24.20, val acc 24.20
# Ep 5 	iter 28  	loss 1.59539, train acc 26.00, val acc 26.00
# Ep 5 	iter 29  	loss 1.60282, train acc 22.60, val acc 22.60
# Ep 5 	iter 30  	loss 1.59631, train acc 27.00, val acc 27.00
# Ep 5 	iter 31  	loss 1.59153, train acc 26.40, val acc 26.40
# Ep 5 	iter 32  	loss 1.59385, train acc 28.40, val acc 28.40
# Ep 5 	iter 33  	loss 1.59226, train acc 24.20, val acc 24.20
# Ep 5 	iter 34  	loss 1.59902, train acc 23.80, val acc 23.80
# Ep 5 	iter 35  	loss 1.59253, train acc 25.40, val acc 25.40
# Ep 5 	iter 36  	loss 1.59984, train acc 25.20, val acc 25.20
# Ep 5 	iter 37  	loss 1.60079, train acc 26.20, val acc 26.20
# Ep 5 	iter 38  	loss 1.59561, train acc 25.80, val acc 25.80
# Ep 5 	iter 39  	loss 1.59761, train acc 26.60, val acc 26.60
# Ep 5 	iter 40  	loss 1.59503, train acc 24.20, val acc 24.20
# Ep 5 	iter 41  	loss 1.59669, train acc 22.80, val acc 22.80
# Ep 5 	iter 42  	loss 1.59857, train acc 24.80, val acc 24.80
# Ep 5 	iter 43  	loss 1.60014, train acc 25.00, val acc 25.00
# Ep 5 	iter 44  	loss 1.59970, train acc 22.00, val acc 22.00
# Ep 5 	iter 45  	loss 1.59025, train acc 26.60, val acc 26.60
# Ep 5 	iter 46  	loss 1.59593, train acc 23.60, val acc 23.60
# Ep 5 	iter 47  	loss 1.59568, train acc 24.00, val acc 24.00
# Epoch 6 of 20 took 492.603s
#   training loss:		1.598062
#   training accuracy:		24.98 %
#   validation loss:		1.595393
#   validation accuracy:		24.00 %
# Ep 6 	iter 0  	loss 1.60510, train acc 23.60, val acc 23.60
# Ep 6 	iter 1  	loss 1.59736, train acc 26.60, val acc 26.60
# Ep 6 	iter 2  	loss 1.60197, train acc 23.40, val acc 23.40
# Ep 6 	iter 3  	loss 1.60032, train acc 23.20, val acc 23.20
# Ep 6 	iter 4  	loss 1.59004, train acc 26.20, val acc 26.20
# Ep 6 	iter 5  	loss 1.58971, train acc 29.20, val acc 29.20
# Ep 6 	iter 6  	loss 1.61239, train acc 22.20, val acc 22.20
# Ep 6 	iter 7  	loss 1.60023, train acc 25.40, val acc 25.40
# Ep 6 	iter 8  	loss 1.60027, train acc 24.60, val acc 24.60
# Ep 6 	iter 9  	loss 1.60184, train acc 23.40, val acc 23.40
# Ep 6 	iter 10  	loss 1.58262, train acc 26.40, val acc 26.40
# Ep 6 	iter 11  	loss 1.61245, train acc 23.40, val acc 23.40
# Ep 6 	iter 12  	loss 1.59891, train acc 24.00, val acc 24.00
# Ep 6 	iter 13  	loss 1.59484, train acc 23.40, val acc 23.40
# Ep 6 	iter 14  	loss 1.59656, train acc 24.40, val acc 24.40
# Ep 6 	iter 15  	loss 1.60166, train acc 24.80, val acc 24.80
# Ep 6 	iter 16  	loss 1.61726, train acc 20.80, val acc 20.80
# Ep 6 	iter 17  	loss 1.60255, train acc 25.60, val acc 25.60
# Ep 6 	iter 18  	loss 1.60037, train acc 25.20, val acc 25.20
# Ep 6 	iter 19  	loss 1.58913, train acc 27.60, val acc 27.60
# Ep 6 	iter 20  	loss 1.59730, train acc 26.40, val acc 26.40
# Ep 6 	iter 21  	loss 1.58765, train acc 28.40, val acc 28.40
# Ep 6 	iter 22  	loss 1.60266, train acc 23.60, val acc 23.60
# Ep 6 	iter 23  	loss 1.58733, train acc 26.80, val acc 26.80
# Ep 6 	iter 24  	loss 1.60716, train acc 21.40, val acc 21.40
# Ep 6 	iter 25  	loss 1.59355, train acc 25.60, val acc 25.60
# Ep 6 	iter 26  	loss 1.58879, train acc 27.60, val acc 27.60
# Ep 6 	iter 27  	loss 1.58965, train acc 25.80, val acc 25.80
# Ep 6 	iter 28  	loss 1.59722, train acc 22.80, val acc 22.80
# Ep 6 	iter 29  	loss 1.59834, train acc 25.80, val acc 25.80
# Ep 6 	iter 30  	loss 1.59348, train acc 25.80, val acc 25.80
# Ep 6 	iter 31  	loss 1.61108, train acc 22.60, val acc 22.60
# Ep 6 	iter 32  	loss 1.58204, train acc 27.60, val acc 27.60
# Ep 6 	iter 33  	loss 1.59113, train acc 26.60, val acc 26.60
# Ep 6 	iter 34  	loss 1.60527, train acc 22.40, val acc 22.40
# Ep 6 	iter 35  	loss 1.59626, train acc 27.00, val acc 27.00
# Ep 6 	iter 36  	loss 1.59627, train acc 25.00, val acc 25.00
# Ep 6 	iter 37  	loss 1.59441, train acc 26.00, val acc 26.00
# Ep 6 	iter 38  	loss 1.58763, train acc 26.40, val acc 26.40
# Ep 6 	iter 39  	loss 1.61138, train acc 25.60, val acc 25.60
# Ep 6 	iter 40  	loss 1.60205, train acc 23.60, val acc 23.60
# Ep 6 	iter 41  	loss 1.59000, train acc 25.60, val acc 25.60
# Ep 6 	iter 42  	loss 1.59894, train acc 24.00, val acc 24.00
# Ep 6 	iter 43  	loss 1.60131, train acc 23.80, val acc 23.80
# Ep 6 	iter 44  	loss 1.59932, train acc 28.00, val acc 28.00
# Ep 6 	iter 45  	loss 1.59403, train acc 21.40, val acc 21.40
# Ep 6 	iter 46  	loss 1.58971, train acc 27.00, val acc 27.00
# Ep 6 	iter 47  	loss 1.61079, train acc 23.20, val acc 23.20
# Epoch 7 of 20 took 437.724s
#   training loss:		1.597923
#   training accuracy:		24.98 %
#   validation loss:		1.610601
#   validation accuracy:		23.20 %
# Ep 7 	iter 0  	loss 1.59406, train acc 23.60, val acc 23.60
# Ep 7 	iter 1  	loss 1.60701, train acc 22.80, val acc 22.80
# Ep 7 	iter 2  	loss 1.59060, train acc 26.60, val acc 26.60
# Ep 7 	iter 3  	loss 1.60848, train acc 23.80, val acc 23.80
# Ep 7 	iter 4  	loss 1.58903, train acc 26.60, val acc 26.60
# Ep 7 	iter 5  	loss 1.59762, train acc 24.20, val acc 24.20
# Ep 7 	iter 6  	loss 1.60176, train acc 25.60, val acc 25.60
# Ep 7 	iter 7  	loss 1.59363, train acc 26.60, val acc 26.60
# Ep 7 	iter 8  	loss 1.60094, train acc 25.80, val acc 25.80
# Ep 7 	iter 9  	loss 1.59338, train acc 27.80, val acc 27.80
# Ep 7 	iter 10  	loss 1.58968, train acc 26.80, val acc 26.80
# Ep 7 	iter 11  	loss 1.60626, train acc 23.20, val acc 23.20
# Ep 7 	iter 12  	loss 1.58555, train acc 25.40, val acc 25.40
# Ep 7 	iter 13  	loss 1.59770, train acc 24.00, val acc 24.00
# Ep 7 	iter 14  	loss 1.59828, train acc 26.40, val acc 26.40
# Ep 7 	iter 15  	loss 1.58563, train acc 27.00, val acc 27.00
# Ep 7 	iter 16  	loss 1.59785, train acc 26.00, val acc 26.00
# Ep 7 	iter 17  	loss 1.60088, train acc 24.80, val acc 24.80
# Ep 7 	iter 18  	loss 1.59932, train acc 25.00, val acc 25.00
# Ep 7 	iter 19  	loss 1.60143, train acc 23.20, val acc 23.20
# Ep 7 	iter 20  	loss 1.60561, train acc 23.00, val acc 23.00
# Ep 7 	iter 21  	loss 1.60314, train acc 24.00, val acc 24.00
# Ep 7 	iter 22  	loss 1.60875, train acc 23.20, val acc 23.20
# Ep 7 	iter 23  	loss 1.59410, train acc 24.00, val acc 24.00
# Ep 7 	iter 24  	loss 1.59808, train acc 24.20, val acc 24.20
# Ep 7 	iter 25  	loss 1.59372, train acc 26.60, val acc 26.60
# Ep 7 	iter 26  	loss 1.60541, train acc 22.60, val acc 22.60
# Ep 7 	iter 27  	loss 1.58390, train acc 28.60, val acc 28.60
# Ep 7 	iter 28  	loss 1.59544, train acc 24.00, val acc 24.00
# Ep 7 	iter 29  	loss 1.59778, train acc 26.80, val acc 26.80
# Ep 7 	iter 30  	loss 1.60533, train acc 25.20, val acc 25.20
# Ep 7 	iter 31  	loss 1.59379, train acc 23.40, val acc 23.40
# Ep 7 	iter 32  	loss 1.59963, train acc 27.20, val acc 27.20
# Ep 7 	iter 33  	loss 1.60005, train acc 25.60, val acc 25.60
# Ep 7 	iter 34  	loss 1.59453, train acc 25.40, val acc 25.40
# Ep 7 	iter 35  	loss 1.59492, train acc 25.40, val acc 25.40
# Ep 7 	iter 36  	loss 1.58479, train acc 29.60, val acc 29.60
# Ep 7 	iter 37  	loss 1.60620, train acc 25.00, val acc 25.00
# Ep 7 	iter 38  	loss 1.59233, train acc 23.40, val acc 23.40
# Ep 7 	iter 39  	loss 1.60043, train acc 22.60, val acc 22.60
# Ep 7 	iter 40  	loss 1.60291, train acc 24.40, val acc 24.40
# Ep 7 	iter 41  	loss 1.60263, train acc 23.40, val acc 23.40
# Ep 7 	iter 42  	loss 1.60673, train acc 22.60, val acc 22.60
# Ep 7 	iter 43  	loss 1.59730, train acc 25.40, val acc 25.40
# Ep 7 	iter 44  	loss 1.59693, train acc 25.80, val acc 25.80
# Ep 7 	iter 45  	loss 1.59885, train acc 24.40, val acc 24.40
# Ep 7 	iter 46  	loss 1.60176, train acc 24.00, val acc 24.00
# Ep 7 	iter 47  	loss 1.59838, train acc 24.20, val acc 24.20
# Epoch 8 of 20 took 372.109s
#   training loss:		1.597969
#   training accuracy:		24.98 %
#   validation loss:		1.598380
#   validation accuracy:		24.20 %
# Ep 8 	iter 0  	loss 1.59470, train acc 24.60, val acc 24.60
# Ep 8 	iter 1  	loss 1.59418, train acc 25.60, val acc 25.60
# Ep 8 	iter 2  	loss 1.60147, train acc 26.00, val acc 26.00
# Ep 8 	iter 3  	loss 1.59885, train acc 24.40, val acc 24.40
# Ep 8 	iter 4  	loss 1.60072, train acc 24.20, val acc 24.20
# Ep 8 	iter 5  	loss 1.60049, train acc 23.80, val acc 23.80
# Ep 8 	iter 6  	loss 1.59994, train acc 25.40, val acc 25.40
# Ep 8 	iter 7  	loss 1.59140, train acc 26.00, val acc 26.00
# Ep 8 	iter 8  	loss 1.59894, train acc 24.00, val acc 24.00
# Ep 8 	iter 9  	loss 1.60365, train acc 24.00, val acc 24.00
# Ep 8 	iter 10  	loss 1.59850, train acc 25.60, val acc 25.60
# Ep 8 	iter 11  	loss 1.59366, train acc 27.00, val acc 27.00
# Ep 8 	iter 12  	loss 1.59391, train acc 25.20, val acc 25.20
# Ep 8 	iter 13  	loss 1.59562, train acc 26.20, val acc 26.20
# Ep 8 	iter 14  	loss 1.59201, train acc 24.20, val acc 24.20
# Ep 8 	iter 15  	loss 1.59979, train acc 24.20, val acc 24.20
# Ep 8 	iter 16  	loss 1.60324, train acc 23.20, val acc 23.20
# Ep 8 	iter 17  	loss 1.60419, train acc 24.60, val acc 24.60
# Ep 8 	iter 18  	loss 1.59793, train acc 24.20, val acc 24.20
# Ep 8 	iter 19  	loss 1.59339, train acc 25.00, val acc 25.00
# Ep 8 	iter 20  	loss 1.60013, train acc 24.20, val acc 24.20
# Ep 8 	iter 21  	loss 1.59630, train acc 25.20, val acc 25.20
# Ep 8 	iter 22  	loss 1.60949, train acc 21.80, val acc 21.80
# Ep 8 	iter 23  	loss 1.59549, train acc 24.00, val acc 24.00
# Ep 8 	iter 24  	loss 1.59237, train acc 27.20, val acc 27.20
# Ep 8 	iter 25  	loss 1.61529, train acc 22.00, val acc 22.00
# Ep 8 	iter 26  	loss 1.60278, train acc 24.40, val acc 24.40
# Ep 8 	iter 27  	loss 1.60081, train acc 24.60, val acc 24.60
# Ep 8 	iter 28  	loss 1.59340, train acc 24.80, val acc 24.80
# Ep 8 	iter 29  	loss 1.59420, train acc 26.80, val acc 26.80
# Ep 8 	iter 30  	loss 1.59058, train acc 26.20, val acc 26.20
# Ep 8 	iter 31  	loss 1.60269, train acc 23.40, val acc 23.40
# Ep 8 	iter 32  	loss 1.59985, train acc 23.80, val acc 23.80
# Ep 8 	iter 33  	loss 1.59310, train acc 24.60, val acc 24.60
# Ep 8 	iter 34  	loss 1.59807, train acc 23.80, val acc 23.80
# Ep 8 	iter 35  	loss 1.58152, train acc 30.60, val acc 30.60
# Ep 8 	iter 36  	loss 1.59499, train acc 26.20, val acc 26.20
# Ep 8 	iter 37  	loss 1.59295, train acc 26.40, val acc 26.40
# Ep 8 	iter 38  	loss 1.59831, train acc 25.80, val acc 25.80
# Ep 8 	iter 39  	loss 1.59793, train acc 27.20, val acc 27.20
# Ep 8 	iter 40  	loss 1.59902, train acc 24.60, val acc 24.60
# Ep 8 	iter 41  	loss 1.59595, train acc 26.20, val acc 26.20
# Ep 8 	iter 42  	loss 1.58535, train acc 27.40, val acc 27.40
# Ep 8 	iter 43  	loss 1.59942, train acc 25.00, val acc 25.00
# Ep 8 	iter 44  	loss 1.60132, train acc 24.40, val acc 24.40
# Ep 8 	iter 45  	loss 1.59088, train acc 25.60, val acc 25.60
# Ep 8 	iter 46  	loss 1.60727, train acc 22.20, val acc 22.20
# Ep 8 	iter 47  	loss 1.60300, train acc 23.40, val acc 23.40
# Epoch 9 of 20 took 536.405s
#   training loss:		1.597689
#   training accuracy:		24.98 %
#   validation loss:		1.602402
#   validation accuracy:		23.40 %
# Ep 9 	iter 0  	loss 1.58664, train acc 28.60, val acc 28.60
# Ep 9 	iter 1  	loss 1.59128, train acc 28.60, val acc 28.60
# Ep 9 	iter 2  	loss 1.59575, train acc 25.80, val acc 25.80
# Ep 9 	iter 3  	loss 1.59674, train acc 26.60, val acc 26.60
# Ep 9 	iter 4  	loss 1.59348, train acc 25.40, val acc 25.40
# Ep 9 	iter 5  	loss 1.60728, train acc 22.20, val acc 22.20
# Ep 9 	iter 6  	loss 1.59675, train acc 24.80, val acc 24.80
# Ep 9 	iter 7  	loss 1.60684, train acc 22.40, val acc 22.40
# Ep 9 	iter 8  	loss 1.60266, train acc 21.60, val acc 21.60
# Ep 9 	iter 9  	loss 1.59355, train acc 26.40, val acc 26.40
# Ep 9 	iter 10  	loss 1.60787, train acc 23.40, val acc 23.40
# Ep 9 	iter 11  	loss 1.61205, train acc 21.80, val acc 21.80
# Ep 9 	iter 12  	loss 1.59156, train acc 26.80, val acc 26.80
# Ep 9 	iter 13  	loss 1.59455, train acc 24.60, val acc 24.60
# Ep 9 	iter 14  	loss 1.60510, train acc 21.20, val acc 21.20
# Ep 9 	iter 15  	loss 1.59844, train acc 27.00, val acc 27.00
# Ep 9 	iter 16  	loss 1.59868, train acc 26.00, val acc 26.00
# Ep 9 	iter 17  	loss 1.59213, train acc 27.60, val acc 27.60
# Ep 9 	iter 18  	loss 1.59659, train acc 25.60, val acc 25.60
# Ep 9 	iter 19  	loss 1.59519, train acc 25.20, val acc 25.20
# Ep 9 	iter 20  	loss 1.60089, train acc 24.00, val acc 24.00
# Ep 9 	iter 21  	loss 1.59983, train acc 25.40, val acc 25.40
# Ep 9 	iter 22  	loss 1.59480, train acc 25.40, val acc 25.40
# Ep 9 	iter 23  	loss 1.58767, train acc 26.00, val acc 26.00
# Ep 9 	iter 24  	loss 1.59881, train acc 21.60, val acc 21.60
# Ep 9 	iter 25  	loss 1.59364, train acc 26.20, val acc 26.20
# Ep 9 	iter 26  	loss 1.61805, train acc 21.80, val acc 21.80
# Ep 9 	iter 27  	loss 1.59268, train acc 27.80, val acc 27.80
# Ep 9 	iter 28  	loss 1.59475, train acc 25.60, val acc 25.60
# Ep 9 	iter 29  	loss 1.58615, train acc 29.00, val acc 29.00
# Ep 9 	iter 30  	loss 1.60826, train acc 21.60, val acc 21.60
# Ep 9 	iter 31  	loss 1.60143, train acc 24.00, val acc 24.00
# Ep 9 	iter 32  	loss 1.59079, train acc 26.60, val acc 26.60
# Ep 9 	iter 33  	loss 1.61151, train acc 24.20, val acc 24.20
# Ep 9 	iter 34  	loss 1.59563, train acc 24.40, val acc 24.40
# Ep 9 	iter 35  	loss 1.59637, train acc 25.00, val acc 25.00
# Ep 9 	iter 36  	loss 1.58854, train acc 24.80, val acc 24.80
# Ep 9 	iter 37  	loss 1.59716, train acc 24.80, val acc 24.80
# Ep 9 	iter 38  	loss 1.60833, train acc 20.40, val acc 20.40
# Ep 9 	iter 39  	loss 1.59609, train acc 24.40, val acc 24.40
# Ep 9 	iter 40  	loss 1.59120, train acc 27.80, val acc 27.80
# Ep 9 	iter 41  	loss 1.59131, train acc 28.60, val acc 28.60
# Ep 9 	iter 42  	loss 1.60010, train acc 22.80, val acc 22.80
# Ep 9 	iter 43  	loss 1.58805, train acc 29.00, val acc 29.00
# Ep 9 	iter 44  	loss 1.59035, train acc 24.60, val acc 24.60
# Ep 9 	iter 45  	loss 1.60244, train acc 22.40, val acc 22.40
# Ep 9 	iter 46  	loss 1.60356, train acc 24.40, val acc 24.40
# Ep 9 	iter 47  	loss 1.59738, train acc 25.00, val acc 25.00
# Epoch 10 of 20 took 567.736s
#   training loss:		1.597685
#   training accuracy:		24.98 %
#   validation loss:		1.597306
#   validation accuracy:		25.00 %
# Ep 10 	iter 0  	loss 1.59698, train acc 25.60, val acc 25.60
# Ep 10 	iter 1  	loss 1.59526, train acc 23.80, val acc 23.80
# Ep 10 	iter 2  	loss 1.59803, train acc 25.20, val acc 25.20
# Ep 10 	iter 3  	loss 1.59352, train acc 26.40, val acc 26.40
# Ep 10 	iter 4  	loss 1.60330, train acc 23.40, val acc 23.40
# Ep 10 	iter 5  	loss 1.59491, train acc 26.80, val acc 26.80
# Ep 10 	iter 6  	loss 1.59656, train acc 23.40, val acc 23.40
# Ep 10 	iter 7  	loss 1.61310, train acc 21.40, val acc 21.40
# Ep 10 	iter 8  	loss 1.60742, train acc 21.00, val acc 21.00
# Ep 10 	iter 9  	loss 1.60084, train acc 24.60, val acc 24.60
# Ep 10 	iter 10  	loss 1.59476, train acc 27.00, val acc 27.00
# Ep 10 	iter 11  	loss 1.60061, train acc 24.40, val acc 24.40
# Ep 10 	iter 12  	loss 1.60064, train acc 21.00, val acc 21.00
# Ep 10 	iter 13  	loss 1.60216, train acc 23.20, val acc 23.20
# Ep 10 	iter 14  	loss 1.59580, train acc 25.60, val acc 25.60
# Ep 10 	iter 15  	loss 1.59585, train acc 25.00, val acc 25.00
# Ep 10 	iter 16  	loss 1.59358, train acc 24.80, val acc 24.80
# Ep 10 	iter 17  	loss 1.59845, train acc 24.20, val acc 24.20
# Ep 10 	iter 18  	loss 1.60026, train acc 25.20, val acc 25.20
# Ep 10 	iter 19  	loss 1.60353, train acc 22.80, val acc 22.80
# Ep 10 	iter 20  	loss 1.59445, train acc 26.80, val acc 26.80
# Ep 10 	iter 21  	loss 1.58874, train acc 27.80, val acc 27.80
# Ep 10 	iter 22  	loss 1.59197, train acc 24.40, val acc 24.40
# Ep 10 	iter 23  	loss 1.59678, train acc 24.40, val acc 24.40
# Ep 10 	iter 24  	loss 1.59755, train acc 22.20, val acc 22.20
# Ep 10 	iter 25  	loss 1.60280, train acc 27.00, val acc 27.00
# Ep 10 	iter 26  	loss 1.59733, train acc 24.40, val acc 24.40
# Ep 10 	iter 27  	loss 1.60380, train acc 22.60, val acc 22.60
# Ep 10 	iter 28  	loss 1.60155, train acc 24.00, val acc 24.00
# Ep 10 	iter 29  	loss 1.59529, train acc 25.60, val acc 25.60
# Ep 10 	iter 30  	loss 1.60313, train acc 25.40, val acc 25.40
# Ep 10 	iter 31  	loss 1.59871, train acc 24.00, val acc 24.00
# Ep 10 	iter 32  	loss 1.59312, train acc 27.80, val acc 27.80
# Ep 10 	iter 33  	loss 1.60201, train acc 24.60, val acc 24.60
# Ep 10 	iter 34  	loss 1.59696, train acc 25.80, val acc 25.80
# Ep 10 	iter 35  	loss 1.59254, train acc 30.20, val acc 30.20
# Ep 10 	iter 36  	loss 1.59545, train acc 24.40, val acc 24.40
# Ep 10 	iter 37  	loss 1.58476, train acc 27.20, val acc 27.20
# Ep 10 	iter 38  	loss 1.58852, train acc 27.40, val acc 27.40
# Ep 10 	iter 39  	loss 1.59256, train acc 26.00, val acc 26.00
# Ep 10 	iter 40  	loss 1.59595, train acc 24.20, val acc 24.20
# Ep 10 	iter 41  	loss 1.58218, train acc 28.20, val acc 28.20
# Ep 10 	iter 42  	loss 1.60774, train acc 22.40, val acc 22.40
# Ep 10 	iter 43  	loss 1.60327, train acc 26.00, val acc 26.00
# Ep 10 	iter 44  	loss 1.59049, train acc 25.80, val acc 25.80
# Ep 10 	iter 45  	loss 1.60254, train acc 26.40, val acc 26.40
# Ep 10 	iter 46  	loss 1.60494, train acc 24.60, val acc 24.60
# Ep 10 	iter 47  	loss 1.60167, train acc 24.80, val acc 24.80
# Epoch 11 of 20 took 485.602s
#   training loss:		1.597757
#   training accuracy:		24.98 %
#   validation loss:		1.600628
#   validation accuracy:		24.80 %
# Ep 11 	iter 0  	loss 1.60012, train acc 24.60, val acc 24.60
# Ep 11 	iter 1  	loss 1.60401, train acc 24.40, val acc 24.40
# Ep 11 	iter 2  	loss 1.60500, train acc 24.20, val acc 24.20
# Ep 11 	iter 3  	loss 1.59832, train acc 26.00, val acc 26.00
# Ep 11 	iter 4  	loss 1.60054, train acc 22.00, val acc 22.00
# Ep 11 	iter 5  	loss 1.61480, train acc 23.20, val acc 23.20
# Ep 11 	iter 6  	loss 1.59363, train acc 25.80, val acc 25.80
# Ep 11 	iter 7  	loss 1.60091, train acc 24.80, val acc 24.80
# Ep 11 	iter 8  	loss 1.59851, train acc 27.20, val acc 27.20
# Ep 11 	iter 9  	loss 1.59886, train acc 27.80, val acc 27.80
# Ep 11 	iter 10  	loss 1.60166, train acc 26.20, val acc 26.20
# Ep 11 	iter 11  	loss 1.60267, train acc 24.40, val acc 24.40
# Ep 11 	iter 12  	loss 1.59219, train acc 26.20, val acc 26.20
# Ep 11 	iter 13  	loss 1.59616, train acc 24.40, val acc 24.40
# Ep 11 	iter 14  	loss 1.59590, train acc 25.80, val acc 25.80
# Ep 11 	iter 15  	loss 1.60106, train acc 26.00, val acc 26.00
# Ep 11 	iter 16  	loss 1.60043, train acc 23.80, val acc 23.80
# Ep 11 	iter 17  	loss 1.58327, train acc 27.20, val acc 27.20
# Ep 11 	iter 18  	loss 1.60804, train acc 21.80, val acc 21.80
# Ep 11 	iter 19  	loss 1.59310, train acc 27.20, val acc 27.20
# Ep 11 	iter 20  	loss 1.60149, train acc 24.00, val acc 24.00
# Ep 11 	iter 21  	loss 1.60388, train acc 24.00, val acc 24.00
# Ep 11 	iter 22  	loss 1.59225, train acc 25.60, val acc 25.60
# Ep 11 	iter 23  	loss 1.59973, train acc 22.80, val acc 22.80
# Ep 11 	iter 24  	loss 1.60052, train acc 24.40, val acc 24.40
# Ep 11 	iter 25  	loss 1.59471, train acc 26.20, val acc 26.20
# Ep 11 	iter 26  	loss 1.60186, train acc 26.00, val acc 26.00
# Ep 11 	iter 27  	loss 1.59225, train acc 28.00, val acc 28.00
# Ep 11 	iter 28  	loss 1.60094, train acc 24.20, val acc 24.20
# Ep 11 	iter 29  	loss 1.60137, train acc 22.80, val acc 22.80
# Ep 11 	iter 30  	loss 1.59606, train acc 23.80, val acc 23.80
# Ep 11 	iter 31  	loss 1.59717, train acc 23.80, val acc 23.80
# Ep 11 	iter 32  	loss 1.59123, train acc 27.40, val acc 27.40
# Ep 11 	iter 33  	loss 1.59183, train acc 26.00, val acc 26.00
# Ep 11 	iter 34  	loss 1.58699, train acc 26.20, val acc 26.20
# Ep 11 	iter 35  	loss 1.59624, train acc 25.00, val acc 25.00
# Ep 11 	iter 36  	loss 1.60316, train acc 24.60, val acc 24.60
# Ep 11 	iter 37  	loss 1.59656, train acc 25.00, val acc 25.00
# Ep 11 	iter 38  	loss 1.59294, train acc 25.80, val acc 25.80
# Ep 11 	iter 39  	loss 1.59614, train acc 21.80, val acc 21.80
# Ep 11 	iter 40  	loss 1.58958, train acc 25.40, val acc 25.40
# Ep 11 	iter 41  	loss 1.58850, train acc 27.60, val acc 27.60
# Ep 11 	iter 42  	loss 1.59433, train acc 27.40, val acc 27.40
# Ep 11 	iter 43  	loss 1.59648, train acc 25.00, val acc 25.00
# Ep 11 	iter 44  	loss 1.60733, train acc 22.60, val acc 22.60
# Ep 11 	iter 45  	loss 1.59736, train acc 25.60, val acc 25.60
# Ep 11 	iter 46  	loss 1.59709, train acc 24.00, val acc 24.00
# Ep 11 	iter 47  	loss 1.60782, train acc 21.20, val acc 21.20
# Epoch 12 of 20 took 411.683s
#   training loss:		1.598021
#   training accuracy:		24.98 %
#   validation loss:		1.607162
#   validation accuracy:		21.20 %
# Ep 12 	iter 0  	loss 1.59183, train acc 27.60, val acc 27.60
# Ep 12 	iter 1  	loss 1.59495, train acc 24.60, val acc 24.60
# Ep 12 	iter 2  	loss 1.60011, train acc 25.80, val acc 25.80
# Ep 12 	iter 3  	loss 1.60347, train acc 23.40, val acc 23.40
# Ep 12 	iter 4  	loss 1.60256, train acc 24.80, val acc 24.80
# Ep 12 	iter 5  	loss 1.59274, train acc 26.00, val acc 26.00
# Ep 12 	iter 6  	loss 1.59967, train acc 23.40, val acc 23.40
# Ep 12 	iter 7  	loss 1.59388, train acc 24.00, val acc 24.00
# Ep 12 	iter 8  	loss 1.58642, train acc 26.60, val acc 26.60
# Ep 12 	iter 9  	loss 1.59693, train acc 23.40, val acc 23.40
# Ep 12 	iter 10  	loss 1.59233, train acc 26.40, val acc 26.40
# Ep 12 	iter 11  	loss 1.61285, train acc 22.60, val acc 22.60
# Ep 12 	iter 12  	loss 1.59409, train acc 27.20, val acc 27.20
# Ep 12 	iter 13  	loss 1.60704, train acc 24.60, val acc 24.60
# Ep 12 	iter 14  	loss 1.59440, train acc 26.80, val acc 26.80
# Ep 12 	iter 15  	loss 1.58606, train acc 27.60, val acc 27.60
# Ep 12 	iter 16  	loss 1.60225, train acc 25.80, val acc 25.80
# Ep 12 	iter 17  	loss 1.59286, train acc 25.60, val acc 25.60
# Ep 12 	iter 18  	loss 1.60718, train acc 21.40, val acc 21.40
# Ep 12 	iter 19  	loss 1.58527, train acc 26.00, val acc 26.00
# Ep 12 	iter 20  	loss 1.61227, train acc 23.80, val acc 23.80
# Ep 12 	iter 21  	loss 1.60081, train acc 25.80, val acc 25.80
# Ep 12 	iter 22  	loss 1.59419, train acc 25.20, val acc 25.20
# Ep 12 	iter 23  	loss 1.59955, train acc 24.20, val acc 24.20
# Ep 12 	iter 24  	loss 1.59235, train acc 24.80, val acc 24.80
# Ep 12 	iter 25  	loss 1.59516, train acc 25.20, val acc 25.20
# Ep 12 	iter 26  	loss 1.60164, train acc 24.60, val acc 24.60
# Ep 12 	iter 27  	loss 1.61408, train acc 20.20, val acc 20.20
# Ep 12 	iter 28  	loss 1.58827, train acc 28.40, val acc 28.40
# Ep 12 	iter 29  	loss 1.59054, train acc 27.00, val acc 27.00
# Ep 12 	iter 30  	loss 1.60036, train acc 24.80, val acc 24.80
# Ep 12 	iter 31  	loss 1.60269, train acc 21.20, val acc 21.20
# Ep 12 	iter 32  	loss 1.60119, train acc 23.60, val acc 23.60
# Ep 12 	iter 33  	loss 1.59711, train acc 26.60, val acc 26.60
# Ep 12 	iter 34  	loss 1.59183, train acc 26.40, val acc 26.40
# Ep 12 	iter 35  	loss 1.58620, train acc 27.40, val acc 27.40
# Ep 12 	iter 36  	loss 1.59897, train acc 24.00, val acc 24.00
# Ep 12 	iter 37  	loss 1.59514, train acc 24.60, val acc 24.60
# Ep 12 	iter 38  	loss 1.60382, train acc 23.40, val acc 23.40
# Ep 12 	iter 39  	loss 1.60392, train acc 25.80, val acc 25.80
# Ep 12 	iter 40  	loss 1.60380, train acc 24.40, val acc 24.40
# Ep 12 	iter 41  	loss 1.59580, train acc 28.20, val acc 28.20
# Ep 12 	iter 42  	loss 1.60497, train acc 23.20, val acc 23.20
# Ep 12 	iter 43  	loss 1.60818, train acc 21.00, val acc 21.00
# Ep 12 	iter 44  	loss 1.59020, train acc 26.80, val acc 26.80
# Ep 12 	iter 45  	loss 1.59294, train acc 25.80, val acc 25.80
# Ep 12 	iter 46  	loss 1.59492, train acc 23.60, val acc 23.60
# Ep 12 	iter 47  	loss 1.59441, train acc 25.60, val acc 25.60
# Epoch 13 of 20 took 365.936s
#   training loss:		1.597754
#   training accuracy:		24.98 %
#   validation loss:		1.594369
#   validation accuracy:		25.60 %
# Ep 13 	iter 0  	loss 1.59216, train acc 26.40, val acc 26.40
# Ep 13 	iter 1  	loss 1.59855, train acc 26.20, val acc 26.20
# Ep 13 	iter 2  	loss 1.61433, train acc 20.40, val acc 20.40
# Ep 13 	iter 3  	loss 1.60297, train acc 23.00, val acc 23.00
# Ep 13 	iter 4  	loss 1.60667, train acc 22.60, val acc 22.60
# Ep 13 	iter 5  	loss 1.60491, train acc 23.20, val acc 23.20
# Ep 13 	iter 6  	loss 1.60283, train acc 24.60, val acc 24.60
# Ep 13 	iter 7  	loss 1.58830, train acc 27.00, val acc 27.00
# Ep 13 	iter 8  	loss 1.59595, train acc 25.20, val acc 25.20
# Ep 13 	iter 9  	loss 1.60558, train acc 23.60, val acc 23.60
# Ep 13 	iter 10  	loss 1.60034, train acc 24.80, val acc 24.80
# Ep 13 	iter 11  	loss 1.60761, train acc 22.60, val acc 22.60
# Ep 13 	iter 12  	loss 1.60373, train acc 24.40, val acc 24.40
# Ep 13 	iter 13  	loss 1.59291, train acc 26.80, val acc 26.80
# Ep 13 	iter 14  	loss 1.59727, train acc 25.80, val acc 25.80
# Ep 13 	iter 15  	loss 1.58891, train acc 26.60, val acc 26.60
# Ep 13 	iter 16  	loss 1.60644, train acc 22.80, val acc 22.80
# Ep 13 	iter 17  	loss 1.59518, train acc 25.00, val acc 25.00
# Ep 13 	iter 18  	loss 1.58584, train acc 26.40, val acc 26.40
# Ep 13 	iter 19  	loss 1.59109, train acc 25.80, val acc 25.80
# Ep 13 	iter 20  	loss 1.59796, train acc 25.20, val acc 25.20
# Ep 13 	iter 21  	loss 1.60168, train acc 24.80, val acc 24.80
# Ep 13 	iter 22  	loss 1.59525, train acc 26.20, val acc 26.20
# Ep 13 	iter 23  	loss 1.59863, train acc 26.00, val acc 26.00
# Ep 13 	iter 24  	loss 1.59700, train acc 24.20, val acc 24.20
# Ep 13 	iter 25  	loss 1.59170, train acc 27.40, val acc 27.40
# Ep 13 	iter 26  	loss 1.59736, train acc 26.60, val acc 26.60
# Ep 13 	iter 27  	loss 1.59930, train acc 25.60, val acc 25.60
# Ep 13 	iter 28  	loss 1.58520, train acc 27.20, val acc 27.20
# Ep 13 	iter 29  	loss 1.58522, train acc 27.80, val acc 27.80
# Ep 13 	iter 30  	loss 1.62002, train acc 21.80, val acc 21.80
# Ep 13 	iter 31  	loss 1.59622, train acc 25.60, val acc 25.60
# Ep 13 	iter 32  	loss 1.60253, train acc 25.00, val acc 25.00
# Ep 13 	iter 33  	loss 1.60169, train acc 23.00, val acc 23.00
# Ep 13 	iter 34  	loss 1.60334, train acc 23.40, val acc 23.40
# Ep 13 	iter 35  	loss 1.60284, train acc 24.40, val acc 24.40
# Ep 13 	iter 36  	loss 1.60255, train acc 23.60, val acc 23.60
# Ep 13 	iter 37  	loss 1.59311, train acc 25.80, val acc 25.80
# Ep 13 	iter 38  	loss 1.59859, train acc 23.60, val acc 23.60
# Ep 13 	iter 39  	loss 1.60181, train acc 24.20, val acc 24.20
# Ep 13 	iter 40  	loss 1.60493, train acc 23.00, val acc 23.00
# Ep 13 	iter 41  	loss 1.59053, train acc 27.20, val acc 27.20
# Ep 13 	iter 42  	loss 1.59341, train acc 26.00, val acc 26.00
# Ep 13 	iter 43  	loss 1.59433, train acc 25.00, val acc 25.00
# Ep 13 	iter 44  	loss 1.59292, train acc 28.20, val acc 28.20
# Ep 13 	iter 45  	loss 1.59150, train acc 23.40, val acc 23.40
# Ep 13 	iter 46  	loss 1.59313, train acc 25.80, val acc 25.80
# Ep 13 	iter 47  	loss 1.58478, train acc 26.00, val acc 26.00
# Epoch 14 of 20 took 366.791s
#   training loss:		1.597898
#   training accuracy:		24.98 %
#   validation loss:		1.583943
#   validation accuracy:		26.00 %
# Ep 14 	iter 0  	loss 1.60499, train acc 22.80, val acc 22.80
# Ep 14 	iter 1  	loss 1.59696, train acc 22.40, val acc 22.40
# Ep 14 	iter 2  	loss 1.60407, train acc 25.80, val acc 25.80
# Ep 14 	iter 3  	loss 1.60011, train acc 24.80, val acc 24.80
# Ep 14 	iter 4  	loss 1.59496, train acc 26.40, val acc 26.40
# Ep 14 	iter 5  	loss 1.60468, train acc 25.00, val acc 25.00
# Ep 14 	iter 6  	loss 1.60288, train acc 24.40, val acc 24.40
# Ep 14 	iter 7  	loss 1.60004, train acc 25.20, val acc 25.20
# Ep 14 	iter 8  	loss 1.60215, train acc 25.20, val acc 25.20
# Ep 14 	iter 9  	loss 1.59038, train acc 26.80, val acc 26.80
# Ep 14 	iter 10  	loss 1.59914, train acc 24.40, val acc 24.40
# Ep 14 	iter 11  	loss 1.59180, train acc 26.20, val acc 26.20
# Ep 14 	iter 12  	loss 1.59265, train acc 29.20, val acc 29.20
# Ep 14 	iter 13  	loss 1.59245, train acc 24.80, val acc 24.80
# Ep 14 	iter 14  	loss 1.59379, train acc 26.20, val acc 26.20
# Ep 14 	iter 15  	loss 1.59576, train acc 26.80, val acc 26.80
# Ep 14 	iter 16  	loss 1.60435, train acc 24.40, val acc 24.40
# Ep 14 	iter 17  	loss 1.59653, train acc 25.40, val acc 25.40
# Ep 14 	iter 18  	loss 1.59133, train acc 25.00, val acc 25.00
# Ep 14 	iter 19  	loss 1.59852, train acc 25.40, val acc 25.40
# Ep 14 	iter 20  	loss 1.61407, train acc 19.60, val acc 19.60
# Ep 14 	iter 21  	loss 1.59252, train acc 27.60, val acc 27.60
# Ep 14 	iter 22  	loss 1.59554, train acc 25.80, val acc 25.80
# Ep 14 	iter 23  	loss 1.58764, train acc 27.60, val acc 27.60
# Ep 14 	iter 24  	loss 1.59236, train acc 25.00, val acc 25.00
# Ep 14 	iter 25  	loss 1.61302, train acc 22.60, val acc 22.60
# Ep 14 	iter 26  	loss 1.59093, train acc 26.00, val acc 26.00
# Ep 14 	iter 27  	loss 1.59415, train acc 22.80, val acc 22.80
# Ep 14 	iter 28  	loss 1.60012, train acc 23.60, val acc 23.60
# Ep 14 	iter 29  	loss 1.58806, train acc 27.00, val acc 27.00
# Ep 14 	iter 30  	loss 1.59565, train acc 26.00, val acc 26.00
# Ep 14 	iter 31  	loss 1.60042, train acc 23.00, val acc 23.00
# Ep 14 	iter 32  	loss 1.59872, train acc 28.20, val acc 28.20
# Ep 14 	iter 33  	loss 1.60002, train acc 26.40, val acc 26.40
# Ep 14 	iter 34  	loss 1.60066, train acc 21.80, val acc 21.80
# Ep 14 	iter 35  	loss 1.60622, train acc 21.40, val acc 21.40
# Ep 14 	iter 36  	loss 1.60846, train acc 22.20, val acc 22.20
# Ep 14 	iter 37  	loss 1.59921, train acc 23.80, val acc 23.80
# Ep 14 	iter 38  	loss 1.60291, train acc 21.60, val acc 21.60
# Ep 14 	iter 39  	loss 1.59760, train acc 26.60, val acc 26.60
# Ep 14 	iter 40  	loss 1.58803, train acc 27.80, val acc 27.80
# Ep 14 	iter 41  	loss 1.60201, train acc 24.40, val acc 24.40
# Ep 14 	iter 42  	loss 1.59110, train acc 27.20, val acc 27.20
# Ep 14 	iter 43  	loss 1.59841, train acc 25.00, val acc 25.00
# Ep 14 	iter 44  	loss 1.59645, train acc 24.60, val acc 24.60
# Ep 14 	iter 45  	loss 1.59981, train acc 23.00, val acc 23.00
# Ep 14 	iter 46  	loss 1.59163, train acc 27.20, val acc 27.20
# Ep 14 	iter 47  	loss 1.60778, train acc 24.80, val acc 24.80
# Epoch 15 of 20 took 362.071s
#   training loss:		1.598147
#   training accuracy:		24.98 %
#   validation loss:		1.607138
#   validation accuracy:		24.80 %
# Ep 15 	iter 0  	loss 1.61316, train acc 21.20, val acc 21.20
# Ep 15 	iter 1  	loss 1.58548, train acc 26.80, val acc 26.80
# Ep 15 	iter 2  	loss 1.59525, train acc 26.20, val acc 26.20
# Ep 15 	iter 3  	loss 1.60197, train acc 24.00, val acc 24.00
# Ep 15 	iter 4  	loss 1.59324, train acc 26.80, val acc 26.80
# Ep 15 	iter 5  	loss 1.59004, train acc 28.80, val acc 28.80
# Ep 15 	iter 6  	loss 1.61168, train acc 21.80, val acc 21.80
# Ep 15 	iter 7  	loss 1.59778, train acc 26.20, val acc 26.20
# Ep 15 	iter 8  	loss 1.60316, train acc 23.40, val acc 23.40
# Ep 15 	iter 9  	loss 1.59941, train acc 23.20, val acc 23.20
# Ep 15 	iter 10  	loss 1.59772, train acc 24.80, val acc 24.80
# Ep 15 	iter 11  	loss 1.59971, train acc 23.80, val acc 23.80
# Ep 15 	iter 12  	loss 1.60575, train acc 23.40, val acc 23.40
# Ep 15 	iter 13  	loss 1.60263, train acc 25.20, val acc 25.20
# Ep 15 	iter 14  	loss 1.60784, train acc 22.60, val acc 22.60
# Ep 15 	iter 15  	loss 1.58698, train acc 27.60, val acc 27.60
# Ep 15 	iter 16  	loss 1.60105, train acc 24.20, val acc 24.20
# Ep 15 	iter 17  	loss 1.59985, train acc 24.20, val acc 24.20
# Ep 15 	iter 18  	loss 1.59967, train acc 24.80, val acc 24.80
# Ep 15 	iter 19  	loss 1.59297, train acc 24.60, val acc 24.60
# Ep 15 	iter 20  	loss 1.60092, train acc 24.00, val acc 24.00
# Ep 15 	iter 21  	loss 1.58311, train acc 29.20, val acc 29.20
# Ep 15 	iter 22  	loss 1.59831, train acc 26.20, val acc 26.20
# Ep 15 	iter 23  	loss 1.58799, train acc 26.20, val acc 26.20
# Ep 15 	iter 24  	loss 1.60395, train acc 23.80, val acc 23.80
# Ep 15 	iter 25  	loss 1.59701, train acc 26.80, val acc 26.80
# Ep 15 	iter 26  	loss 1.58584, train acc 28.20, val acc 28.20
# Ep 15 	iter 27  	loss 1.59365, train acc 23.80, val acc 23.80
# Ep 15 	iter 28  	loss 1.59185, train acc 28.20, val acc 28.20
# Ep 15 	iter 29  	loss 1.59315, train acc 27.20, val acc 27.20
# Ep 15 	iter 30  	loss 1.60406, train acc 23.80, val acc 23.80
# Ep 15 	iter 31  	loss 1.60789, train acc 24.00, val acc 24.00
# Ep 15 	iter 32  	loss 1.59659, train acc 24.40, val acc 24.40
# Ep 15 	iter 33  	loss 1.58962, train acc 25.40, val acc 25.40
# Ep 15 	iter 34  	loss 1.59597, train acc 25.60, val acc 25.60
# Ep 15 	iter 35  	loss 1.60298, train acc 23.00, val acc 23.00
# Ep 15 	iter 36  	loss 1.60451, train acc 23.80, val acc 23.80
# Ep 15 	iter 37  	loss 1.60498, train acc 23.80, val acc 23.80
# Ep 15 	iter 38  	loss 1.59129, train acc 26.40, val acc 26.40
# Ep 15 	iter 39  	loss 1.59590, train acc 28.20, val acc 28.20
# Ep 15 	iter 40  	loss 1.60451, train acc 23.60, val acc 23.60
# Ep 15 	iter 41  	loss 1.58956, train acc 27.40, val acc 27.40
# Ep 15 	iter 42  	loss 1.59121, train acc 27.80, val acc 27.80
# Ep 15 	iter 43  	loss 1.60204, train acc 21.80, val acc 21.80
# Ep 15 	iter 44  	loss 1.60547, train acc 21.60, val acc 21.60
# Ep 15 	iter 45  	loss 1.60697, train acc 23.60, val acc 23.60
# Ep 15 	iter 46  	loss 1.61038, train acc 24.20, val acc 24.20
# Ep 15 	iter 47  	loss 1.59898, train acc 23.60, val acc 23.60
# Epoch 16 of 20 took 361.695s
#   training loss:		1.598417
#   training accuracy:		24.98 %
#   validation loss:		1.598724
#   validation accuracy:		23.60 %
# Ep 16 	iter 0  	loss 1.60218, train acc 23.40, val acc 23.40
# Ep 16 	iter 1  	loss 1.59980, train acc 25.00, val acc 25.00
# Ep 16 	iter 2  	loss 1.59819, train acc 25.60, val acc 25.60
# Ep 16 	iter 3  	loss 1.60514, train acc 23.20, val acc 23.20
# Ep 16 	iter 4  	loss 1.60562, train acc 22.00, val acc 22.00
# Ep 16 	iter 5  	loss 1.59961, train acc 27.00, val acc 27.00
# Ep 16 	iter 6  	loss 1.60090, train acc 25.80, val acc 25.80
# Ep 16 	iter 7  	loss 1.60090, train acc 23.20, val acc 23.20
# Ep 16 	iter 8  	loss 1.60371, train acc 23.00, val acc 23.00
# Ep 16 	iter 9  	loss 1.60296, train acc 23.40, val acc 23.40
# Ep 16 	iter 10  	loss 1.59725, train acc 24.40, val acc 24.40
# Ep 16 	iter 11  	loss 1.60163, train acc 25.00, val acc 25.00
# Ep 16 	iter 12  	loss 1.60222, train acc 23.60, val acc 23.60
# Ep 16 	iter 13  	loss 1.59589, train acc 25.00, val acc 25.00
# Ep 16 	iter 14  	loss 1.59645, train acc 25.00, val acc 25.00
# Ep 16 	iter 15  	loss 1.60075, train acc 22.40, val acc 22.40
# Ep 16 	iter 16  	loss 1.60200, train acc 23.40, val acc 23.40
# Ep 16 	iter 17  	loss 1.59610, train acc 24.80, val acc 24.80
# Ep 16 	iter 18  	loss 1.60986, train acc 20.60, val acc 20.60
# Ep 16 	iter 19  	loss 1.60200, train acc 24.60, val acc 24.60
# Ep 16 	iter 20  	loss 1.59351, train acc 25.80, val acc 25.80
# Ep 16 	iter 21  	loss 1.59699, train acc 22.80, val acc 22.80
# Ep 16 	iter 22  	loss 1.59337, train acc 29.20, val acc 29.20
# Ep 16 	iter 23  	loss 1.59652, train acc 24.80, val acc 24.80
# Ep 16 	iter 24  	loss 1.59186, train acc 26.20, val acc 26.20
# Ep 16 	iter 25  	loss 1.59313, train acc 27.20, val acc 27.20
# Ep 16 	iter 26  	loss 1.59257, train acc 26.40, val acc 26.40
# Ep 16 	iter 27  	loss 1.59728, train acc 24.20, val acc 24.20
# Ep 16 	iter 28  	loss 1.59399, train acc 22.40, val acc 22.40
# Ep 16 	iter 29  	loss 1.58985, train acc 25.60, val acc 25.60
# Ep 16 	iter 30  	loss 1.59485, train acc 26.20, val acc 26.20
# Ep 16 	iter 31  	loss 1.59505, train acc 24.00, val acc 24.00
# Ep 16 	iter 32  	loss 1.58894, train acc 28.20, val acc 28.20
# Ep 16 	iter 33  	loss 1.59653, train acc 23.60, val acc 23.60
# Ep 16 	iter 34  	loss 1.59374, train acc 26.40, val acc 26.40
# Ep 16 	iter 35  	loss 1.59762, train acc 27.20, val acc 27.20
# Ep 16 	iter 36  	loss 1.59049, train acc 27.20, val acc 27.20
# Ep 16 	iter 37  	loss 1.59345, train acc 25.00, val acc 25.00
# Ep 16 	iter 38  	loss 1.60555, train acc 22.80, val acc 22.80
# Ep 16 	iter 39  	loss 1.60379, train acc 25.20, val acc 25.20
# Ep 16 	iter 40  	loss 1.59837, train acc 25.40, val acc 25.40
# Ep 16 	iter 41  	loss 1.59590, train acc 28.20, val acc 28.20
# Ep 16 	iter 42  	loss 1.58216, train acc 26.80, val acc 26.80
# Ep 16 	iter 43  	loss 1.59747, train acc 24.20, val acc 24.20
# Ep 16 	iter 44  	loss 1.59371, train acc 28.20, val acc 28.20
# Ep 16 	iter 45  	loss 1.60068, train acc 25.00, val acc 25.00
# Ep 16 	iter 46  	loss 1.59631, train acc 25.80, val acc 25.80
# Ep 16 	iter 47  	loss 1.59432, train acc 24.80, val acc 24.80
# Epoch 17 of 20 took 392.349s
#   training loss:		1.597524
#   training accuracy:		24.98 %
#   validation loss:		1.594095
#   validation accuracy:		24.80 %
# Ep 17 	iter 0  	loss 1.60310, train acc 22.00, val acc 22.00
# Ep 17 	iter 1  	loss 1.58343, train acc 27.80, val acc 27.80
# Ep 17 	iter 2  	loss 1.60095, train acc 24.00, val acc 24.00
# Ep 17 	iter 3  	loss 1.60049, train acc 22.60, val acc 22.60
# Ep 17 	iter 4  	loss 1.59630, train acc 27.40, val acc 27.40
# Ep 17 	iter 5  	loss 1.59730, train acc 24.40, val acc 24.40
# Ep 17 	iter 6  	loss 1.60229, train acc 23.40, val acc 23.40
# Ep 17 	iter 7  	loss 1.59364, train acc 25.00, val acc 25.00
# Ep 17 	iter 8  	loss 1.60320, train acc 23.80, val acc 23.80
# Ep 17 	iter 9  	loss 1.60353, train acc 22.80, val acc 22.80
# Ep 17 	iter 10  	loss 1.60213, train acc 24.80, val acc 24.80
# Ep 17 	iter 11  	loss 1.60111, train acc 24.60, val acc 24.60
# Ep 17 	iter 12  	loss 1.59293, train acc 26.40, val acc 26.40
# Ep 17 	iter 13  	loss 1.59578, train acc 24.80, val acc 24.80
# Ep 17 	iter 14  	loss 1.60851, train acc 25.20, val acc 25.20
# Ep 17 	iter 15  	loss 1.60565, train acc 25.60, val acc 25.60
# Ep 17 	iter 16  	loss 1.60164, train acc 26.40, val acc 26.40
# Ep 17 	iter 17  	loss 1.59264, train acc 25.40, val acc 25.40
# Ep 17 	iter 18  	loss 1.60145, train acc 24.00, val acc 24.00
# Ep 17 	iter 19  	loss 1.60068, train acc 23.40, val acc 23.40
# Ep 17 	iter 20  	loss 1.58845, train acc 27.00, val acc 27.00
# Ep 17 	iter 21  	loss 1.59110, train acc 27.60, val acc 27.60
# Ep 17 	iter 22  	loss 1.59496, train acc 25.80, val acc 25.80
# Ep 17 	iter 23  	loss 1.60827, train acc 22.20, val acc 22.20
# Ep 17 	iter 24  	loss 1.60378, train acc 22.60, val acc 22.60
# Ep 17 	iter 25  	loss 1.59634, train acc 25.00, val acc 25.00
# Ep 17 	iter 26  	loss 1.59873, train acc 24.20, val acc 24.20
# Ep 17 	iter 27  	loss 1.59452, train acc 26.60, val acc 26.60
# Ep 17 	iter 28  	loss 1.59583, train acc 26.40, val acc 26.40
# Ep 17 	iter 29  	loss 1.60042, train acc 24.80, val acc 24.80
# Ep 17 	iter 30  	loss 1.60714, train acc 22.00, val acc 22.00
# Ep 17 	iter 31  	loss 1.59595, train acc 25.20, val acc 25.20
# Ep 17 	iter 32  	loss 1.59415, train acc 26.80, val acc 26.80
# Ep 17 	iter 33  	loss 1.59293, train acc 25.40, val acc 25.40
# Ep 17 	iter 34  	loss 1.58958, train acc 26.60, val acc 26.60
# Ep 17 	iter 35  	loss 1.60472, train acc 25.20, val acc 25.20
# Ep 17 	iter 36  	loss 1.59568, train acc 25.60, val acc 25.60
# Ep 17 	iter 37  	loss 1.59881, train acc 26.60, val acc 26.60
# Ep 17 	iter 38  	loss 1.59787, train acc 23.80, val acc 23.80
# Ep 17 	iter 39  	loss 1.59572, train acc 25.80, val acc 25.80
# Ep 17 	iter 40  	loss 1.60160, train acc 25.20, val acc 25.20
# Ep 17 	iter 41  	loss 1.60078, train acc 24.20, val acc 24.20
# Ep 17 	iter 42  	loss 1.59779, train acc 27.20, val acc 27.20
# Ep 17 	iter 43  	loss 1.59300, train acc 24.00, val acc 24.00
# Ep 17 	iter 44  	loss 1.59716, train acc 24.00, val acc 24.00
# Ep 17 	iter 45  	loss 1.59710, train acc 25.60, val acc 25.60
# Ep 17 	iter 46  	loss 1.59664, train acc 26.80, val acc 26.80
# Ep 17 	iter 47  	loss 1.60400, train acc 23.20, val acc 23.20
# Epoch 18 of 20 took 450.570s
#   training loss:		1.598329
#   training accuracy:		24.98 %
#   validation loss:		1.603557
#   validation accuracy:		23.20 %
# Ep 18 	iter 0  	loss 1.58946, train acc 26.60, val acc 26.60
# Ep 18 	iter 1  	loss 1.61462, train acc 21.80, val acc 21.80
# Ep 18 	iter 2  	loss 1.59680, train acc 26.00, val acc 26.00
# Ep 18 	iter 3  	loss 1.59449, train acc 25.40, val acc 25.40
# Ep 18 	iter 4  	loss 1.59953, train acc 23.60, val acc 23.60
# Ep 18 	iter 5  	loss 1.58973, train acc 29.20, val acc 29.20
# Ep 18 	iter 6  	loss 1.59910, train acc 24.00, val acc 24.00
# Ep 18 	iter 7  	loss 1.59523, train acc 26.20, val acc 26.20
# Ep 18 	iter 8  	loss 1.60434, train acc 22.60, val acc 22.60
# Ep 18 	iter 9  	loss 1.60173, train acc 23.00, val acc 23.00
# Ep 18 	iter 10  	loss 1.59220, train acc 27.80, val acc 27.80
# Ep 18 	iter 11  	loss 1.58830, train acc 26.80, val acc 26.80
# Ep 18 	iter 12  	loss 1.60934, train acc 22.40, val acc 22.40
# Ep 18 	iter 13  	loss 1.60164, train acc 27.20, val acc 27.20
# Ep 18 	iter 14  	loss 1.59451, train acc 26.80, val acc 26.80
# Ep 18 	iter 15  	loss 1.59699, train acc 25.40, val acc 25.40
# Ep 18 	iter 16  	loss 1.59510, train acc 24.80, val acc 24.80
# Ep 18 	iter 17  	loss 1.60597, train acc 22.80, val acc 22.80
# Ep 18 	iter 18  	loss 1.60000, train acc 23.80, val acc 23.80
# Ep 18 	iter 19  	loss 1.59001, train acc 27.40, val acc 27.40
# Ep 18 	iter 20  	loss 1.60088, train acc 24.20, val acc 24.20
# Ep 18 	iter 21  	loss 1.60217, train acc 25.20, val acc 25.20
# Ep 18 	iter 22  	loss 1.59985, train acc 24.20, val acc 24.20
# Ep 18 	iter 23  	loss 1.59364, train acc 26.20, val acc 26.20
# Ep 18 	iter 24  	loss 1.59353, train acc 23.40, val acc 23.40
# Ep 18 	iter 25  	loss 1.58902, train acc 27.00, val acc 27.00
# Ep 18 	iter 26  	loss 1.59924, train acc 24.60, val acc 24.60
# Ep 18 	iter 27  	loss 1.59360, train acc 25.20, val acc 25.20
# Ep 18 	iter 28  	loss 1.59743, train acc 25.40, val acc 25.40
# Ep 18 	iter 29  	loss 1.60747, train acc 22.80, val acc 22.80
# Ep 18 	iter 30  	loss 1.59335, train acc 28.60, val acc 28.60
# Ep 18 	iter 31  	loss 1.59884, train acc 22.80, val acc 22.80
# Ep 18 	iter 32  	loss 1.59073, train acc 27.40, val acc 27.40
# Ep 18 	iter 33  	loss 1.60910, train acc 22.40, val acc 22.40
# Ep 18 	iter 34  	loss 1.59228, train acc 25.40, val acc 25.40
# Ep 18 	iter 35  	loss 1.60006, train acc 25.20, val acc 25.20
# Ep 18 	iter 36  	loss 1.60984, train acc 22.80, val acc 22.80
# Ep 18 	iter 37  	loss 1.58400, train acc 26.80, val acc 26.80
# Ep 18 	iter 38  	loss 1.59533, train acc 25.40, val acc 25.40
# Ep 18 	iter 39  	loss 1.60750, train acc 21.80, val acc 21.80
# Ep 18 	iter 40  	loss 1.59057, train acc 25.20, val acc 25.20
# Ep 18 	iter 41  	loss 1.60046, train acc 23.40, val acc 23.40
# Ep 18 	iter 42  	loss 1.60438, train acc 24.20, val acc 24.20
# Ep 18 	iter 43  	loss 1.59253, train acc 25.60, val acc 25.60
# Ep 18 	iter 44  	loss 1.60776, train acc 23.00, val acc 23.00
# Ep 18 	iter 45  	loss 1.59369, train acc 26.20, val acc 26.20
# Ep 18 	iter 46  	loss 1.59198, train acc 26.40, val acc 26.40
# Ep 18 	iter 47  	loss 1.58883, train acc 24.80, val acc 24.80
# Epoch 19 of 20 took 404.022s
#   training loss:		1.597649
#   training accuracy:		24.98 %
#   validation loss:		1.588484
#   validation accuracy:		24.80 %
# Ep 19 	iter 0  	loss 1.58925, train acc 27.40, val acc 27.40
# Ep 19 	iter 1  	loss 1.59368, train acc 25.80, val acc 25.80
# Ep 19 	iter 2  	loss 1.60807, train acc 23.20, val acc 23.20
# Ep 19 	iter 3  	loss 1.59478, train acc 25.20, val acc 25.20
# Ep 19 	iter 4  	loss 1.59192, train acc 26.00, val acc 26.00
# Ep 19 	iter 5  	loss 1.59379, train acc 26.40, val acc 26.40
# Ep 19 	iter 6  	loss 1.59021, train acc 28.20, val acc 28.20
# Ep 19 	iter 7  	loss 1.59451, train acc 24.80, val acc 24.80
# Ep 19 	iter 8  	loss 1.59632, train acc 25.60, val acc 25.60
# Ep 19 	iter 9  	loss 1.59721, train acc 27.80, val acc 27.80
# Ep 19 	iter 10  	loss 1.58567, train acc 26.20, val acc 26.20
# Ep 19 	iter 11  	loss 1.59296, train acc 24.60, val acc 24.60
# Ep 19 	iter 12  	loss 1.59975, train acc 24.40, val acc 24.40
# Ep 19 	iter 13  	loss 1.61513, train acc 22.00, val acc 22.00
# Ep 19 	iter 14  	loss 1.60980, train acc 22.20, val acc 22.20
# Ep 19 	iter 15  	loss 1.60028, train acc 22.40, val acc 22.40
# Ep 19 	iter 16  	loss 1.59756, train acc 26.40, val acc 26.40
# Ep 19 	iter 17  	loss 1.60881, train acc 21.60, val acc 21.60
# Ep 19 	iter 18  	loss 1.58614, train acc 26.00, val acc 26.00
# Ep 19 	iter 19  	loss 1.59241, train acc 26.60, val acc 26.60
# Ep 19 	iter 20  	loss 1.58542, train acc 27.60, val acc 27.60
# Ep 19 	iter 21  	loss 1.60046, train acc 24.20, val acc 24.20
# Ep 19 	iter 22  	loss 1.59385, train acc 24.60, val acc 24.60
# Ep 19 	iter 23  	loss 1.60416, train acc 23.40, val acc 23.40
# Ep 19 	iter 24  	loss 1.61286, train acc 23.20, val acc 23.20
# Ep 19 	iter 25  	loss 1.59935, train acc 23.20, val acc 23.20
# Ep 19 	iter 26  	loss 1.59552, train acc 23.80, val acc 23.80
# Ep 19 	iter 27  	loss 1.61075, train acc 22.40, val acc 22.40
# Ep 19 	iter 28  	loss 1.60603, train acc 24.20, val acc 24.20
# Ep 19 	iter 29  	loss 1.59982, train acc 25.00, val acc 25.00
# Ep 19 	iter 30  	loss 1.60656, train acc 23.60, val acc 23.60
# Ep 19 	iter 31  	loss 1.60276, train acc 23.00, val acc 23.00
# Ep 19 	iter 32  	loss 1.60435, train acc 24.00, val acc 24.00
# Ep 19 	iter 33  	loss 1.59083, train acc 27.20, val acc 27.20
# Ep 19 	iter 34  	loss 1.60453, train acc 24.00, val acc 24.00
# Ep 19 	iter 35  	loss 1.59305, train acc 27.80, val acc 27.80
# Ep 19 	iter 36  	loss 1.58324, train acc 28.80, val acc 28.80
# Ep 19 	iter 37  	loss 1.59758, train acc 24.60, val acc 24.60
# Ep 19 	iter 38  	loss 1.59152, train acc 26.20, val acc 26.20
# Ep 19 	iter 39  	loss 1.60137, train acc 24.60, val acc 24.60
# Ep 19 	iter 40  	loss 1.59757, train acc 26.40, val acc 26.40
# Ep 19 	iter 41  	loss 1.59257, train acc 26.20, val acc 26.20
# Ep 19 	iter 42  	loss 1.59302, train acc 25.80, val acc 25.80
# Ep 19 	iter 43  	loss 1.59200, train acc 25.80, val acc 25.80
# Ep 19 	iter 44  	loss 1.60148, train acc 25.00, val acc 25.00
# Ep 19 	iter 45  	loss 1.59866, train acc 24.20, val acc 24.20
# Ep 19 	iter 46  	loss 1.61279, train acc 22.60, val acc 22.60
# Ep 19 	iter 47  	loss 1.59994, train acc 25.00, val acc 25.00
# Epoch 20 of 20 took 368.218s
#   training loss:		1.598131
#   training accuracy:		24.98 %
#   validation loss:		1.599807
#   validation accuracy:		25.00 %
# Training finished!

# %%
# Testing.
print('Testing...')
test_err = 0
test_acc = 0
test_batches = 0
for batch in data_utils.iterate_minibatches(X_test, y_test, batchsize, shuffle=False):
    inputs, targets = batch
    err, acc = val_fn(inputs, targets)
    test_err += err
    test_acc += acc
    test_batches += 1
    
print("Final results:")
print("  test loss:\t\t\t{:.6f}".format(test_err / test_batches))
print("  test accuracy:\t\t{:.2f} %".format(
    test_acc / test_batches * 100))
# Out:
# Testing...
# Final results:
#   test loss:			1.601944
#   test accuracy:		23.40 %

# %%
# Visualize the loss and the accuracies for both training and validation sets for each iteration
num_train = X_train.shape[0]
if record_per_iter:
    xlabel = "iterations"
else:
    xlabel = "epochs"
# Printing training losses and training + validation accuracies
data_set_name = DATA_SET + 'batch_' + str(USE_BATCH) + '_' + USE_OPTIMIZER
visualize.plot_loss_acc(data_set_name, train_err_list, train_acc_list, val_acc_list, LEARNING_RATE, reg_strength, num_epochs, num_train, xlabel=xlabel)

# %%
# Visualize the loss and the accuracies for both training and validation sets for each epoch
num_train = X_train.shape[0]
xlabel = "epochs"
# Printing training losses and training + validation accuracies
data_set_name = DATA_SET + 'batch_' + str(USE_BATCH) + '_on_epochs' + '_' + USE_OPTIMIZER
visualize.plot_loss_acc(data_set_name, epochs_train_err_list, epochs_train_acc_list, epochs_val_acc_list, LEARNING_RATE, reg_strength, num_epochs, num_train, xlabel=xlabel)

# %%
# Visualize the VAL loss (instead of train) and the accuracies for both training and validation sets for each iteration
num_train = X_train.shape[0]
if record_per_iter:
    xlabel = "iterations"
else:
    xlabel = "epochs"
# Printing training losses and training + validation accuracies
data_set_name = DATA_SET + 'batch_' + str(USE_BATCH) + '_' + USE_OPTIMIZER + '_val_loss'
visualize.plot_loss_acc(data_set_name, val_err_list, train_acc_list, val_acc_list, LEARNING_RATE, reg_strength, num_epochs, num_train, xlabel=xlabel)

# %%
# Visualize the VAL loss (instead of train) and the accuracies for both training and validation sets for each epoch
num_train = X_train.shape[0]
xlabel = "epochs"
# Printing training losses and training + validation accuracies
data_set_name = DATA_SET + 'batch_' + str(USE_BATCH) + '_on_epochs' + '_' + USE_OPTIMIZER + '_val_loss'
visualize.plot_loss_acc(data_set_name, epochs_val_err_list, epochs_train_acc_list, epochs_val_acc_list, LEARNING_RATE, reg_strength, num_epochs, num_train, xlabel=xlabel)
