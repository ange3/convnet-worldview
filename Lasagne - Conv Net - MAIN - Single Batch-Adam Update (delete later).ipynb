# %% [markdown]
# # Lasagne Conv Net on Media Eval 2015 Placing Task - Locale

# %%
# Import Python libraries
import numpy as np
import theano
import theano.tensor as Tensor
import lasagne
import time

# allows plots to show inline in ipython notebook
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
# Import own modules
import data_utils, visualize
import lasagne_model_predict_country as cnn_model

# %%
# Model hyperparameters
cnn_architecture = "complex_cnn"
num_filters = 32
filter_width = 3 # can be integer or tuple
pool_width = 2 
stride_width = 1 # can be integer or tuple
padding = 'full'  # can be integer or tuple or 'full', 'same', 'valid'
hidden_size = 256 # size of hidden layer of neurons
dropout_p = 0.0
# lr_decay = 0.995
reg_strength = 0
# grad_clip = 10

# Optimization hyperparams
# LEARNING_RATE = 1e-2
LEARNING_RATE = 0.045

# USE_OPTIMIZER = "nesterov_momentum"
USE_OPTIMIZER = "adam"
# (1) Nesterov Momentum
MOMENTUM = 0.9
# (2) Adam
beta1=0.9
beta2=0.999
epsilon=1e-08
# Optimizer config
theano.config.optimizer='fast_compile'
theano.config.exception_verbosity='high'

# Training parameters
batchsize = 500
num_epochs = 10
record_per_iter = True  # save train and val loss/accuracy after each batch runthrough

# %%
# Load Data Set

# DATA_BATCH = '000_small_'
# DATA_SIZE = '48by32'
# DATA_SET = DATA_BATCH + DATA_SIZE
# NUM_CLASSES = 5

DATA_SET = 'subset_48by32_5'
NUM_CLASSES = 5
NUM_BATCHES = 6
USE_BATCH = 0

print ('Data Set:', DATA_SET)
print ('Num classes:', NUM_CLASSES)
print ('Batches: {}'.format(USE_BATCH))
print ('Preparing Data Set....')

X_input_filename = 'data_maps/' + DATA_SET + '/x_input_' + str(USE_BATCH) + '.npy'
Y_output_filename = 'data_maps/' + DATA_SET + '/y_labels_' + str(USE_BATCH) + '.npy'

X = data_utils.load_npy_file(X_input_filename)
Y = data_utils.load_npy_file(Y_output_filename)
# print 'X: {}'.format(X.shape)
# print 'Y: {}'.format(Y.shape)
# print 'Y sample ', Y[:10]

num_samples, H, W, C = X.shape

# swap C and H axes --> expected input
X = np.swapaxes(X, 1, 3)  # (num_samples, C, W, H)
X -= np.mean(X, axis = 0)  # Data Preprocessing: mean subtraction
X /= np.std(X, axis = 0)  # Normalization

#Splitting into train, val, test sets

num_train = int(num_samples * 0.8)
num_val = int(num_samples * 0.1)
num_test = num_samples - num_train - num_val

# print 'num_train: %d, num_val: %d, num_test: %d' % (num_train, num_val, num_test)

X_train = X[:num_train]
X_val = X[num_train:num_train+num_val]
X_test = X[num_train+num_val:]

y_train = Y[:num_train]
y_val = Y[num_train:num_train+num_val]
y_test = Y[num_train+num_val:]

print ('X_train', X_train.shape)
print ('y_train', y_train.shape)
print ('X_val', X_val.shape)
print ('y_val', y_val.shape)
print ('X_test', X_test.shape)
print ('y_test', y_test.shape)
# Out:
# ('Data Set:', 'subset_48by32_5')
# ('Num classes:', 5)
# Batches: 0
# Preparing Data Set....
# ('X_train', (24000, 3, 48, 32))
# ('y_train', (24000,))
# ('X_val', (3000, 3, 48, 32))
# ('y_val', (3000,))
# ('X_test', (3000, 3, 48, 32))
# ('y_test', (3000,))

# %%
# Prepare Theano variables for inputs and targets
input_var = Tensor.tensor4('inputs')
target_var = Tensor.ivector('targets')

print('Building network...')

# Create neural network model
l_in, l_out = cnn_model.build_cnn(C, W, H, NUM_CLASSES, cnn_architecture=cnn_architecture, num_filters=num_filters, filter_width=filter_width, pool_width=pool_width, stride=stride_width, pad=padding, hidden_size=hidden_size, dropout=dropout_p, inputVar = input_var)

print('Compiling functions...')

# Create a loss expression for training, i.e., a scalar objective we want
    # to minimize (for our multi-class problem, it is the cross-entropy loss):
prediction = lasagne.layers.get_output(l_out)
loss = Tensor.nnet.categorical_crossentropy(prediction, target_var)
# loss = lasagne.objectives.categorical_crossentropy(prediction, target_var)
loss = loss.mean()
acc = Tensor.mean(Tensor.eq(Tensor.argmax(prediction, axis=1), target_var),
                  dtype=theano.config.floatX)

# Return predictions in a function
pred_fn = theano.function([l_in.input_var], prediction)

 # Create update expressions for training, i.e., how to modify the
# parameters at each training step. Here, we'll use Stochastic Gradient
# Descent (SGD) with Nesterov momentum, but Lasagne offers plenty more.
params = lasagne.layers.get_all_params(l_out, trainable=True)
if USE_OPTIMIZER == "nesterov_momentum":
    updates = lasagne.updates.nesterov_momentum(
        loss, params, learning_rate=LEARNING_RATE, momentum=MOMENTUM)
elif USE_OPTIMIZER == "adam":
    updates = lasagne.updates.adam(
        loss, params, learning_rate=LEARNING_RATE, beta1=beta1, beta2=beta2, epsilon=epsilon)
else:   # default is nesterov momentum
    updates = lasagne.updates.nesterov_momentum(
        loss, params, learning_rate=LEARNING_RATE, momentum=MOMENTUM)
    
# Create a loss expression for validation/testing. The crucial difference
# here is that we do a deterministic forward pass through the network,
# disabling dropout layers.
test_prediction = lasagne.layers.get_output(l_out, deterministic=True)
# test_loss = lasagne.objectives.categorical_crossentropy(test_prediction, target_var)
test_loss = Tensor.nnet.categorical_crossentropy(test_prediction, target_var)

test_loss = test_loss.mean()
# As a bonus, also create an expression for the classification accuracy:
test_acc = Tensor.mean(Tensor.eq(Tensor.argmax(test_prediction, axis=1), target_var),
                  dtype=theano.config.floatX)

 # Compile a function performing a training step on a mini-batch (by giving
# the updates dictionary) and returning the corresponding training loss:
train_fn = theano.function([input_var, target_var], [loss, acc], updates=updates)
# train_fn = theano.function([input_var, target_var], loss, updates=updates)

# Compile a second function computing the validation loss and accuracy:
val_fn = theano.function([input_var, target_var], [test_loss, test_acc])

print('Compiling Finished!')
# Out:
# Building network...
# Building a complex CNN...
# Compiling functions...
# Using optimizer: adam
# Compiling Finished!

# %%
# Finally, launch the training loop.
print ( 'Training on: {} epochs of batch size {} with num training samples {}'.format(num_epochs,batchsize,num_train) )
print ('Using optimizer: {}'.format(USE_OPTIMIZER))
print ("Validation Size: {}".format(num_val) )
print("Starting training...")

# Data structures to store error and accuracy values
train_err_list = []
val_err_list = []
train_acc_list = []
val_acc_list = []

epochs_train_err_list = []
epochs_train_acc_list = []
epochs_val_err_list = []
epochs_val_acc_list = []

# We iterate over epochs:

for epoch in range(num_epochs):
    # 1) In each epoch, we do a full pass over the training data:
    train_err = 0
    train_acc = 0
    train_batches = 0
    start_time = time.time()
    
    # Each batch is 1 iteration
    num_iters = 0
    for batch in data_utils.iterate_minibatches(X_train, y_train, batchsize, shuffle=True):
        # For testing, limit num iterations
#         if num_iters >= 2:
#             break
        inputs, targets = batch
        iter_train_err, iter_train_acc = train_fn(inputs, targets)
#         prediction = pred_fn(inputs)
        train_err += iter_train_err
        train_acc += iter_train_acc
        train_batches += 1
        
        # Run validation on entire data set after each iteration, not iterating over mini batches of 
        
        val_err, val_acc = val_fn(inputs, targets)
        
        if record_per_iter:
            train_err_list.append(iter_train_err)
            train_acc_list.append(iter_train_acc)
            val_err_list.append(val_err)
            val_acc_list.append(val_acc)
        
        print("Ep {} \titer {}  \tloss {:.5f}, train acc {:.2f}, val acc {:.2f}".format(epoch, num_iters, float(iter_train_err), iter_train_acc * 100, val_acc *100 ))
        num_iters += 1

    # Then we print the results for this epoch:
    
    epoch_train_err = train_err / train_batches
    epoch_train_acc = train_acc / train_batches * 100
    epoch_val_err = val_err / 1
    epoch_val_acc = val_acc / 1 * 100
    
    print("Epoch {} of {} took {:.3f}s".format(
        epoch + 1, num_epochs, time.time() - start_time))
    print("  training loss:\t\t{:.6f}".format(epoch_train_err))
    print("  training accuracy:\t\t{:.2f} %".format(epoch_train_acc))
    print("  validation loss:\t\t{:.6f}".format(epoch_val_err))
    print("  validation accuracy:\t\t{:.2f} %".format(epoch_val_acc))
    
#     if not record_per_iter:
    epochs_train_err_list.append(epoch_train_err)
    epochs_train_acc_list.append(epoch_train_acc)
    epochs_val_err_list.append(epoch_val_err)
    epochs_val_acc_list.append(epoch_val_acc)

print('Training finished!')
# Out:
# Training on: 10 epochs of batch size 500 with num training samples 24000
# Validation Size: 3000
# Starting training...
# Ep 0 	iter 0  	loss 1.78188, train acc 15.80, val acc 23.00
# Ep 0 	iter 1  	loss 3407.48315, train acc 18.80, val acc 24.20
# Ep 0 	iter 2  	loss 561.90243, train acc 25.60, val acc 25.60
# Ep 0 	iter 3  	loss 81.93314, train acc 23.60, val acc 24.80
# Ep 0 	iter 4  	loss 137.77106, train acc 17.80, val acc 19.00
# Ep 0 	iter 5  	loss 70.13708, train acc 19.20, val acc 23.60
# Ep 0 	iter 6  	loss 113.38878, train acc 22.20, val acc 21.00
# Ep 0 	iter 7  	loss 46.54157, train acc 20.80, val acc 17.40
# Ep 0 	iter 8  	loss 10.55827, train acc 21.00, val acc 21.40
# Ep 0 	iter 9  	loss 2.38293, train acc 18.40, val acc 18.40
# Ep 0 	iter 10  	loss 1.63565, train acc 21.80, val acc 21.80
# Ep 0 	iter 11  	loss 1.65657, train acc 16.60, val acc 16.60
# Ep 0 	iter 12  	loss 1.64654, train acc 20.60, val acc 20.60
# Ep 0 	iter 13  	loss 1.65714, train acc 18.20, val acc 18.20
# Ep 0 	iter 14  	loss 1.64488, train acc 18.80, val acc 18.80
# Ep 0 	iter 15  	loss 1.64845, train acc 19.80, val acc 19.80
# Ep 0 	iter 16  	loss 2.41539, train acc 18.80, val acc 18.80
# Ep 0 	iter 17  	loss 1.63946, train acc 18.40, val acc 18.40
# Ep 0 	iter 18  	loss 1.61648, train acc 22.20, val acc 22.20
# Ep 0 	iter 19  	loss 1.62806, train acc 18.20, val acc 18.20
# Ep 0 	iter 20  	loss 1.61649, train acc 19.40, val acc 19.40
# Ep 0 	iter 21  	loss 1.61580, train acc 20.40, val acc 20.40
# Ep 0 	iter 22  	loss 1.61115, train acc 19.80, val acc 19.80
# Ep 0 	iter 23  	loss 1.61613, train acc 14.60, val acc 14.60
# Ep 0 	iter 24  	loss 1.60976, train acc 18.60, val acc 18.60
# Ep 0 	iter 25  	loss 1.60662, train acc 16.80, val acc 21.00
# Ep 0 	iter 26  	loss 1.60734, train acc 18.40, val acc 18.40
# Ep 0 	iter 27  	loss 1.60164, train acc 20.40, val acc 20.40
# Ep 0 	iter 28  	loss 1.60481, train acc 17.40, val acc 17.40
# Ep 0 	iter 29  	loss 1.60335, train acc 17.80, val acc 24.80
# Ep 0 	iter 30  	loss 1.59689, train acc 24.40, val acc 24.40
# Ep 0 	iter 31  	loss 1.60377, train acc 23.60, val acc 23.60
# Ep 0 	iter 32  	loss 1.60064, train acc 25.20, val acc 25.20
# Ep 0 	iter 33  	loss 1.60225, train acc 22.60, val acc 22.60
# Ep 0 	iter 34  	loss 1.60643, train acc 20.20, val acc 20.20
# Ep 0 	iter 35  	loss 1.59425, train acc 26.80, val acc 26.80
# Ep 0 	iter 36  	loss 1.60151, train acc 26.40, val acc 26.40
# Ep 0 	iter 37  	loss 1.60272, train acc 23.20, val acc 23.20
# Ep 0 	iter 38  	loss 2.06667, train acc 25.40, val acc 25.40
# Ep 0 	iter 39  	loss 1.59298, train acc 27.40, val acc 27.40
# Ep 0 	iter 40  	loss 1.58737, train acc 28.40, val acc 28.40
# Ep 0 	iter 41  	loss 1.60350, train acc 24.40, val acc 24.40
# Ep 0 	iter 42  	loss 1.60140, train acc 26.20, val acc 26.20
# Ep 0 	iter 43  	loss 1.59846, train acc 23.00, val acc 23.00
# Ep 0 	iter 44  	loss 1.59991, train acc 26.20, val acc 26.20
# Ep 0 	iter 45  	loss 1.61073, train acc 20.20, val acc 20.20
# Ep 0 	iter 46  	loss 1.60843, train acc 24.80, val acc 24.80
# Ep 0 	iter 47  	loss 1.61058, train acc 23.40, val acc 23.40
# Epoch 1 of 10 took 464.096s
#   training loss:		93.676052
#   training accuracy:		21.29 %
#   validation loss:		1.609608
#   validation accuracy:		23.40 %
# Ep 1 	iter 0  	loss 1.59290, train acc 27.20, val acc 27.20
# Ep 1 	iter 1  	loss 1.60534, train acc 24.00, val acc 24.00
# Ep 1 	iter 2  	loss 1.59819, train acc 24.20, val acc 24.20
# Ep 1 	iter 3  	loss 1.59776, train acc 25.60, val acc 25.60
# Ep 1 	iter 4  	loss 1.61407, train acc 22.20, val acc 22.20
# Ep 1 	iter 5  	loss 1.59528, train acc 26.00, val acc 26.00
# Ep 1 	iter 6  	loss 1.58771, train acc 27.80, val acc 27.80
# Ep 1 	iter 7  	loss 1.59808, train acc 24.80, val acc 24.80
# Ep 1 	iter 8  	loss 1.59404, train acc 26.00, val acc 26.00
# Ep 1 	iter 9  	loss 1.59316, train acc 27.20, val acc 27.20
# Ep 1 	iter 10  	loss 1.60283, train acc 25.40, val acc 25.40
# Ep 1 	iter 11  	loss 1.60522, train acc 21.60, val acc 21.60
# Ep 1 	iter 12  	loss 1.60463, train acc 22.00, val acc 22.00
# Ep 1 	iter 13  	loss 1.61021, train acc 22.80, val acc 22.80
# Ep 1 	iter 14  	loss 1.59279, train acc 25.00, val acc 25.00
# Ep 1 	iter 15  	loss 1.59747, train acc 25.60, val acc 25.60
# Ep 1 	iter 16  	loss 1.58459, train acc 29.00, val acc 29.00
# Ep 1 	iter 17  	loss 1.59167, train acc 28.40, val acc 28.40
# Ep 1 	iter 18  	loss 1.59682, train acc 26.60, val acc 26.60
# Ep 1 	iter 19  	loss 1.60841, train acc 21.60, val acc 21.60
# Ep 1 	iter 20  	loss 1.59834, train acc 24.20, val acc 24.20
# Ep 1 	iter 21  	loss 1.60139, train acc 23.60, val acc 23.60
# Ep 1 	iter 22  	loss 1.60705, train acc 21.60, val acc 21.60
# Ep 1 	iter 23  	loss 1.58655, train acc 27.40, val acc 27.40
# Ep 1 	iter 24  	loss 1.58225, train acc 28.00, val acc 28.00
# Ep 1 	iter 25  	loss 1.59998, train acc 23.40, val acc 23.40
# Ep 1 	iter 26  	loss 1.60320, train acc 24.00, val acc 24.00
# Ep 1 	iter 27  	loss 1.59186, train acc 27.20, val acc 27.20
# Ep 1 	iter 28  	loss 1.59998, train acc 23.80, val acc 23.80
# Ep 1 	iter 29  	loss 1.59192, train acc 26.20, val acc 26.20
# Ep 1 	iter 30  	loss 1.60177, train acc 25.00, val acc 25.00
# Ep 1 	iter 31  	loss 1.59619, train acc 24.60, val acc 24.60
# Ep 1 	iter 32  	loss 1.60449, train acc 24.60, val acc 24.60
# Ep 1 	iter 33  	loss 1.58886, train acc 26.00, val acc 26.00
# Ep 1 	iter 34  	loss 1.59247, train acc 26.60, val acc 26.60
# Ep 1 	iter 35  	loss 1.58580, train acc 26.40, val acc 26.40
# Ep 1 	iter 36  	loss 1.60255, train acc 25.60, val acc 25.60
# Ep 1 	iter 37  	loss 1.59937, train acc 23.80, val acc 23.80
# Ep 1 	iter 38  	loss 1.59838, train acc 25.00, val acc 25.00
# Ep 1 	iter 39  	loss 1.59666, train acc 24.60, val acc 24.60
# Ep 1 	iter 40  	loss 1.59697, train acc 25.80, val acc 25.80
# Ep 1 	iter 41  	loss 1.60587, train acc 23.20, val acc 23.20
# Ep 1 	iter 42  	loss 1.60019, train acc 21.60, val acc 21.60
# Ep 1 	iter 43  	loss 1.60297, train acc 23.80, val acc 23.80
# Ep 1 	iter 44  	loss 1.59369, train acc 26.40, val acc 26.40
# Ep 1 	iter 45  	loss 1.59451, train acc 24.00, val acc 24.00
# Ep 1 	iter 46  	loss 1.58981, train acc 25.60, val acc 25.60
# Ep 1 	iter 47  	loss 1.60983, train acc 24.20, val acc 24.20
# Epoch 2 of 10 took 397.476s
#   training loss:		1.597793
#   training accuracy:		24.98 %
#   validation loss:		1.609880
#   validation accuracy:		24.20 %
# Ep 2 	iter 0  	loss 1.60111, train acc 26.20, val acc 26.20
# Ep 2 	iter 1  	loss 1.59620, train acc 23.60, val acc 23.60
# Ep 2 	iter 2  	loss 1.60843, train acc 21.00, val acc 21.00
# Ep 2 	iter 3  	loss 1.59033, train acc 27.00, val acc 27.00
# Ep 2 	iter 4  	loss 1.59647, train acc 22.60, val acc 22.60
# Ep 2 	iter 5  	loss 1.60726, train acc 22.20, val acc 22.20
# Ep 2 	iter 6  	loss 1.60942, train acc 23.40, val acc 23.40
# Ep 2 	iter 7  	loss 1.58132, train acc 29.80, val acc 29.80
# Ep 2 	iter 8  	loss 1.59611, train acc 26.20, val acc 26.20
# Ep 2 	iter 9  	loss 1.59719, train acc 26.40, val acc 26.40
# Ep 2 	iter 10  	loss 1.59358, train acc 25.80, val acc 25.80
# Ep 2 	iter 11  	loss 1.59679, train acc 25.40, val acc 25.40
# Ep 2 	iter 12  	loss 1.60448, train acc 25.00, val acc 25.00
# Ep 2 	iter 13  	loss 1.60422, train acc 23.20, val acc 23.20
# Ep 2 	iter 14  	loss 1.59874, train acc 25.00, val acc 25.00
# Ep 2 	iter 15  	loss 1.59083, train acc 25.00, val acc 25.00
# Ep 2 	iter 16  	loss 1.58809, train acc 26.60, val acc 26.60
# Ep 2 	iter 17  	loss 1.60552, train acc 21.60, val acc 21.60
# Ep 2 	iter 18  	loss 1.59625, train acc 25.60, val acc 25.60
# Ep 2 	iter 19  	loss 1.58419, train acc 29.00, val acc 29.00
# Ep 2 	iter 20  	loss 1.58478, train acc 29.40, val acc 29.40
# Ep 2 	iter 21  	loss 1.60003, train acc 24.20, val acc 24.20
# Ep 2 	iter 22  	loss 1.60011, train acc 25.60, val acc 25.60
# Ep 2 	iter 23  	loss 1.60349, train acc 21.60, val acc 21.60
# Ep 2 	iter 24  	loss 1.60131, train acc 24.60, val acc 24.60
# Ep 2 	iter 25  	loss 1.59909, train acc 25.00, val acc 25.00
# Ep 2 	iter 26  	loss 1.58591, train acc 27.60, val acc 27.60
# Ep 2 	iter 27  	loss 1.60418, train acc 24.40, val acc 24.40
# Ep 2 	iter 28  	loss 1.59940, train acc 25.00, val acc 25.00
# Ep 2 	iter 29  	loss 1.60007, train acc 23.80, val acc 23.80
# Ep 2 	iter 30  	loss 1.59668, train acc 24.40, val acc 24.40
# Ep 2 	iter 31  	loss 1.59421, train acc 25.40, val acc 25.40
# Ep 2 	iter 32  	loss 1.59946, train acc 22.60, val acc 22.60
# Ep 2 	iter 33  	loss 1.59852, train acc 25.20, val acc 25.20
# Ep 2 	iter 34  	loss 1.59327, train acc 26.00, val acc 26.00
# Ep 2 	iter 35  	loss 1.59063, train acc 25.60, val acc 25.60
# Ep 2 	iter 36  	loss 1.59196, train acc 26.80, val acc 26.80
# Ep 2 	iter 37  	loss 1.59635, train acc 26.20, val acc 26.20
# Ep 2 	iter 38  	loss 1.59615, train acc 24.60, val acc 24.60
# Ep 2 	iter 39  	loss 1.60947, train acc 22.80, val acc 22.80
# Ep 2 	iter 40  	loss 1.59855, train acc 26.00, val acc 26.00
# Ep 2 	iter 41  	loss 1.59541, train acc 25.40, val acc 25.40
# Ep 2 	iter 42  	loss 1.60120, train acc 24.60, val acc 24.60
# Ep 2 	iter 43  	loss 1.60387, train acc 23.40, val acc 23.40
# Ep 2 	iter 44  	loss 1.59577, train acc 25.40, val acc 25.40
# Ep 2 	iter 45  	loss 1.58615, train acc 26.80, val acc 26.80
# Ep 2 	iter 46  	loss 1.60861, train acc 22.00, val acc 22.00
# Ep 2 	iter 47  	loss 1.60188, train acc 24.20, val acc 24.20
# Epoch 3 of 10 took 397.591s
#   training loss:		1.597563
#   training accuracy:		24.98 %
#   validation loss:		1.601854
#   validation accuracy:		24.20 %
# Ep 3 	iter 0  	loss 1.59883, train acc 25.20, val acc 25.20
# Ep 3 	iter 1  	loss 1.58933, train acc 27.20, val acc 27.20
# Ep 3 	iter 2  	loss 1.60610, train acc 23.20, val acc 23.20
# Ep 3 	iter 3  	loss 1.59552, train acc 25.60, val acc 25.60
# Ep 3 	iter 4  	loss 1.60442, train acc 22.60, val acc 22.60
# Ep 3 	iter 5  	loss 1.60260, train acc 24.80, val acc 24.80
# Ep 3 	iter 6  	loss 1.59833, train acc 23.00, val acc 23.00
# Ep 3 	iter 7  	loss 1.60613, train acc 22.20, val acc 22.20
# Ep 3 	iter 8  	loss 1.59947, train acc 24.80, val acc 24.80
# Ep 3 	iter 9  	loss 1.60062, train acc 24.00, val acc 24.00
# Ep 3 	iter 10  	loss 1.58915, train acc 26.20, val acc 26.20
# Ep 3 	iter 11  	loss 1.59296, train acc 25.20, val acc 25.20
# Ep 3 	iter 12  	loss 1.58925, train acc 25.20, val acc 25.20
# Ep 3 	iter 13  	loss 1.60890, train acc 24.20, val acc 24.20
# Ep 3 	iter 14  	loss 1.59684, train acc 26.40, val acc 26.40
# Ep 3 	iter 15  	loss 1.59532, train acc 26.00, val acc 26.00
# Ep 3 	iter 16  	loss 1.60223, train acc 24.20, val acc 24.20
# Ep 3 	iter 17  	loss 1.60293, train acc 23.80, val acc 23.80
# Ep 3 	iter 18  	loss 1.58774, train acc 27.20, val acc 27.20
# Ep 3 	iter 19  	loss 1.60048, train acc 25.00, val acc 25.00
# Ep 3 	iter 20  	loss 1.60223, train acc 23.00, val acc 23.00
# Ep 3 	iter 21  	loss 1.58938, train acc 26.60, val acc 26.60
# Ep 3 	iter 22  	loss 1.58522, train acc 29.00, val acc 29.00
# Ep 3 	iter 23  	loss 1.59626, train acc 26.60, val acc 26.60
# Ep 3 	iter 24  	loss 1.59015, train acc 25.00, val acc 25.00
# Ep 3 	iter 25  	loss 1.60060, train acc 25.00, val acc 25.00
# Ep 3 	iter 26  	loss 1.58251, train acc 27.60, val acc 27.60
# Ep 3 	iter 27  	loss 1.60036, train acc 24.00, val acc 24.00
# Ep 3 	iter 28  	loss 1.59414, train acc 26.60, val acc 26.60
# Ep 3 	iter 29  	loss 1.58377, train acc 26.60, val acc 26.60
# Ep 3 	iter 30  	loss 1.57980, train acc 29.60, val acc 29.60
# Ep 3 	iter 31  	loss 1.60359, train acc 23.60, val acc 23.60
# Ep 3 	iter 32  	loss 1.60013, train acc 22.00, val acc 22.00
# Ep 3 	iter 33  	loss 1.60472, train acc 24.00, val acc 24.00
# Ep 3 	iter 34  	loss 1.61152, train acc 23.80, val acc 23.80
# Ep 3 	iter 35  	loss 1.58392, train acc 27.60, val acc 27.60
# Ep 3 	iter 36  	loss 1.59515, train acc 25.20, val acc 25.20
# Ep 3 	iter 37  	loss 1.60650, train acc 22.00, val acc 22.00
# Ep 3 	iter 38  	loss 1.60051, train acc 24.60, val acc 24.60
# Ep 3 	iter 39  	loss 1.60724, train acc 24.00, val acc 24.00
# Ep 3 	iter 40  	loss 1.60044, train acc 24.20, val acc 24.20
# Ep 3 	iter 41  	loss 1.59811, train acc 23.00, val acc 23.00
# Ep 3 	iter 42  	loss 1.60132, train acc 24.40, val acc 24.40
# Ep 3 	iter 43  	loss 1.59031, train acc 27.20, val acc 27.20
# Ep 3 	iter 44  	loss 1.59481, train acc 23.40, val acc 23.40
# Ep 3 	iter 45  	loss 1.61877, train acc 21.80, val acc 21.80
# Ep 3 	iter 46  	loss 1.60031, train acc 27.60, val acc 27.60
# Ep 3 	iter 47  	loss 1.60054, train acc 25.20, val acc 25.20
# Epoch 4 of 10 took 360.656s
#   training loss:		1.597697
#   training accuracy:		24.98 %
#   validation loss:		1.600334
#   validation accuracy:		25.20 %
# Ep 4 	iter 0  	loss 1.60025, train acc 22.40, val acc 22.40
# Ep 4 	iter 1  	loss 1.60687, train acc 23.80, val acc 23.80
# Ep 4 	iter 2  	loss 1.59906, train acc 23.60, val acc 23.60
# Ep 4 	iter 3  	loss 1.59043, train acc 27.60, val acc 27.60
# Ep 4 	iter 4  	loss 1.60799, train acc 22.60, val acc 22.60
# Ep 4 	iter 5  	loss 1.60328, train acc 21.60, val acc 21.60
# Ep 4 	iter 6  	loss 1.59548, train acc 26.20, val acc 26.20
# Ep 4 	iter 7  	loss 1.60390, train acc 24.40, val acc 24.40
# Ep 4 	iter 8  	loss 1.59580, train acc 24.00, val acc 24.00
# Ep 4 	iter 9  	loss 1.59391, train acc 27.20, val acc 27.20
# Ep 4 	iter 10  	loss 1.60090, train acc 26.00, val acc 26.00
# Ep 4 	iter 11  	loss 1.59392, train acc 26.40, val acc 26.40
# Ep 4 	iter 12  	loss 1.59612, train acc 25.80, val acc 25.80
# Ep 4 	iter 13  	loss 1.59548, train acc 25.40, val acc 25.40
# Ep 4 	iter 14  	loss 1.58479, train acc 26.80, val acc 26.80
# Ep 4 	iter 15  	loss 1.61525, train acc 21.20, val acc 21.20
# Ep 4 	iter 16  	loss 1.59544, train acc 26.00, val acc 26.00
# Ep 4 	iter 17  	loss 1.59606, train acc 27.00, val acc 27.00
# Ep 4 	iter 18  	loss 1.59978, train acc 23.20, val acc 23.20
# Ep 4 	iter 19  	loss 1.60025, train acc 24.60, val acc 24.60
# Ep 4 	iter 20  	loss 1.60470, train acc 23.60, val acc 23.60
# Ep 4 	iter 21  	loss 1.58547, train acc 28.80, val acc 28.80
# Ep 4 	iter 22  	loss 1.58738, train acc 28.00, val acc 28.00
# Ep 4 	iter 23  	loss 1.60820, train acc 24.60, val acc 24.60
# Ep 4 	iter 24  	loss 1.59870, train acc 25.60, val acc 25.60
# Ep 4 	iter 25  	loss 1.60011, train acc 24.80, val acc 24.80
# Ep 4 	iter 26  	loss 1.59605, train acc 24.20, val acc 24.20
# Ep 4 	iter 27  	loss 1.58851, train acc 26.00, val acc 26.00
# Ep 4 	iter 28  	loss 1.59393, train acc 26.40, val acc 26.40
# Ep 4 	iter 29  	loss 1.59617, train acc 23.60, val acc 23.60
# Ep 4 	iter 30  	loss 1.59895, train acc 24.40, val acc 24.40
# Ep 4 	iter 31  	loss 1.61522, train acc 21.00, val acc 21.00
# Ep 4 	iter 32  	loss 1.60316, train acc 22.20, val acc 22.20
# Ep 4 	iter 33  	loss 1.59371, train acc 23.80, val acc 23.80
# Ep 4 	iter 34  	loss 1.58006, train acc 29.40, val acc 29.40
# Ep 4 	iter 35  	loss 1.58888, train acc 26.60, val acc 26.60
# Ep 4 	iter 36  	loss 1.58898, train acc 28.00, val acc 28.00
# Ep 4 	iter 37  	loss 1.59642, train acc 25.20, val acc 25.20
# Ep 4 	iter 38  	loss 1.59450, train acc 25.40, val acc 25.40
# Ep 4 	iter 39  	loss 1.60118, train acc 23.40, val acc 23.40
# Ep 4 	iter 40  	loss 1.59337, train acc 24.60, val acc 24.60
# Ep 4 	iter 41  	loss 1.60265, train acc 25.60, val acc 25.60
# Ep 4 	iter 42  	loss 1.60168, train acc 24.60, val acc 24.60
# Ep 4 	iter 43  	loss 1.59694, train acc 24.20, val acc 24.20
# Ep 4 	iter 44  	loss 1.59245, train acc 26.00, val acc 26.00
# Ep 4 	iter 45  	loss 1.61291, train acc 21.40, val acc 21.40
# Ep 4 	iter 46  	loss 1.59687, train acc 26.40, val acc 26.40
# Ep 4 	iter 47  	loss 1.59527, train acc 25.60, val acc 25.60
# Epoch 5 of 10 took 360.347s
#   training loss:		1.597654
#   training accuracy:		24.98 %
#   validation loss:		1.595292
#   validation accuracy:		25.60 %
# Ep 5 	iter 0  	loss 1.60019, train acc 25.00, val acc 25.00
# Ep 5 	iter 1  	loss 1.59489, train acc 26.00, val acc 26.00
# Ep 5 	iter 2  	loss 1.60004, train acc 23.80, val acc 23.80
# Ep 5 	iter 3  	loss 1.58932, train acc 27.60, val acc 27.60
# Ep 5 	iter 4  	loss 1.60008, train acc 24.80, val acc 24.80
# Ep 5 	iter 5  	loss 1.60516, train acc 23.60, val acc 23.60
# Ep 5 	iter 6  	loss 1.59104, train acc 27.00, val acc 27.00
# Ep 5 	iter 7  	loss 1.59666, train acc 25.00, val acc 25.00
# Ep 5 	iter 8  	loss 1.60091, train acc 26.00, val acc 26.00
# Ep 5 	iter 9  	loss 1.58761, train acc 29.00, val acc 29.00
# Ep 5 	iter 10  	loss 1.59299, train acc 24.60, val acc 24.60
# Ep 5 	iter 11  	loss 1.60138, train acc 24.20, val acc 24.20
# Ep 5 	iter 12  	loss 1.60206, train acc 25.20, val acc 25.20
# Ep 5 	iter 13  	loss 1.59082, train acc 27.00, val acc 27.00
# Ep 5 	iter 14  	loss 1.59825, train acc 25.00, val acc 25.00
# Ep 5 	iter 15  	loss 1.60195, train acc 21.80, val acc 21.80
# Ep 5 	iter 16  	loss 1.60337, train acc 25.00, val acc 25.00
# Ep 5 	iter 17  	loss 1.59295, train acc 26.40, val acc 26.40
# Ep 5 	iter 18  	loss 1.60863, train acc 22.40, val acc 22.40
# Ep 5 	iter 19  	loss 1.60586, train acc 24.80, val acc 24.80
# Ep 5 	iter 20  	loss 1.59432, train acc 24.40, val acc 24.40
# Ep 5 	iter 21  	loss 1.60513, train acc 23.20, val acc 23.20
# Ep 5 	iter 22  	loss 1.58774, train acc 29.40, val acc 29.40
# Ep 5 	iter 23  	loss 1.60349, train acc 23.40, val acc 23.40
# Ep 5 	iter 24  	loss 1.59552, train acc 26.20, val acc 26.20
# Ep 5 	iter 25  	loss 1.60718, train acc 20.80, val acc 20.80
# Ep 5 	iter 26  	loss 1.59186, train acc 26.80, val acc 26.80
# Ep 5 	iter 27  	loss 1.59492, train acc 26.40, val acc 26.40
# Ep 5 	iter 28  	loss 1.59258, train acc 24.80, val acc 24.80
# Ep 5 	iter 29  	loss 1.58182, train acc 28.60, val acc 28.60
# Ep 5 	iter 30  	loss 1.60707, train acc 23.60, val acc 23.60
# Ep 5 	iter 31  	loss 1.60441, train acc 23.80, val acc 23.80
# Ep 5 	iter 32  	loss 1.59691, train acc 25.60, val acc 25.60
# Ep 5 	iter 33  	loss 1.59941, train acc 23.40, val acc 23.40
# Ep 5 	iter 34  	loss 1.59776, train acc 23.60, val acc 23.60
# Ep 5 	iter 35  	loss 1.59344, train acc 23.20, val acc 23.20
# Ep 5 	iter 36  	loss 1.60352, train acc 24.80, val acc 24.80
# Ep 5 	iter 37  	loss 1.60989, train acc 22.40, val acc 22.40
# Ep 5 	iter 38  	loss 1.60582, train acc 22.00, val acc 22.00
# Ep 5 	iter 39  	loss 1.60518, train acc 23.60, val acc 23.60
# Ep 5 	iter 40  	loss 1.58973, train acc 28.20, val acc 28.20
# Ep 5 	iter 41  	loss 1.59354, train acc 25.40, val acc 25.40
# Ep 5 	iter 42  	loss 1.60306, train acc 22.20, val acc 22.20
# Ep 5 	iter 43  	loss 1.58838, train acc 25.20, val acc 25.20
# Ep 5 	iter 44  	loss 1.58408, train acc 29.40, val acc 29.40
# Ep 5 	iter 45  	loss 1.59219, train acc 24.80, val acc 24.80
# Ep 5 	iter 46  	loss 1.59942, train acc 23.60, val acc 23.60
# Ep 5 	iter 47  	loss 1.59176, train acc 26.20, val acc 26.20
# Epoch 6 of 10 took 346.330s
#   training loss:		1.597589
#   training accuracy:		24.98 %
#   validation loss:		1.591807
#   validation accuracy:		26.20 %
# Ep 6 	iter 0  	loss 1.60119, train acc 26.20, val acc 26.20
# Ep 6 	iter 1  	loss 1.59136, train acc 27.20, val acc 27.20
# Ep 6 	iter 2  	loss 1.60227, train acc 23.20, val acc 23.20
# Ep 6 	iter 3  	loss 1.59326, train acc 25.40, val acc 25.40
# Ep 6 	iter 4  	loss 1.58895, train acc 28.60, val acc 28.60
# Ep 6 	iter 5  	loss 1.60441, train acc 25.00, val acc 25.00
# Ep 6 	iter 6  	loss 1.59895, train acc 26.80, val acc 26.80
# Ep 6 	iter 7  	loss 1.60542, train acc 23.00, val acc 23.00
# Ep 6 	iter 8  	loss 1.58470, train acc 28.20, val acc 28.20
# Ep 6 	iter 9  	loss 1.59685, train acc 24.00, val acc 24.00
# Ep 6 	iter 10  	loss 1.58818, train acc 24.20, val acc 24.20
# Ep 6 	iter 11  	loss 1.58638, train acc 24.80, val acc 24.80
# Ep 6 	iter 12  	loss 1.59754, train acc 24.80, val acc 24.80
# Ep 6 	iter 13  	loss 1.60112, train acc 26.80, val acc 26.80
# Ep 6 	iter 14  	loss 1.60094, train acc 23.80, val acc 23.80
# Ep 6 	iter 15  	loss 1.60143, train acc 26.20, val acc 26.20
# Ep 6 	iter 16  	loss 1.60291, train acc 24.20, val acc 24.20
# Ep 6 	iter 17  	loss 1.59562, train acc 27.00, val acc 27.00
# Ep 6 	iter 18  	loss 1.59144, train acc 26.80, val acc 26.80
# Ep 6 	iter 19  	loss 1.58714, train acc 26.40, val acc 26.40
# Ep 6 	iter 20  	loss 1.59570, train acc 24.20, val acc 24.20
# Ep 6 	iter 21  	loss 1.60251, train acc 23.40, val acc 23.40
# Ep 6 	iter 22  	loss 1.59911, train acc 24.20, val acc 24.20
# Ep 6 	iter 23  	loss 1.60005, train acc 25.00, val acc 25.00
# Ep 6 	iter 24  	loss 1.59898, train acc 25.00, val acc 25.00
# Ep 6 	iter 25  	loss 1.59535, train acc 25.00, val acc 25.00
# Ep 6 	iter 26  	loss 1.60419, train acc 23.60, val acc 23.60
# Ep 6 	iter 27  	loss 1.60820, train acc 24.80, val acc 24.80
# Ep 6 	iter 28  	loss 1.59142, train acc 26.80, val acc 26.80
# Ep 6 	iter 29  	loss 1.59892, train acc 25.80, val acc 25.80
# Ep 6 	iter 30  	loss 1.60397, train acc 24.80, val acc 24.80
# Ep 6 	iter 31  	loss 1.61364, train acc 20.40, val acc 20.40
# Ep 6 	iter 32  	loss 1.59499, train acc 25.40, val acc 25.40
# Ep 6 	iter 33  	loss 1.61041, train acc 23.60, val acc 23.60
# Ep 6 	iter 34  	loss 1.59374, train acc 26.20, val acc 26.20
# Ep 6 	iter 35  	loss 1.60973, train acc 20.60, val acc 20.60
# Ep 6 	iter 36  	loss 1.60439, train acc 21.40, val acc 21.40
# Ep 6 	iter 37  	loss 1.59602, train acc 26.40, val acc 26.40
# Ep 6 	iter 38  	loss 1.60157, train acc 22.00, val acc 22.00
# Ep 6 	iter 39  	loss 1.60232, train acc 23.40, val acc 23.40
# Ep 6 	iter 40  	loss 1.58932, train acc 27.40, val acc 27.40
# Ep 6 	iter 41  	loss 1.59800, train acc 23.00, val acc 23.00
# Ep 6 	iter 42  	loss 1.60052, train acc 24.80, val acc 24.80
# Ep 6 	iter 43  	loss 1.59904, train acc 25.60, val acc 25.60
# Ep 6 	iter 44  	loss 1.59162, train acc 24.60, val acc 24.60
# Ep 6 	iter 45  	loss 1.60099, train acc 23.80, val acc 23.80
# Ep 6 	iter 46  	loss 1.58623, train acc 27.60, val acc 27.60
# Ep 6 	iter 47  	loss 1.58320, train acc 27.80, val acc 27.80
# Epoch 7 of 10 took 346.061s
#   training loss:		1.597796
#   training accuracy:		24.98 %
#   validation loss:		1.582361
#   validation accuracy:		27.80 %
# Ep 7 	iter 0  	loss 1.60359, train acc 24.00, val acc 24.00
# Ep 7 	iter 1  	loss 1.59356, train acc 21.60, val acc 21.60
# Ep 7 	iter 2  	loss 1.59019, train acc 26.00, val acc 26.00
# Ep 7 	iter 3  	loss 1.59487, train acc 26.20, val acc 26.20
# Ep 7 	iter 4  	loss 1.60105, train acc 26.20, val acc 26.20
# Ep 7 	iter 5  	loss 1.60655, train acc 24.80, val acc 24.80
# Ep 7 	iter 6  	loss 1.59840, train acc 23.80, val acc 23.80
# Ep 7 	iter 7  	loss 1.58951, train acc 27.40, val acc 27.40
# Ep 7 	iter 8  	loss 1.60203, train acc 25.00, val acc 25.00
# Ep 7 	iter 9  	loss 1.60163, train acc 23.80, val acc 23.80
# Ep 7 	iter 10  	loss 1.60035, train acc 23.60, val acc 23.60
# Ep 7 	iter 11  	loss 1.58300, train acc 28.60, val acc 28.60
# Ep 7 	iter 12  	loss 1.58441, train acc 27.20, val acc 27.20
# Ep 7 	iter 13  	loss 1.60357, train acc 26.00, val acc 26.00
# Ep 7 	iter 14  	loss 1.59039, train acc 29.00, val acc 29.00
# Ep 7 	iter 15  	loss 1.59876, train acc 25.60, val acc 25.60
# Ep 7 	iter 16  	loss 1.59125, train acc 26.40, val acc 26.40
# Ep 7 	iter 17  	loss 1.60762, train acc 21.60, val acc 21.60
# Ep 7 	iter 18  	loss 1.59685, train acc 25.00, val acc 25.00
# Ep 7 	iter 19  	loss 1.59314, train acc 25.40, val acc 25.40
# Ep 7 	iter 20  	loss 1.59945, train acc 25.40, val acc 25.40
# Ep 7 	iter 21  	loss 1.60248, train acc 22.40, val acc 22.40
# Ep 7 	iter 22  	loss 1.60366, train acc 23.00, val acc 23.00
# Ep 7 	iter 23  	loss 1.61041, train acc 22.60, val acc 22.60
# Ep 7 	iter 24  	loss 1.58899, train acc 27.20, val acc 27.20
# Ep 7 	iter 25  	loss 1.59043, train acc 27.20, val acc 27.20
# Ep 7 	iter 26  	loss 1.58805, train acc 27.60, val acc 27.60
# Ep 7 	iter 27  	loss 1.61468, train acc 20.20, val acc 20.20
# Ep 7 	iter 28  	loss 1.60792, train acc 23.80, val acc 23.80
# Ep 7 	iter 29  	loss 1.60383, train acc 23.60, val acc 23.60
# Ep 7 	iter 30  	loss 1.60006, train acc 22.40, val acc 22.40
# Ep 7 	iter 31  	loss 1.59253, train acc 24.80, val acc 24.80
# Ep 7 	iter 32  	loss 1.59070, train acc 25.20, val acc 25.20
# Ep 7 	iter 33  	loss 1.59368, train acc 25.40, val acc 25.40
# Ep 7 	iter 34  	loss 1.60717, train acc 22.00, val acc 22.00
# Ep 7 	iter 35  	loss 1.58612, train acc 29.20, val acc 29.20
# Ep 7 	iter 36  	loss 1.59344, train acc 26.60, val acc 26.60
# Ep 7 	iter 37  	loss 1.60128, train acc 27.00, val acc 27.00
# Ep 7 	iter 38  	loss 1.59030, train acc 27.80, val acc 27.80
# Ep 7 	iter 39  	loss 1.59443, train acc 27.00, val acc 27.00
# Ep 7 	iter 40  	loss 1.61651, train acc 20.40, val acc 20.40
# Ep 7 	iter 41  	loss 1.59179, train acc 26.00, val acc 26.00
# Ep 7 	iter 42  	loss 1.59840, train acc 25.20, val acc 25.20
# Ep 7 	iter 43  	loss 1.59054, train acc 25.60, val acc 25.60
# Ep 7 	iter 44  	loss 1.60201, train acc 24.40, val acc 24.40
# Ep 7 	iter 45  	loss 1.61141, train acc 23.60, val acc 23.60
# Ep 7 	iter 46  	loss 1.60399, train acc 23.40, val acc 23.40
# Ep 7 	iter 47  	loss 1.59853, train acc 23.00, val acc 23.00
# Epoch 8 of 10 took 346.789s
#   training loss:		1.597990
#   training accuracy:		24.98 %
#   validation loss:		1.597809
#   validation accuracy:		23.00 %
# Ep 8 	iter 0  	loss 1.59695, train acc 23.20, val acc 23.20
# Ep 8 	iter 1  	loss 1.58267, train acc 28.20, val acc 28.20
# Ep 8 	iter 2  	loss 1.59139, train acc 23.80, val acc 23.80
# Ep 8 	iter 3  	loss 1.58443, train acc 28.40, val acc 28.40
# Ep 8 	iter 4  	loss 1.60053, train acc 24.80, val acc 24.80
# Ep 8 	iter 5  	loss 1.60987, train acc 23.00, val acc 23.00
# Ep 8 	iter 6  	loss 1.59352, train acc 25.00, val acc 25.00
# Ep 8 	iter 7  	loss 1.60007, train acc 24.60, val acc 24.60
# Ep 8 	iter 8  	loss 1.60526, train acc 22.20, val acc 22.20
# Ep 8 	iter 9  	loss 1.59190, train acc 26.40, val acc 26.40
# Ep 8 	iter 10  	loss 1.60357, train acc 24.60, val acc 24.60
# Ep 8 	iter 11  	loss 1.59105, train acc 26.40, val acc 26.40
# Ep 8 	iter 12  	loss 1.58874, train acc 27.20, val acc 27.20
# Ep 8 	iter 13  	loss 1.59870, train acc 25.60, val acc 25.60
# Ep 8 	iter 14  	loss 1.58842, train acc 24.60, val acc 24.60
# Ep 8 	iter 15  	loss 1.60189, train acc 25.60, val acc 25.60
# Ep 8 	iter 16  	loss 1.60358, train acc 26.00, val acc 26.00
# Ep 8 	iter 17  	loss 1.59137, train acc 26.20, val acc 26.20
# Ep 8 	iter 18  	loss 1.59702, train acc 27.00, val acc 27.00
# Ep 8 	iter 19  	loss 1.60151, train acc 24.80, val acc 24.80
# Ep 8 	iter 20  	loss 1.60054, train acc 24.00, val acc 24.00
# Ep 8 	iter 21  	loss 1.59530, train acc 23.80, val acc 23.80
# Ep 8 	iter 22  	loss 1.59455, train acc 24.20, val acc 24.20
# Ep 8 	iter 23  	loss 1.60378, train acc 25.20, val acc 25.20
# Ep 8 	iter 24  	loss 1.59021, train acc 27.00, val acc 27.00
# Ep 8 	iter 25  	loss 1.60896, train acc 22.20, val acc 22.20
# Ep 8 	iter 26  	loss 1.58748, train acc 26.60, val acc 26.60
# Ep 8 	iter 27  	loss 1.60034, train acc 22.60, val acc 22.60
# Ep 8 	iter 28  	loss 1.59823, train acc 24.40, val acc 24.40
# Ep 8 	iter 29  	loss 1.58800, train acc 25.40, val acc 25.40
# Ep 8 	iter 30  	loss 1.59391, train acc 24.60, val acc 24.60
# Ep 8 	iter 31  	loss 1.59485, train acc 26.60, val acc 26.60
# Ep 8 	iter 32  	loss 1.60263, train acc 24.80, val acc 24.80
# Ep 8 	iter 33  	loss 1.60352, train acc 25.60, val acc 25.60
# Ep 8 	iter 34  	loss 1.60226, train acc 24.00, val acc 24.00
# Ep 8 	iter 35  	loss 1.60540, train acc 24.00, val acc 24.00
# Ep 8 	iter 36  	loss 1.59826, train acc 23.00, val acc 23.00
# Ep 8 	iter 37  	loss 1.59716, train acc 25.80, val acc 25.80
# Ep 8 	iter 38  	loss 1.58769, train acc 26.80, val acc 26.80
# Ep 8 	iter 39  	loss 1.60907, train acc 21.20, val acc 21.20
# Ep 8 	iter 40  	loss 1.59676, train acc 25.80, val acc 25.80
# Ep 8 	iter 41  	loss 1.60990, train acc 21.00, val acc 21.00
# Ep 8 	iter 42  	loss 1.59342, train acc 27.20, val acc 27.20
# Ep 8 	iter 43  	loss 1.59153, train acc 28.00, val acc 28.00
# Ep 8 	iter 44  	loss 1.60340, train acc 23.80, val acc 23.80
# Ep 8 	iter 45  	loss 1.60907, train acc 23.40, val acc 23.40
# Ep 8 	iter 46  	loss 1.59886, train acc 25.80, val acc 25.80
# Ep 8 	iter 47  	loss 1.60228, train acc 24.80, val acc 24.80
# Epoch 9 of 10 took 425.720s
#   training loss:		1.597705
#   training accuracy:		24.98 %
#   validation loss:		1.602052
#   validation accuracy:		24.80 %
# Ep 9 	iter 0  	loss 1.59694, train acc 23.40, val acc 23.40
# Ep 9 	iter 1  	loss 1.61137, train acc 21.00, val acc 21.00
# Ep 9 	iter 2  	loss 1.60141, train acc 24.00, val acc 24.00
# Ep 9 	iter 3  	loss 1.59905, train acc 25.40, val acc 25.40
# Ep 9 	iter 4  	loss 1.59254, train acc 24.80, val acc 24.80
# Ep 9 	iter 5  	loss 1.59872, train acc 24.80, val acc 24.80
# Ep 9 	iter 6  	loss 1.60458, train acc 23.40, val acc 23.40
# Ep 9 	iter 7  	loss 1.59891, train acc 27.20, val acc 27.20
# Ep 9 	iter 8  	loss 1.60030, train acc 24.20, val acc 24.20
# Ep 9 	iter 9  	loss 1.59687, train acc 24.80, val acc 24.80
# Ep 9 	iter 10  	loss 1.60089, train acc 24.00, val acc 24.00
# Ep 9 	iter 11  	loss 1.59601, train acc 25.60, val acc 25.60
# Ep 9 	iter 12  	loss 1.59498, train acc 24.80, val acc 24.80
# Ep 9 	iter 13  	loss 1.60321, train acc 21.80, val acc 21.80
# Ep 9 	iter 14  	loss 1.59443, train acc 25.60, val acc 25.60
# Ep 9 	iter 15  	loss 1.59710, train acc 25.80, val acc 25.80
# Ep 9 	iter 16  	loss 1.59822, train acc 24.60, val acc 24.60
# Ep 9 	iter 17  	loss 1.59632, train acc 25.00, val acc 25.00
# Ep 9 	iter 18  	loss 1.60999, train acc 19.80, val acc 19.80
# Ep 9 	iter 19  	loss 1.59979, train acc 25.40, val acc 25.40
# Ep 9 	iter 20  	loss 1.60097, train acc 24.60, val acc 24.60
# Ep 9 	iter 21  	loss 1.59164, train acc 27.00, val acc 27.00
# Ep 9 	iter 22  	loss 1.59982, train acc 24.00, val acc 24.00
# Ep 9 	iter 23  	loss 1.58684, train acc 29.80, val acc 29.80
# Ep 9 	iter 24  	loss 1.59851, train acc 26.00, val acc 26.00
# Ep 9 	iter 25  	loss 1.61550, train acc 23.80, val acc 23.80
# Ep 9 	iter 26  	loss 1.59926, train acc 25.60, val acc 25.60
# Ep 9 	iter 27  	loss 1.58786, train acc 27.00, val acc 27.00
# Ep 9 	iter 28  	loss 1.58760, train acc 28.20, val acc 28.20
# Ep 9 	iter 29  	loss 1.59401, train acc 24.40, val acc 24.40
# Ep 9 	iter 30  	loss 1.60236, train acc 26.00, val acc 26.00
# Ep 9 	iter 31  	loss 1.58965, train acc 25.60, val acc 25.60
# Ep 9 	iter 32  	loss 1.59998, train acc 24.80, val acc 24.80
# Ep 9 	iter 33  	loss 1.59679, train acc 25.00, val acc 25.00
# Ep 9 	iter 34  	loss 1.60325, train acc 23.80, val acc 23.80
# Ep 9 	iter 35  	loss 1.59565, train acc 25.40, val acc 25.40
# Ep 9 	iter 36  	loss 1.59852, train acc 23.20, val acc 23.20
# Ep 9 	iter 37  	loss 1.59892, train acc 22.40, val acc 22.40
# Ep 9 	iter 38  	loss 1.59798, train acc 24.20, val acc 24.20
# Ep 9 	iter 39  	loss 1.58848, train acc 27.80, val acc 27.80
# Ep 9 	iter 40  	loss 1.60061, train acc 23.20, val acc 23.20
# Ep 9 	iter 41  	loss 1.59228, train acc 25.20, val acc 25.20
# Ep 9 	iter 42  	loss 1.59059, train acc 27.20, val acc 27.20
# Ep 9 	iter 43  	loss 1.58733, train acc 27.00, val acc 27.00
# Ep 9 	iter 44  	loss 1.59661, train acc 27.60, val acc 27.60
# Ep 9 	iter 45  	loss 1.60117, train acc 25.20, val acc 25.20
# Ep 9 	iter 46  	loss 1.60112, train acc 25.40, val acc 25.40
# Ep 9 	iter 47  	loss 1.60746, train acc 24.40, val acc 24.40
# Epoch 10 of 10 took 473.466s
#   training loss:		1.597967
#   training accuracy:		24.98 %
#   validation loss:		1.607172
#   validation accuracy:		24.40 %
# Training finished!

# %%
# After training, we compute and print the test error:
print('Testing...')
test_err = 0
test_acc = 0
test_batches = 0
for batch in data_utils.iterate_minibatches(X_test, y_test, batchsize, shuffle=False):
    inputs, targets = batch
    err, acc = val_fn(inputs, targets)
    test_err += err
    test_acc += acc
    test_batches += 1
    
print("Final results:")
print("  test loss:\t\t\t{:.6f}".format(test_err / test_batches))
print("  test accuracy:\t\t{:.2f} %".format(
    test_acc / test_batches * 100))
# Out:
# Testing...
# Final results:
#   test loss:			1.602842
#   test accuracy:		23.40 %

# %%
# Visualize the loss and the accuracies for both training and validation sets for each epoch
num_train = X_train.shape[0]
if record_per_iter:
    xlabel = "iterations"
else:
    xlabel = "epochs"
# Printing training losses and training + validation accuracies
data_set_name = DATA_SET + 'batch_' + str(USE_BATCH) + '_' + USE_OPTIMIZER
visualize.plot_loss_acc(data_set_name, train_err_list, train_acc_list, val_acc_list, LEARNING_RATE, reg_strength, num_epochs, num_train, xlabel=xlabel)

# %%
# Visualize the loss and the accuracies for both training and validation sets for each epoch
num_train = X_train.shape[0]
xlabel = "epochs"
# Printing training losses and training + validation accuracies
data_set_name = DATA_SET + 'batch_' + str(USE_BATCH) + '_on_epochs' + '_' + USE_OPTIMIZER
visualize.plot_loss_acc(data_set_name, epochs_train_err_list, epochs_train_acc_list, epochs_val_acc_list, LEARNING_RATE, reg_strength, num_epochs, num_train, xlabel=xlabel)
